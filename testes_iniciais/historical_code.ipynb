# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib

# Carregar o CSV com nome atualizado
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')

# Converter o timestamp para datetime
if 'time' in df.columns:
    df['time'] = pd.to_datetime(df['time'], errors='coerce')  # Remove unit='s' e converte diretamente
    # Verifique se houve falha na conversão
    if df['time'].isnull().any():
        num_failed = df['time'].isnull().sum()
        print(f"Atenção: {num_failed} entradas na coluna 'time' não puderam ser convertidas para datetime.")

# Atribuir os dados às variáveis
timestamp = df['time']
open_price = df['open']
high_price = df['high']
low_price = df['low']
close_price = df['close']

# Parâmetros configuráveis
emaShortLength = 11  # Período da EMA Curta
emaLongLength = 55  # Período da EMA Longa
rsiLength = 22  # Período do RSI
macdShort = 15  # Período Curto MACD
macdLong = 34  # Período Longo MACD
macdSignal = 11  # Período de Sinal MACD
adxLength = 16  # Período ADX (igual ao DI Length)
adxSmoothing = 13  # ADX Smoothing
adxThreshold = 12  # Nível de ADX para indicar tendência
bbLength = 14  # Período do Bollinger Bands
bbMultiplier = 1.7  # Multiplicador do Bollinger Bands
lateralThreshold = 0.005  # Limite de Lateralização
stopgain_lateral_long = 1.11
stoploss_lateral_long = 0.973
stopgain_lateral_short = 0.973
stoploss_lateral_short = 1.09
stopgain_normal_long = 1.32
stoploss_normal_long = 0.92
stopgain_normal_short = 0.77
stoploss_normal_short = 1.12

# Funções para cálculo manual do MACD
def macd_func(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    tr = []
    previous_close = close.iloc[0]
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        current_plus_dm = high.iloc[i] - high.iloc[i-1]
        current_minus_dm = low.iloc[i-1] - low.iloc[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)

        tr1 = high.iloc[i] - low.iloc[i]
        tr2 = abs(high.iloc[i] - previous_close)
        tr3 = abs(low.iloc[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)

        previous_close = close.iloc[i]

    tr.insert(0, np.nan)
    plus_dm.insert(0, np.nan)
    minus_dm.insert(0, np.nan)

    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)

    atr = tr.rolling(window=di_lookback).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)

    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.ewm(alpha=1/adx_smoothing, adjust=False).mean()

    return plus_di, minus_di, adx

# Cálculo dos indicadores
emaShort = talib.EMA(close_price, emaShortLength)
emaLong = talib.EMA(close_price, emaLongLength)
rsi = talib.RSI(close_price, timeperiod=rsiLength)
plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
adx = adx.fillna(0).astype(int)
macdLine, signalLine, macdHist = macd_func(close_price, macdShort, macdLong, macdSignal)
upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)

# Função para detectar crossover (cruzamento ascendente)
def crossover(series1, series2):
    return (series1.shift(1) <= series2.shift(1)) & (series1 > series2)

# Função para detectar crossunder (cruzamento descendente)
def crossunder(series1, series2):
    return (series1.shift(1) >= series2.shift(1)) & (series1 < series2)

# Condição de mercado em tendência (baseada no ADX)
trendingMarket = adx >= adxThreshold

# Condições de lateralização com Bollinger Bands
bandWidth = (upperBand - lowerBand) / middleBand
isLateral = bandWidth < lateralThreshold

# Saldo inicial
saldo = 1_000_000  # Saldo inicial de 1.000.000
quantidade = 0  # Quantidade de BTC comprada/vendida na transação
position_open = False  # Indica se estamos em uma transação
current_position = None  # 'long' ou 'short'
entry_price = None  # Preço de entrada da posição
orders = []
trade_count = 0  # Contador de trades

# Condição Long
longCondition = (crossover(emaShort, emaLong)) & (rsi < 60) & (macdHist > 0.5) & trendingMarket

# Condição Short
shortCondition = (crossunder(emaShort, emaLong)) & (rsi > 40) & (macdHist < -0.5) & trendingMarket

commission = 0.00032  # 0,032%

# Definir período de negociação
start_date = pd.to_datetime('2024-02-01 00:00:00')  # Data inicial
end_date = pd.to_datetime('2024-09-01 23:59:59')    # Data final

# Loop para verificar e executar as ordens
for i in range(1, len(df)):
    current_time = timestamp.iloc[i]

    # Verificar se a data atual está dentro do período de negociação
    if current_time < start_date:
        continue  # Pula para a próxima iteração se antes do período de negociação
    if current_time > end_date:
        # Fechar qualquer posição aberta no final do período
        if position_open:
            # Fechar posição na abertura deste candle
            exit_price = open_price.iloc[i]
            if current_position == 'long':
                saldo = quantidade * exit_price
                orders.append(f"Sair de transação (long) em {current_time} com preço {exit_price:.2f} (Fechamento do período), saldo atualizado: {saldo:.2f}")
            elif current_position == 'short':
                saldo += quantidade * (entry_price - exit_price)
                orders.append(f"Sair de transação (short) em {current_time} com preço {exit_price:.2f} (Fechamento do período), saldo atualizado: {saldo:.2f}")
            position_open = False
        break  # Sai do loop se passamos do período de negociação

    adjusted_timestamp = timestamp.iloc[i]

    print(f"Vela: {adjusted_timestamp}")
    print(f"EMA Curta: {emaShort[i]}, EMA Longa: {emaLong[i]}")
    print(f"RSI: {rsi[i]}")
    print(f"MACD Line: {macdLine[i]}, Signal Line: {signalLine[i]}, MACD Hist: {macdHist[i]}")
    print(f"ADX: {adx[i]}")
    print(f"Bollinger Upper: {upperBand[i]}, Bollinger Lower: {lowerBand[i]}")
    print("-" * 50)
    
    # Determinar a condição de lateralização da vela anterior
    lateral_prev = isLateral.iloc[i-1]

    # Estratégia de Mean Reversion para mercado lateral
    if lateral_prev:
        if not position_open:
            # Condição para entrar em Long
            if (close_price.iloc[i-1] < lowerBand.iloc[i-1]) and crossover(close_price, lowerBand).iloc[i-1] and longCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]  # Executa no candle atual
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (long lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                position_open = True
                current_position = 'long'
                trade_count += 1
                print(f"Trade LONG lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            # Condição para entrar em Short
            elif (close_price.iloc[i-1] > upperBand.iloc[i-1]) and crossunder(close_price, upperBand).iloc[i-1] and shortCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (short lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                position_open = True
                current_position = 'short'
                trade_count += 1
                print(f"Trade SHORT lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
        elif position_open:
            if current_position == 'long':
                # Condição para inverter para Short
                if (close_price.iloc[i] > upperBand.iloc[i]) and crossover(close_price, upperBand).iloc[i] and shortCondition.iloc[i-1]:
                    saldo = quantidade * close_price.iloc[i]
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Short), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]  # Executa no candle atual
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif current_position == 'short':
                # Condição para inverter para Long
                if (close_price.iloc[i] < lowerBand.iloc[i]) and crossover(close_price, lowerBand).iloc[i] and longCondition.iloc[i-1]:
                    saldo += quantidade * (entry_price - close_price.iloc[i])
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Long), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")

            # Gerenciamento de posições abertas com base nos parâmetros laterais da vela anterior
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                if low_price.iloc[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss LONG atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                elif high_price.iloc[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit LONG atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short  # Corrigido para takeProfitShort
                if high_price.iloc[i] >= stopLossShort:
                    saldo -= quantidade * (stopLossShort - entry_price)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {stopLossShort:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss SHORT atingido em {adjusted_timestamp} a {stopLossShort:.2f}")
                elif low_price.iloc[i] <= takeProfitShort:
                    saldo += quantidade * (entry_price - takeProfitShort)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit SHORT atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")

    # Estratégia para mercado não lateral
    if not lateral_prev:
        if not position_open:
            # Condição para entrar em Long
            if longCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (long normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                position_open = True
                current_position = 'long'
                trade_count += 1
                print(f"Trade LONG normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            # Condição para entrar em Short
            elif shortCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (short normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                position_open = True
                current_position = 'short'
                trade_count += 1
                print(f"Trade SHORT normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
        elif position_open:
            if current_position == 'long':
                # Condição para inverter para Short
                if shortCondition.iloc[i-1]:
                    saldo = quantidade * open_price.iloc[i]
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Short), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif current_position == 'short':
                # Condição para inverter para Long
                if longCondition.iloc[i-1]:
                    saldo += quantidade * (entry_price - open_price.iloc[i])
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Long), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")

            # Gerenciamento de posições abertas com base nos parâmetros não laterais
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                if low_price.iloc[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss LONG normal atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                elif high_price.iloc[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit LONG normal atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short  # Corrigido para takeProfitShort
                if high_price.iloc[i] >= stopLossShort:
                    saldo -= quantidade * (stopLossShort - entry_price)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss SHORT normal atingido em {adjusted_timestamp} a {stopLossShort:.2f}")
                elif low_price.iloc[i] <= takeProfitShort:
                    saldo += quantidade * (entry_price - takeProfitShort)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit SHORT normal atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")

# Exibir as ordens geradas
for order in orders:
    print(order)

# Exibir o número total de trades
print(f"Total de trades: {trade_count}")
# Out:
# Vela: 2024-02-01 00:00:00
# EMA Curta: 42786.82392074956, EMA Longa: 42890.67607083344
# RSI: 42.91480817623315
# MACD Line: -95.08829080405121, Signal Line: -31.11292244716027, MACD Hist: -63.97536835689094
# ADX: 22
# Bollinger Upper: 43635.91743805733, Bollinger Lower: 42183.33970479966
# --------------------------------------------------
# Vela: 2024-02-01 01:00:00
# EMA Curta: 42649.03660062463, EMA Longa: 42857.44121116082
# RSI: 37.56965292706714
# MACD Line: -149.21424935218238, Signal Line: -50.796476931330616, MACD Hist: -98.41777242085176
# ADX: 24
# Bollinger Upper: 43693.01597501105, Bollinger Lower: 42031.19831070308
# --------------------------------------------------
# Vela: 2024-02-01 02:00:00
# EMA Curta: 42565.197167187194, EMA Longa: 42832.0325964765
# RSI: 40.54333627888175
# MACD Line: -180.18770623044838, Signal Line: -72.36168181451691, MACD Hist: -107.82602441593147
# ADX: 25
# Bollinger Upper: 43712.288207832185, Bollinger Lower: 41946.854649310524
# --------------------------------------------------
# Vela: 2024-02-01 03:00:00
# EMA Curta: 42471.49763932266, EMA Longa: 42802.42428945948
# RSI: 39.04461740199156
# MACD Line: -214.15732453908277, Signal Line: -95.9942889352779, MACD Hist: -118.16303560380487
# ADX: 26
# Bollinger Upper: 43728.691263001674, Bollinger Lower: 41819.951594141035
# --------------------------------------------------
# Vela: 2024-02-01 04:00:00
# EMA Curta: 42403.69803276888, EMA Longa: 42776.076993407354
# RSI: 40.04638863186841
# MACD Line: -236.46577875414368, Signal Line: -119.40620390508886, MACD Hist: -117.05957484905483
# ADX: 28
# Bollinger Upper: 43720.47409775727, Bollinger Lower: 41715.98304509972
# --------------------------------------------------
# Vela: 2024-02-01 05:00:00
# EMA Curta: 42361.18169397407, EMA Longa: 42753.667100785664
# RSI: 41.41790678988029
# MACD Line: -247.4879979190373, Signal Line: -140.75316957408026, MACD Hist: -106.73482834495704
# ADX: 29
# Bollinger Upper: 43620.574317997016, Bollinger Lower: 41647.11139628854
# --------------------------------------------------
# Vela: 2024-02-01 06:00:00
# EMA Curta: 42330.13474497839, EMA Longa: 42732.99684718618
# RSI: 41.854722085927904
# MACD Line: -253.02891445922432, Signal Line: -159.46579372160426, MACD Hist: -93.56312073762007
# EMA Curta: 58287.572612898686, EMA Longa: 58697.24202299424
# RSI: 46.40723488823863
# MACD Line: -181.72900352359284, Signal Line: -232.07970830930438, MACD Hist: 50.35070478571154
# ADX: 36
# Bollinger Upper: 58509.17246376002, Bollinger Lower: 57858.3418219541
# --------------------------------------------------
# Vela: 2024-09-01 22:00:00
# EMA Curta: 58118.69384408224, EMA Longa: 58646.422665030164
# RSI: 35.8311640734011
# MACD Line: -241.04402180488978, Signal Line: -233.5737605585686, MACD Hist: -7.470261246321172
# ADX: 37
# Bollinger Upper: 58629.473658955474, Bollinger Lower: 57603.26919818723
# --------------------------------------------------
# Vela: 2024-09-01 23:00:00
# EMA Curta: 57976.59487006853, EMA Longa: 58597.12542699337
# RSI: 35.76417488671486
# MACD Line: -288.8135974454999, Signal Line: -242.78040003972382, MACD Hist: -46.03319740577609
# ADX: 38
# Bollinger Upper: 58682.70234306834, Bollinger Lower: 57419.05479978864
# --------------------------------------------------
# Entrar em transação (long normal) em 2024-02-01 21:00:00 com preço 42985.90, Stop Loss: 39547.03, Take Profit: 56741.39
# Sair de transação (long) em 2024-02-04 06:00:00 com preço 42870.10 (Inversão para Short), saldo atualizado: 996986.96
# Entrar em transação (short normal) em 2024-02-04 06:00:00 com preço 42870.10, Stop Loss: 48014.51, Take Profit: 33009.98
# Sair de transação (short) em 2024-02-05 11:00:00 com preço 43128.50 (Inversão para Long), saldo atualizado: 990341.56
# Entrar em transação (long normal) em 2024-02-05 11:00:00 com preço 43128.50, Stop Loss: 39678.22, Take Profit: 56929.62
# Sair de transação (long) em 2024-02-05 19:00:00 com preço 42718.20 (Inversão para Short), saldo atualizado: 980606.12
# Entrar em transação (short normal) em 2024-02-05 19:00:00 com preço 42718.20, Stop Loss: 47844.38, Take Profit: 32893.01
# Sair de transação (short) em 2024-02-09 18:00:00 com preço 47632.40 (Stoploss), saldo atualizado: 862619.59
# Entrar em transação (long normal) em 2024-02-18 10:00:00 com preço 52007.00, Stop Loss: 47846.44, Take Profit: 68649.24
# Sair de transação (long) em 2024-02-20 01:00:00 com preço 51663.50 (Inversão para Short), saldo atualizado: 856647.88
# Entrar em transação (short normal) em 2024-02-20 01:00:00 com preço 51663.50, Stop Loss: 57863.12, Take Profit: 39780.90
# Sair de transação (short) em 2024-02-20 12:00:00 com preço 52323.00 (Inversão para Long), saldo atualizado: 845167.84
# Entrar em transação (long normal) em 2024-02-20 12:00:00 com preço 52323.00, Stop Loss: 48137.16, Take Profit: 69066.36
# Sair de transação (long) em 2024-02-20 18:00:00 com preço 51351.80 (Inversão para Short), saldo atualizado: 829214.72
# Entrar em transação (short normal) em 2024-02-20 18:00:00 com preço 51351.80, Stop Loss: 57514.02, Take Profit: 39540.89
# Sair de transação (short) em 2024-02-20 23:00:00 com preço 52188.00 (Inversão para Long), saldo atualizado: 815185.70
# Entrar em transação (long normal) em 2024-02-20 23:00:00 com preço 52188.00, Stop Loss: 48012.96, Take Profit: 68888.16
# Sair de transação (long) em 2024-03-05 14:00:00 com preço 68888.16 (Take Profit), saldo atualizado: 1076045.12
# Entrar em transação (long normal) em 2024-03-06 09:00:00 com preço 67034.40, Stop Loss: 61671.65, Take Profit: 88485.41
# Sair de transação (long) em 2024-03-14 17:00:00 com preço 71415.20 (Inversão para Short), saldo atualizado: 1145999.47
# Entrar em transação (short normal) em 2024-03-14 17:00:00 com preço 71415.20, Stop Loss: 79985.02, Take Profit: 54989.70
# Sair de transação (short) em 2024-03-17 23:00:00 com preço 68266.50 (Inversão para Long), saldo atualizado: 1195777.16
# Entrar em transação (long normal) em 2024-03-17 23:00:00 com preço 68266.50, Stop Loss: 62805.18, Take Profit: 90111.78
# Sair de transação (long) em 2024-03-18 15:00:00 com preço 67034.00 (Inversão para Short), saldo atualizado: 1173812.57
# Entrar em transação (short normal) em 2024-03-18 15:00:00 com preço 67034.00, Stop Loss: 75078.08, Take Profit: 51616.18
# Sair de transação (short) em 2024-03-23 17:00:00 com preço 65667.40 (Inversão para Long), saldo atualizado: 1196983.92
# Entrar em transação (long normal) em 2024-03-23 17:00:00 com preço 65667.40, Stop Loss: 60414.01, Take Profit: 86680.97
# Sair de transação (long) em 2024-03-29 16:00:00 com preço 69236.40 (Inversão para Short), saldo atualizado: 1261635.72
# Entrar em transação (short normal) em 2024-03-29 16:00:00 com preço 69236.40, Stop Loss: 77544.77, Take Profit: 53312.03
# Sair de transação (short) em 2024-04-10 23:00:00 com preço 70568.50 (Inversão para Long), saldo atualizado: 1236562.45
# Entrar em transação (long normal) em 2024-04-10 23:00:00 com preço 70568.50, Stop Loss: 64923.02, Take Profit: 93150.42
# Sair de transação (long) em 2024-04-12 16:00:00 com preço 69375.90 (Inversão para Short), saldo atualizado: 1215275.67
# Entrar em transação (short normal) em 2024-04-12 16:00:00 com preço 69375.90, Stop Loss: 77701.01, Take Profit: 53419.44
# Sair de transação (short) em 2024-04-15 10:00:00 com preço 66554.90 (Inversão para Long), saldo atualizado: 1263898.39
# Entrar em transação (long normal) em 2024-04-15 10:00:00 com preço 66554.90, Stop Loss: 61230.51, Take Profit: 87852.47
# Sair de transação (long) em 2024-04-17 14:00:00 com preço 61230.51 (Stoploss), saldo atualizado: 1162786.52
# Entrar em transação (long normal) em 2024-04-18 17:00:00 com preço 63488.00, Stop Loss: 58408.96, Take Profit: 83804.16
# Sair de transação (long) em 2024-04-19 03:00:00 com preço 61340.00 (Inversão para Short), saldo atualizado: 1123086.27
# Entrar em transação (short normal) em 2024-04-19 03:00:00 com preço 61340.00, Stop Loss: 68700.80, Take Profit: 47231.80
# Sair de transação (short) em 2024-04-19 07:00:00 com preço 64600.10 (Inversão para Long), saldo atualizado: 1062696.89
# Entrar em transação (long normal) em 2024-04-19 07:00:00 com preço 64600.10, Stop Loss: 59432.09, Take Profit: 85272.13
# Sair de transação (long) em 2024-04-28 23:00:00 com preço 63118.30 (Inversão para Short), saldo atualizado: 1037988.44
# Entrar em transação (short normal) em 2024-04-28 23:00:00 com preço 63118.30, Stop Loss: 70692.50, Take Profit: 48601.09
# Sair de transação (short) em 2024-05-03 03:00:00 com preço 59518.30 (Inversão para Long), saldo atualizado: 1096507.74
# Entrar em transação (long normal) em 2024-05-03 03:00:00 com preço 59518.30, Stop Loss: 54756.84, Take Profit: 78564.16
# Sair de transação (long) em 2024-05-07 00:00:00 com preço 63149.30 (Inversão para Short), saldo atualizado: 1163029.50
# Entrar em transação (short normal) em 2024-05-07 00:00:00 com preço 63149.30, Stop Loss: 70727.22, Take Profit: 48624.96
# Sair de transação (short) em 2024-05-11 11:00:00 com preço 61444.27 (Take Profit Lateral), saldo atualizado: 1194059.12
# Entrar em transação (long normal) em 2024-05-12 20:00:00 com preço 61379.90, Stop Loss: 56469.51, Take Profit: 81021.47
# Sair de transação (long) em 2024-05-14 13:00:00 com preço 61550.10 (Inversão para Short), saldo atualizado: 1196986.96
# Entrar em transação (short normal) em 2024-05-14 13:00:00 com preço 61550.10, Stop Loss: 68936.11, Take Profit: 47393.58
# Sair de transação (short) em 2024-05-15 09:00:00 com preço 62120.30 (Inversão para Long), saldo atualizado: 1185135.68
# Entrar em transação (long normal) em 2024-05-15 09:00:00 com preço 62120.30, Stop Loss: 57150.68, Take Profit: 81998.80
# Sair de transação (long) em 2024-05-26 01:00:00 com preço 68953.53 (Take Profit Lateral), saldo atualizado: 1315500.60
# Entrar em transação (short normal) em 2024-05-26 22:00:00 com preço 68536.10, Stop Loss: 76760.43, Take Profit: 52772.80
# Sair de transação (short) em 2024-05-30 16:00:00 com preço 68558.90 (Inversão para Long), saldo atualizado: 1314221.33
# Entrar em transação (long normal) em 2024-05-30 16:00:00 com preço 68558.90, Stop Loss: 63074.19, Take Profit: 90497.75
# Sair de transação (long) em 2024-06-02 22:00:00 com preço 67815.20 (Inversão para Short), saldo atualizado: 1299549.18
# Entrar em transação (short normal) em 2024-06-02 22:00:00 com preço 67815.20, Stop Loss: 75953.02, Take Profit: 52217.70
# Sair de transação (short) em 2024-06-03 02:00:00 com preço 68498.20 (Inversão para Long), saldo atualizado: 1285633.40
# Entrar em transação (long normal) em 2024-06-03 02:00:00 com preço 68498.20, Stop Loss: 63018.34, Take Profit: 90417.62
# Sair de transação (long) em 2024-06-10 23:00:00 com preço 69492.10 (Inversão para Short), saldo atualizado: 1303870.40
# Entrar em transação (short normal) em 2024-06-10 23:00:00 com preço 69492.10, Stop Loss: 77831.15, Take Profit: 53508.92
# Sair de transação (short) em 2024-06-12 09:00:00 com preço 67615.81 (Take Profit Lateral), saldo atualizado: 1338657.66
# Entrar em transação (short normal) em 2024-06-13 03:00:00 com preço 67708.00, Stop Loss: 75832.96, Take Profit: 52135.16
# Sair de transação (short) em 2024-06-15 20:00:00 com preço 65879.88 (Take Profit Lateral), saldo atualizado: 1374373.05
# Entrar em transação (long normal) em 2024-06-16 15:00:00 com preço 66491.20, Stop Loss: 61171.90, Take Profit: 87768.38
# Sair de transação (long) em 2024-06-17 04:00:00 com preço 66188.90 (Inversão para Short), saldo atualizado: 1367686.71
# Entrar em transação (short normal) em 2024-06-17 04:00:00 com preço 66188.90, Stop Loss: 74131.57, Take Profit: 50965.45
# Sair de transação (short) em 2024-06-17 23:00:00 com preço 66631.60 (Inversão para Long), saldo atualizado: 1357666.78
# Entrar em transação (long normal) em 2024-06-17 23:00:00 com preço 66631.60, Stop Loss: 61301.07, Take Profit: 87953.71
# Sair de transação (long) em 2024-06-20 17:00:00 com preço 64863.40 (Inversão para Short), saldo atualizado: 1321215.50
# Entrar em transação (short normal) em 2024-06-20 17:00:00 com preço 64863.40, Stop Loss: 72647.01, Take Profit: 49944.82
# Sair de transação (short) em 2024-06-27 17:00:00 com preço 61687.30 (Inversão para Long), saldo atualizado: 1385043.97
# Entrar em transação (long normal) em 2024-06-27 17:00:00 com preço 61687.30, Stop Loss: 56752.32, Take Profit: 81427.24
# Sair de transação (long) em 2024-06-28 15:00:00 com preço 60881.30 (Inversão para Short), saldo atualizado: 1366509.71
# Entrar em transação (short normal) em 2024-06-28 15:00:00 com preço 60881.30, Stop Loss: 68187.06, Take Profit: 46878.60
# Sair de transação (short) em 2024-07-09 05:00:00 com preço 57264.70 (Inversão para Long), saldo atualizado: 1446785.61
# Entrar em transação (long normal) em 2024-07-09 05:00:00 com preço 57264.70, Stop Loss: 52683.52, Take Profit: 75589.40
# Sair de transação (long) em 2024-07-18 18:00:00 com preço 63534.70 (Inversão para Short), saldo atualizado: 1604682.73
# Entrar em transação (short normal) em 2024-07-18 18:00:00 com preço 63534.70, Stop Loss: 71158.86, Take Profit: 48921.72
# Sair de transação (short) em 2024-07-19 14:00:00 com preço 65099.10 (Inversão para Long), saldo atualizado: 1564156.81
# Entrar em transação (long normal) em 2024-07-19 14:00:00 com preço 65099.10, Stop Loss: 59891.17, Take Profit: 85930.81
# Sair de transação (long) em 2024-07-23 07:00:00 com preço 66503.00 (Inversão para Short), saldo atualizado: 1597377.44
# Entrar em transação (short normal) em 2024-07-23 07:00:00 com preço 66503.00, Stop Loss: 74483.36, Take Profit: 51207.31
# Sair de transação (short) em 2024-07-26 02:00:00 com preço 66400.00 (Inversão para Long), saldo atualizado: 1598828.51
# Entrar em transação (long normal) em 2024-07-26 02:00:00 com preço 66400.00, Stop Loss: 61088.00, Take Profit: 87648.00
# Sair de transação (long) em 2024-07-29 19:00:00 com preço 67399.90 (Inversão para Short), saldo atualizado: 1622385.52
# Entrar em transação (short normal) em 2024-07-29 19:00:00 com preço 67399.90, Stop Loss: 75487.89, Take Profit: 51897.92
# Sair de transação (short) em 2024-08-05 06:00:00 com preço 51897.92 (Take Profit), saldo atualizado: 1995015.02
# Entrar em transação (long normal) em 2024-08-06 21:00:00 com preço 56515.30, Stop Loss: 51994.08, Take Profit: 74600.20
# Sair de transação (long) em 2024-08-07 19:00:00 com preço 54784.30 (Inversão para Short), saldo atualizado: 1933291.11
# Entrar em transação (short normal) em 2024-08-07 19:00:00 com preço 54784.30, Stop Loss: 61358.42, Take Profit: 42183.91
# Sair de transação (short) em 2024-08-08 05:00:00 com preço 56746.10 (Inversão para Long), saldo atualizado: 1862845.91
# Entrar em transação (long normal) em 2024-08-08 05:00:00 com preço 56746.10, Stop Loss: 52206.41, Take Profit: 74904.85
# Sair de transação (long) em 2024-08-14 18:00:00 com preço 59131.20 (Inversão para Short), saldo atualizado: 1940522.17
# Entrar em transação (short normal) em 2024-08-14 18:00:00 com preço 59131.20, Stop Loss: 66226.94, Take Profit: 45531.02
# Sair de transação (short) em 2024-08-16 20:00:00 com preço 59653.90 (Inversão para Long), saldo atualizado: 1922132.36
# Entrar em transação (long normal) em 2024-08-16 20:00:00 com preço 59653.90, Stop Loss: 54881.59, Take Profit: 78743.15
# Sair de transação (long) em 2024-08-20 22:00:00 com preço 59257.70 (Inversão para Short), saldo atualizado: 1908755.24
# Entrar em transação (short normal) em 2024-08-20 22:00:00 com preço 59257.70, Stop Loss: 66368.62, Take Profit: 45628.43
# Sair de transação (short) em 2024-08-21 14:00:00 com preço 59898.00 (Inversão para Long), saldo atualizado: 1886915.67
# Entrar em transação (long normal) em 2024-08-21 14:00:00 com preço 59898.00, Stop Loss: 55106.16, Take Profit: 79065.36
# Sair de transação (long) em 2024-08-26 18:00:00 com preço 63361.60 (Inversão para Short), saldo atualizado: 1995387.78
# Entrar em transação (short normal) em 2024-08-26 18:00:00 com preço 63361.60, Stop Loss: 70964.99, Take Profit: 48788.43
# Sair de transação (short) em 2024-09-01 01:00:00 com preço 61650.84 (Take Profit Lateral), saldo atualizado: 2048624.73
# Total de trades: 53

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib

# Carregar o CSV com nome atualizado
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')

# Converter o timestamp para datetime (descomente se necessário)
if 'time' in df.columns:
    try:
        df['time'] = pd.to_datetime(df['time'], unit='s')
    except:
        pass  # Se o timestamp já estiver em formato datetime

# Atribuir os dados às variáveis
timestamp = df['time']
open_price = df['open']
high_price = df['high']
low_price = df['low']
close_price = df['close']

# Parâmetros configuráveis
emaShortLength = 11  # Período da EMA Curta
emaLongLength = 55  # Período da EMA Longa
rsiLength = 22  # Período do RSI
macdShort = 15  # Período Curto MACD
macdLong = 34  # Período Longo MACD
macdSignal = 11  # Período de Sinal MACD
adxLength = 16  # Período ADX (igual ao DI Length)
adxSmoothing = 13  # ADX Smoothing
adxThreshold = 12  # Nível de ADX para indicar tendência
bbLength = 14  # Período do Bollinger Bands
bbMultiplier = 1.7  # Multiplicador do Bollinger Bands
lateralThreshold = 0.005  # Limite de Lateralização
stopgain_lateral_long = 1.11
stoploss_lateral_long = 0.973
stopgain_lateral_short = 0.973
stoploss_lateral_short = 1.09
stopgain_normal_long = 1.32
stoploss_normal_long = 0.92
stopgain_normal_short = 0.77
stoploss_normal_short = 1.12

# Funções para cálculo manual do MACD
def macd_func(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    tr = []
    previous_close = close.iloc[0]
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        current_plus_dm = high.iloc[i] - high.iloc[i-1]
        current_minus_dm = low.iloc[i-1] - low.iloc[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)

        tr1 = high.iloc[i] - low.iloc[i]
        tr2 = abs(high.iloc[i] - previous_close)
        tr3 = abs(low.iloc[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)

        previous_close = close.iloc[i]

    tr.insert(0, np.nan)
    plus_dm.insert(0, np.nan)
    minus_dm.insert(0, np.nan)

    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)

    atr = tr.rolling(window=di_lookback).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)

    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.ewm(alpha=1/adx_smoothing, adjust=False).mean()

    return plus_di, minus_di, adx

# Cálculo dos indicadores
emaShort = talib.EMA(close_price, emaShortLength)
emaLong = talib.EMA(close_price, emaLongLength)
rsi = talib.RSI(close_price, timeperiod=rsiLength)
plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
adx = adx.fillna(0).astype(int)
macdLine, signalLine, macdHist = macd_func(close_price, macdShort, macdLong, macdSignal)
upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)

# Função para detectar crossover (cruzamento ascendente)
def crossover(series1, series2):
    return (series1.shift(1) <= series2.shift(1)) & (series1 > series2)

# Função para detectar crossunder (cruzamento descendente)
def crossunder(series1, series2):
    return (series1.shift(1) >= series2.shift(1)) & (series1 < series2)

# Condição de mercado em tendência (baseada no ADX)
trendingMarket = adx >= adxThreshold

# Condições de lateralização com Bollinger Bands
bandWidth = (upperBand - lowerBand) / middleBand
isLateral = bandWidth < lateralThreshold

# Determinar eventos de cruzamento
crossover_events = crossover(emaShort, emaLong)
crossunder_events = crossunder(emaShort, emaLong)

# Inicializar a Série ema_cross_event
ema_cross_event = pd.Series(index=df.index, dtype='object')

ema_cross_event[crossover_events] = 'crossover'
ema_cross_event[crossunder_events] = 'crossunder'

# Preencher adiante para obter o último evento de cruzamento em cada momento
last_cross_event = ema_cross_event.fillna(method='ffill')

# Detectar mudanças na condição de mercado
isLateral_change = isLateral != isLateral.shift(1)

# Saldo inicial
saldo = 1_000_000  # Saldo inicial de 1.000.000
quantidade = 0  # Quantidade de BTC comprada/vendida na transação
position_open = False  # Indica se estamos em uma transação
current_position = None  # 'long' ou 'short'
entry_price = None  # Preço de entrada da posição
orders = []
trade_count = 0  # Contador de trades

commission = 0.00032  # 0,032%

# Loop para verificar e executar as ordens
for i in range(1, len(df)):
    adjusted_timestamp = timestamp.iloc[i]

    # Determinar a condição da vela anterior e atual
    lateral_prev = isLateral.iloc[i-1]
    lateral_curr = isLateral.iloc[i]

    # Verificar se a condição de mercado mudou
    if isLateral_change.iloc[i]:
        # A condição de mercado mudou
        last_event = last_cross_event.iloc[i-1]
        if not position_open:
            if last_event == 'crossover' and rsi.iloc[i-1] < 60 and macdHist.iloc[i-1] > 0.5:
                # Entrar em posição Long
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                if lateral_curr:
                    # Mercado lateral
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                else:
                    # Mercado em tendência
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (long) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                position_open = True
                current_position = 'long'
                trade_count += 1
                print(f"Trade LONG executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif last_event == 'crossunder' and rsi.iloc[i-1] > 40 and macdHist.iloc[i-1] < -0.5:
                # Entrar em posição Short
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                if lateral_curr:
                    # Mercado lateral
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                else:
                    # Mercado em tendência
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (short) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                position_open = True
                current_position = 'short'
                trade_count += 1
                print(f"Trade SHORT executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
        elif position_open:
            if current_position == 'long':
                if last_event == 'crossunder' and rsi.iloc[i-1] > 40 and macdHist.iloc[i-1] < -0.5:
                    # Reverter para posição Short
                    saldo = quantidade * open_price.iloc[i]
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Short), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    if lateral_curr:
                        stopLossShort = entry_price * stoploss_lateral_short
                        takeProfitShort = entry_price * stopgain_lateral_short
                    else:
                        stopLossShort = entry_price * stoploss_normal_short
                        takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif current_position == 'short':
                if last_event == 'crossover' and rsi.iloc[i-1] < 60 and macdHist.iloc[i-1] > 0.5:
                    # Reverter para posição Long
                    saldo += quantidade * (entry_price - open_price.iloc[i])
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Long), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    if lateral_curr:
                        stopLossLong = entry_price * stoploss_lateral_long
                        takeProfitLong = entry_price * stopgain_lateral_long
                    else:
                        stopLossLong = entry_price * stoploss_normal_long
                        takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
    else:
        # Estratégia padrão baseada na condição atual de mercado
        # Estratégia de Mean Reversion para mercado lateral
        if lateral_prev:
            if not position_open:
                # Condição para entrar em Long
                if (close_price.iloc[i-1] < lowerBand.iloc[i-1]) and crossover(close_price, lowerBand).iloc[i-1]:
                    entry_price = open_price.iloc[i]  # Executa no candle atual
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
                # Condição para entrar em Short
                elif (close_price.iloc[i-1] > upperBand.iloc[i-1]) and crossunder(close_price, upperBand).iloc[i-1]:
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif position_open:
                # Gerenciamento de posições abertas com base nos parâmetros laterais
                if current_position == 'long':
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    if low_price.iloc[i] <= stopLossLong:
                        saldo = quantidade * stopLossLong
                        orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Stop Loss LONG atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                    elif high_price.iloc[i] >= takeProfitLong:
                        saldo = quantidade * takeProfitLong
                        orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Take Profit LONG atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
                elif current_position == 'short':
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    if high_price.iloc[i] >= stopLossShort:
                        saldo -= quantidade * (stopLossShort - entry_price)
                        orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {stopLossShort:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Stop Loss SHORT atingido em {adjusted_timestamp} a {stopLossShort:.2f}")
                    elif low_price.iloc[i] <= takeProfitShort:
                        saldo += quantidade * (entry_price - takeProfitShort)
                        orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Take Profit SHORT atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")
        else:
            # Estratégia para mercado em tendência
            if not position_open:
                # Condição para entrar em Long
                if longCondition.iloc[i-1]:
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
                # Condição para entrar em Short
                elif shortCondition.iloc[i-1]:
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif position_open:
                # Gerenciamento de posições abertas com base nos parâmetros não laterais
                if current_position == 'long':
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    if low_price.iloc[i] <= stopLossLong:
                        saldo = quantidade * stopLossLong
                        orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Stop Loss LONG normal atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                    elif high_price.iloc[i] >= takeProfitLong:
                        saldo = quantidade * takeProfitLong
                        orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Take Profit LONG normal atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
                elif current_position == 'short':
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    if high_price.iloc[i] >= stopLossShort:
                        saldo -= quantidade * (stopLossShort - entry_price)
                        orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {stopLossShort:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Stop Loss SHORT normal atingido em {adjusted_timestamp} a {stopLossShort:.2f}")
                    elif low_price.iloc[i] <= takeProfitShort:
                        saldo += quantidade * (entry_price - takeProfitShort)
                        orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                        position_open = False
                        print(f"Take Profit SHORT normal atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")

# Exibir as ordens geradas
for order in orders:
    print(order)

# Exibir o número total de trades
print(f"Total de trades: {trade_count}")
# Out:
# C:\Users\erik\AppData\Local\Temp\ipykernel_13876\4147341913.py:127: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   last_cross_event = ema_cross_event.fillna(method='ffill')
# Trade SHORT normal executado em 2020-04-01 07:00:00 a 6289.50
# Stop Loss SHORT normal atingido em 2020-04-02 17:00:00 a 7044.24
# Trade SHORT normal executado em 2020-04-10 04:00:00 a 7175.50
# Stop Loss SHORT normal atingido em 2020-04-29 10:00:00 a 8036.56
# Trade SHORT normal executado em 2020-05-04 01:00:00 a 8806.00
# Stop Loss SHORT normal atingido em 2020-05-07 17:00:00 a 9862.72
# Trade SHORT normal executado em 2020-05-09 23:00:00 a 9604.50
# Trade LONG executado em 2020-06-01 14:00:00 a 9550.00
# Trade SHORT executado em 2020-06-03 06:00:00 a 9513.00
# Trade LONG executado em 2020-06-21 10:00:00 a 9366.50
# Stop Loss LONG atingido em 2020-06-27 15:00:00 a 9113.60
# Trade LONG normal executado em 2020-06-29 02:00:00 a 9144.00
# Trade SHORT executado em 2020-07-11 22:00:00 a 9217.00
# Trade LONG executado em 2020-07-12 12:00:00 a 9240.00
# Trade SHORT executado em 2020-07-15 18:00:00 a 9205.50
# Trade LONG executado em 2020-07-20 06:00:00 a 9185.50
# Take Profit LONG normal atingido em 2020-08-17 13:00:00 a 12124.86
# Trade SHORT normal executado em 2020-08-18 20:00:00 a 11990.00
# Take Profit SHORT atingido em 2020-08-22 20:00:00 a 11666.27
# Trade LONG normal executado em 2020-08-23 21:00:00 a 11675.50
# Stop Loss LONG normal atingido em 2020-09-03 12:00:00 a 10741.46
# Trade LONG normal executado em 2020-09-08 01:00:00 a 10326.00
# Trade SHORT executado em 2020-10-07 10:00:00 a 10589.00
# Trade LONG executado em 2020-10-18 03:00:00 a 11375.50
# Take Profit LONG normal atingido em 2020-11-05 15:00:00 a 15015.66
# Trade LONG normal executado em 2020-11-08 15:00:00 a 15341.00
# Take Profit LONG normal atingido em 2022-03-28 18:00:00 a 48016.32
# Trade SHORT normal executado em 2022-03-31 15:00:00 a 46700.00
# Trade LONG executado em 2022-04-05 11:00:00 a 46653.50
# Stop Loss LONG normal atingido em 2022-04-07 00:00:00 a 42921.22
# Trade LONG normal executado em 2022-04-13 18:00:00 a 41012.50
# Stop Loss LONG normal atingido em 2022-04-26 20:00:00 a 37731.50
# Trade LONG normal executado em 2022-04-28 03:00:00 a 39401.00
# Trade SHORT executado em 2022-05-03 11:00:00 a 38418.50
# Take Profit SHORT normal atingido em 2022-05-11 12:00:00 a 29582.24
# Trade LONG normal executado em 2022-05-13 07:00:00 a 30369.50
# Stop Loss LONG atingido em 2022-05-29 08:00:00 a 29549.52
# Trade LONG normal executado em 2022-05-29 11:00:00 a 29131.00
# Stop Loss LONG normal atingido em 2022-06-12 23:00:00 a 26800.52
# Trade LONG normal executado em 2022-06-19 20:00:00 a 20113.50
# Take Profit LONG atingido em 2022-08-06 14:00:00 a 22325.99
# Trade SHORT normal executado em 2022-08-07 01:00:00 a 22885.50
# Take Profit SHORT atingido em 2022-10-01 19:00:00 a 22267.59
# Trade LONG normal executado em 2022-10-03 16:00:00 a 19326.00
# Trade SHORT executado em 2022-10-15 07:00:00 a 19160.00
# Trade LONG executado em 2022-10-22 04:00:00 a 19142.00
# Take Profit LONG atingido em 2022-11-05 22:00:00 a 21247.62
# Trade LONG normal executado em 2022-11-15 05:00:00 a 16749.00
# Trade SHORT executado em 2022-12-06 12:00:00 a 16976.00
# Trade LONG executado em 2022-12-22 10:00:00 a 16840.00
# Trade SHORT executado em 2022-12-30 07:00:00 a 16551.00
# Trade LONG executado em 2023-01-02 03:00:00 a 16593.00
# Take Profit LONG normal atingido em 2023-01-20 20:00:00 a 21902.76
# Trade SHORT normal executado em 2023-01-25 01:00:00 a 22656.00
# Take Profit SHORT atingido em 2023-02-11 13:00:00 a 22044.29
# Trade SHORT normal executado em 2023-02-12 23:00:00 a 21780.60
# Stop Loss SHORT normal atingido em 2023-02-15 22:00:00 a 24394.27
# Trade SHORT normal executado em 2023-02-20 01:00:00 a 24205.60
# Take Profit SHORT atingido em 2023-03-03 16:00:00 a 23552.05
# Trade SHORT executado em 2023-03-06 04:00:00 a 22372.90
# Take Profit SHORT atingido em 2023-03-12 15:00:00 a 21768.83
# Trade SHORT normal executado em 2023-03-22 21:00:00 a 27290.80
# Stop Loss SHORT normal atingido em 2023-04-13 15:00:00 a 30565.70
# Trade SHORT executado em 2023-04-16 02:00:00 a 30236.10
# Take Profit SHORT atingido em 2023-04-29 08:00:00 a 29419.73
# Trade SHORT normal executado em 2023-04-30 03:00:00 a 29165.30
# Take Profit SHORT atingido em 2023-05-13 13:00:00 a 28377.84
# Trade SHORT normal executado em 2023-05-16 12:00:00 a 27044.10
# Trade LONG executado em 2023-05-27 03:00:00 a 26733.50
# Stop Loss LONG atingido em 2023-06-11 14:00:00 a 26011.70
# Trade SHORT normal executado em 2023-06-13 19:00:00 a 25877.10
# Trade LONG normal executado em 2024-05-03 03:00:00 a 59518.30
# Take Profit LONG atingido em 2024-05-18 06:00:00 a 66065.31
# Trade LONG normal executado em 2024-05-20 05:00:00 a 67116.70
# Trade SHORT executado em 2024-06-02 11:00:00 a 67556.20
# Trade LONG executado em 2024-06-16 23:00:00 a 66719.50
# Stop Loss LONG atingido em 2024-06-22 15:00:00 a 64918.07
# Trade SHORT executado em 2024-06-23 15:00:00 a 64163.60
# Take Profit SHORT atingido em 2024-06-29 20:00:00 a 62431.18
# Trade SHORT executado em 2024-06-30 04:00:00 a 60857.70
# Stop Loss SHORT atingido em 2024-07-20 12:00:00 a 66334.89
# Trade SHORT normal executado em 2024-07-23 07:00:00 a 66503.00
# Take Profit SHORT normal atingido em 2024-08-05 06:00:00 a 51207.31
# Trade LONG normal executado em 2024-08-06 21:00:00 a 56515.30
# Entrar em transação (short normal) em 2020-04-01 07:00:00 com preço 6289.50, Stop Loss: 7044.24, Take Profit: 4842.91
# Sair de transação (short) em 2020-04-02 17:00:00 com preço 7044.24 (Stoploss), saldo atualizado: 879680.00
# Entrar em transação (short normal) em 2020-04-10 04:00:00 com preço 7175.50, Stop Loss: 8036.56, Take Profit: 5525.14
# Sair de transação (short) em 2020-04-29 10:00:00 com preço 8036.56 (Stoploss), saldo atualizado: 773836.90
# Entrar em transação (short normal) em 2020-05-04 01:00:00 com preço 8806.00, Stop Loss: 9862.72, Take Profit: 6780.62
# Sair de transação (short) em 2020-05-07 17:00:00 com preço 9862.72 (Stoploss), saldo atualizado: 680728.85
# Entrar em transação (short normal) em 2020-05-09 23:00:00 com preço 9604.50, Stop Loss: 10757.04, Take Profit: 7395.47
# Sair de transação (short) em 2020-06-01 14:00:00 com preço 9550.00 (Inversão para Long), saldo atualizado: 684154.76
# Entrar em transação (long) em 2020-06-01 14:00:00 com preço 9550.00, Stop Loss: 9292.15, Take Profit: 10600.50
# Sair de transação (long) em 2020-06-03 06:00:00 com preço 9513.00 (Inversão para Short), saldo atualizado: 681286.02
# Entrar em transação (short) em 2020-06-03 06:00:00 com preço 9513.00, Stop Loss: 10369.17, Take Profit: 9256.15
# Sair de transação (short) em 2020-06-21 10:00:00 com preço 9366.50 (Inversão para Long), saldo atualizado: 691338.50
# Entrar em transação (long) em 2020-06-21 10:00:00 com preço 9366.50, Stop Loss: 9113.60, Take Profit: 10396.82
# Sair de transação (long) em 2020-06-27 15:00:00 com preço 9113.60 (Stoploss Lateral), saldo atualizado: 672672.36
# Entrar em transação (long normal) em 2020-06-29 02:00:00 com preço 9144.00, Stop Loss: 8412.48, Take Profit: 12070.08
# Sair de transação (long) em 2020-07-11 22:00:00 com preço 9217.00 (Inversão para Short), saldo atualizado: 677825.59
# Entrar em transação (short) em 2020-07-11 22:00:00 com preço 9217.00, Stop Loss: 10046.53, Take Profit: 8968.14
# Sair de transação (short) em 2020-07-12 12:00:00 com preço 9240.00 (Inversão para Long), saldo atualizado: 675700.95
# Entrar em transação (long) em 2020-07-12 12:00:00 com preço 9240.00, Stop Loss: 8990.52, Take Profit: 10256.40
# Sair de transação (long) em 2020-07-15 18:00:00 com preço 9205.50 (Inversão para Short), saldo atualizado: 672962.63
# Entrar em transação (short) em 2020-07-15 18:00:00 com preço 9205.50, Stop Loss: 10310.16, Take Profit: 7088.24
# Sair de transação (short) em 2020-07-20 06:00:00 com preço 9185.50 (Inversão para Long), saldo atualizado: 673993.62
# Entrar em transação (long) em 2020-07-20 06:00:00 com preço 9185.50, Stop Loss: 8937.49, Take Profit: 10195.91
# Sair de transação (long) em 2020-08-17 13:00:00 com preço 12124.86 (Take Profit), saldo atualizado: 889671.58
# Entrar em transação (short normal) em 2020-08-18 20:00:00 com preço 11990.00, Stop Loss: 13428.80, Take Profit: 9232.30
# Sair de transação (short) em 2020-08-22 20:00:00 com preço 11666.27 (Take Profit Lateral), saldo atualizado: 913408.01
# Entrar em transação (long normal) em 2020-08-23 21:00:00 com preço 11675.50, Stop Loss: 10741.46, Take Profit: 15411.66
# Sair de transação (long) em 2020-09-03 12:00:00 com preço 10741.46 (Stoploss), saldo atualizado: 840335.37
# Entrar em transação (long normal) em 2020-09-08 01:00:00 com preço 10326.00, Stop Loss: 9499.92, Take Profit: 13630.32
# Sair de transação (long) em 2020-10-07 10:00:00 com preço 10589.00 (Inversão para Short), saldo atualizado: 861462.70
# Entrar em transação (short) em 2020-10-07 10:00:00 com preço 10589.00, Stop Loss: 11542.01, Take Profit: 10303.10
# Sair de transação (short) em 2020-10-18 03:00:00 com preço 11375.50 (Inversão para Long), saldo atualizado: 796946.62
# Entrar em transação (long) em 2020-10-18 03:00:00 com preço 11375.50, Stop Loss: 11068.36, Take Profit: 12626.81
# Sair de transação (long) em 2020-11-05 15:00:00 com preço 15015.66 (Take Profit), saldo atualizado: 1051969.53
# Entrar em transação (long normal) em 2020-11-08 15:00:00 com preço 15341.00, Stop Loss: 14113.72, Take Profit: 20250.12
# Sair de transação (long) em 2020-12-16 13:00:00 com preço 20250.12 (Take Profit), saldo atualizado: 1388599.79
# Entrar em transação (long normal) em 2020-12-22 17:00:00 com preço 23363.00, Stop Loss: 21493.96, Take Profit: 30839.16
# Sair de transação (long) em 2021-01-02 12:00:00 com preço 30839.16 (Take Profit), saldo atualizado: 1832951.72
# Entrar em transação (long normal) em 2021-01-05 17:00:00 com preço 32455.00, Stop Loss: 29858.60, Take Profit: 42840.60
# Sair de transação (long) em 2021-01-22 00:00:00 com preço 29858.60 (Stoploss), saldo atualizado: 1686315.58
# Entrar em transação (long normal) em 2021-01-24 09:00:00 com preço 32659.00, Stop Loss: 30046.28, Take Profit: 43109.88
# Sair de transação (long) em 2021-01-27 14:00:00 com preço 30046.28 (Stoploss), saldo atualizado: 1551410.33
# Entrar em transação (long normal) em 2021-01-28 16:00:00 com preço 31916.00, Stop Loss: 29362.72, Take Profit: 42129.12
# Sair de transação (long) em 2021-02-08 12:00:00 com preço 42129.12 (Take Profit), saldo atualizado: 2047861.64
# Entrar em transação (short normal) em 2021-02-11 02:00:00 com preço 44249.50, Stop Loss: 49559.44, Take Profit: 34072.11
# Sair de transação (short) em 2021-02-14 12:00:00 com preço 49559.44 (Stoploss), saldo atualizado: 1801462.93
# Entrar em transação (long normal) em 2021-02-15 17:00:00 com preço 48488.00, Stop Loss: 44608.96, Take Profit: 64004.16
# Sair de transação (long) em 2021-02-26 07:00:00 com preço 44608.96 (Stoploss), saldo atualizado: 1657345.89
# Entrar em transação (long normal) em 2021-03-01 09:00:00 com preço 47014.00, Stop Loss: 43252.88, Take Profit: 62058.48
# Sair de transação (long) em 2021-04-13 08:00:00 com preço 62058.48 (Take Profit), saldo atualizado: 2187696.58
# Entrar em transação (short normal) em 2021-04-16 06:00:00 com preço 61951.50, Stop Loss: 69385.68, Take Profit: 47702.65
# Sair de transação (short) em 2021-04-23 08:00:00 com preço 47702.65 (Take Profit), saldo atualizado: 2690166.73
# Entrar em transação (short normal) em 2021-04-29 15:00:00 com preço 53768.00, Stop Loss: 60220.16, Take Profit: 41401.36
# Sair de transação (short) em 2021-05-19 01:00:00 com preço 41401.36 (Take Profit), saldo atualizado: 3308044.22
# Entrar em transação (long normal) em 2021-05-21 01:00:00 com preço 41670.50, Stop Loss: 38336.86, Take Profit: 55005.06
# Sair de transação (long) em 2021-05-21 14:00:00 com preço 38336.86 (Stoploss), saldo atualizado: 3043400.69
# Entrar em transação (short normal) em 2021-05-21 15:00:00 com preço 37790.00, Stop Loss: 42324.80, Take Profit: 29098.30
# Sair de transação (short) em 2021-06-22 13:00:00 com preço 29098.30 (Take Profit), saldo atualizado: 3742408.96
# Entrar em transação (long normal) em 2021-06-23 04:00:00 com preço 33957.50, Stop Loss: 31240.90, Take Profit: 44823.90
# Sair de transação (long) em 2021-06-26 07:00:00 com preço 31240.90 (Stoploss), saldo atualizado: 3443016.24
# Entrar em transação (long normal) em 2021-06-27 05:00:00 com preço 33105.00, Stop Loss: 30456.60, Take Profit: 43698.60
# Sair de transação (long) em 2021-07-19 14:00:00 com preço 30456.60 (Stoploss), saldo atualizado: 3167574.94
# Entrar em transação (short normal) em 2021-07-30 11:00:00 com preço 38835.00, Stop Loss: 43495.20, Take Profit: 29902.95
# Sair de transação (short) em 2021-08-07 03:00:00 com preço 43495.20 (Stoploss), saldo atualizado: 2786452.32
# Entrar em transação (short normal) em 2021-08-12 09:00:00 com preço 45267.50, Stop Loss: 50699.60, Take Profit: 34855.97
# Sair de transação (short) em 2021-09-03 10:00:00 com preço 50699.60 (Stoploss), saldo atualizado: 2451186.38
# Entrar em transação (long normal) em 2021-09-12 13:00:00 com preço 45981.50, Stop Loss: 42302.98, Take Profit: 60695.58
# Sair de transação (long) em 2021-09-21 00:00:00 com preço 42302.98 (Stoploss), saldo atualizado: 2255091.47
# Entrar em transação (long normal) em 2021-09-23 01:00:00 com preço 43180.50, Stop Loss: 39726.06, Take Profit: 56998.26
# Sair de transação (long) em 2021-10-11 07:00:00 com preço 56998.26 (Take Profit), saldo atualizado: 2976720.74
# Entrar em transação (long normal) em 2021-10-13 19:00:00 com preço 56957.00, Stop Loss: 52400.44, Take Profit: 75183.24
# Sair de transação (long) em 2021-12-03 20:00:00 com preço 52400.44 (Stoploss), saldo atualizado: 2738583.08
# Entrar em transação (long normal) em 2021-12-07 00:00:00 com preço 50422.00, Stop Loss: 46388.24, Take Profit: 66557.04
# Sair de transação (long) em 2021-12-13 19:00:00 com preço 46388.24 (Stoploss), saldo atualizado: 2519496.43
# Entrar em transação (long normal) em 2021-12-15 04:00:00 com preço 48251.50, Stop Loss: 44391.38, Take Profit: 63691.98
# Sair de transação (long) em 2022-01-05 19:00:00 com preço 44391.38 (Stoploss), saldo atualizado: 2317936.72
# Entrar em transação (long normal) em 2022-01-09 21:00:00 com preço 42423.00, Stop Loss: 39029.16, Take Profit: 55998.36
# Sair de transação (long) em 2022-01-21 03:00:00 com preço 39029.16 (Stoploss), saldo atualizado: 2132501.78
# Entrar em transação (long normal) em 2022-01-24 23:00:00 com preço 36376.00, Stop Loss: 33465.92, Take Profit: 48016.32
# Sair de transação (long) em 2022-03-28 18:00:00 com preço 48016.32 (Take Profit), saldo atualizado: 2814902.35
# Entrar em transação (short normal) em 2022-03-31 15:00:00 com preço 46700.00, Stop Loss: 52304.00, Take Profit: 35959.00
# Sair de transação (short) em 2022-04-05 11:00:00 com preço 46653.50 (Inversão para Long), saldo atualizado: 2815903.05
# Entrar em transação (long) em 2022-04-05 11:00:00 com preço 46653.50, Stop Loss: 45393.86, Take Profit: 51785.39
# Sair de transação (long) em 2022-04-07 00:00:00 com preço 42921.22 (Stoploss), saldo atualizado: 2590630.81
# Entrar em transação (long normal) em 2022-04-13 18:00:00 com preço 41012.50, Stop Loss: 37731.50, Take Profit: 54136.50
# Sair de transação (long) em 2022-04-26 20:00:00 com preço 37731.50 (Stoploss), saldo atualizado: 2383380.34
# Entrar em transação (long normal) em 2022-04-28 03:00:00 com preço 39401.00, Stop Loss: 36248.92, Take Profit: 52009.32
# Sair de transação (long) em 2022-05-03 11:00:00 com preço 38418.50 (Inversão para Short), saldo atualizado: 2323204.91
# Entrar em transação (short) em 2022-05-03 11:00:00 com preço 38418.50, Stop Loss: 41876.17, Take Profit: 37381.20
# Sair de transação (short) em 2022-05-11 12:00:00 com preço 29582.24 (Take Profit), saldo atualizado: 2856798.61
# Entrar em transação (long normal) em 2022-05-13 07:00:00 com preço 30369.50, Stop Loss: 27939.94, Take Profit: 40087.74
# Sair de transação (long) em 2022-05-29 08:00:00 com preço 29549.52 (Stoploss Lateral), saldo atualizado: 2779665.05
# Entrar em transação (long normal) em 2022-05-29 11:00:00 com preço 29131.00, Stop Loss: 26800.52, Take Profit: 38452.92
# Sair de transação (long) em 2022-06-12 23:00:00 com preço 26800.52 (Stoploss), saldo atualizado: 2557291.85
# Entrar em transação (long normal) em 2022-06-19 20:00:00 com preço 20113.50, Stop Loss: 18504.42, Take Profit: 26549.82
# Sair de transação (long) em 2022-08-06 14:00:00 com preço 22325.99 (Take Profit Lateral), saldo atualizado: 2838593.95
# Entrar em transação (short normal) em 2022-08-07 01:00:00 com preço 22885.50, Stop Loss: 25631.76, Take Profit: 17621.83
# Sair de transação (short) em 2022-10-01 19:00:00 com preço 22267.59 (Take Profit Lateral), saldo atualizado: 2914327.64
# Entrar em transação (long normal) em 2022-10-03 16:00:00 com preço 19326.00, Stop Loss: 17779.92, Take Profit: 25510.32
# Sair de transação (long) em 2022-10-15 07:00:00 com preço 19160.00 (Inversão para Short), saldo atualizado: 2888370.55
# Entrar em transação (short) em 2022-10-15 07:00:00 com preço 19160.00, Stop Loss: 20884.40, Take Profit: 18642.68
# Sair de transação (short) em 2022-10-22 04:00:00 com preço 19142.00 (Inversão para Long), saldo atualizado: 2889234.92
# Entrar em transação (long) em 2022-10-22 04:00:00 com preço 19142.00, Stop Loss: 18625.17, Take Profit: 21247.62
# Sair de transação (long) em 2022-11-05 22:00:00 com preço 21247.62 (Take Profit Lateral), saldo atualizado: 3207050.76
# Entrar em transação (long normal) em 2022-11-15 05:00:00 com preço 16749.00, Stop Loss: 15409.08, Take Profit: 22108.68
# Sair de transação (long) em 2022-12-06 12:00:00 com preço 16976.00 (Inversão para Short), saldo atualizado: 3249475.91
# Entrar em transação (short) em 2022-12-06 12:00:00 com preço 16976.00, Stop Loss: 18503.84, Take Profit: 16517.65
# Sair de transação (short) em 2022-12-22 10:00:00 com preço 16840.00 (Inversão para Long), saldo atualizado: 3273420.80
# Entrar em transação (long) em 2022-12-22 10:00:00 com preço 16840.00, Stop Loss: 16385.32, Take Profit: 18692.40
# Sair de transação (long) em 2022-12-30 07:00:00 com preço 16551.00 (Inversão para Short), saldo atualizado: 3216214.41
# Entrar em transação (short) em 2022-12-30 07:00:00 com preço 16551.00, Stop Loss: 18537.12, Take Profit: 12744.27
# Sair de transação (short) em 2023-01-02 03:00:00 com preço 16593.00 (Inversão para Long), saldo atualizado: 3205997.47
# Entrar em transação (long) em 2023-01-02 03:00:00 com preço 16593.00, Stop Loss: 15265.56, Take Profit: 21902.76
# Sair de transação (long) em 2023-01-20 20:00:00 com preço 21902.76 (Take Profit), saldo atualizado: 4231916.66
# Entrar em transação (short normal) em 2023-01-25 01:00:00 com preço 22656.00, Stop Loss: 25374.72, Take Profit: 17445.12
# Sair de transação (short) em 2023-02-11 13:00:00 com preço 22044.29 (Take Profit Lateral), saldo atualizado: 4344824.20
# Entrar em transação (short normal) em 2023-02-12 23:00:00 com preço 21780.60, Stop Loss: 24394.27, Take Profit: 16771.06
# Sair de transação (short) em 2023-02-15 22:00:00 com preço 24394.27 (Stoploss), saldo atualizado: 3822054.95
# Entrar em transação (short normal) em 2023-02-20 01:00:00 com preço 24205.60, Stop Loss: 27110.27, Take Profit: 18638.31
# Sair de transação (short) em 2023-03-03 16:00:00 com preço 23552.05 (Take Profit Lateral), saldo atualizado: 3924027.38
# Entrar em transação (short) em 2023-03-06 04:00:00 com preço 22372.90, Stop Loss: 25057.65, Take Profit: 17227.13
# Sair de transação (short) em 2023-03-12 15:00:00 com preço 21768.83 (Take Profit Lateral), saldo atualizado: 4028720.43
# Entrar em transação (short normal) em 2023-03-22 21:00:00 com preço 27290.80, Stop Loss: 30565.70, Take Profit: 21013.92
# Sair de transação (short) em 2023-04-13 15:00:00 com preço 30565.70 (Stoploss), saldo atualizado: 3543984.78
# Entrar em transação (short) em 2023-04-16 02:00:00 com preço 30236.10, Stop Loss: 32957.35, Take Profit: 29419.73
# Sair de transação (short) em 2023-04-29 08:00:00 com preço 29419.73 (Take Profit Lateral), saldo atualizado: 3638538.30
# Entrar em transação (short normal) em 2023-04-30 03:00:00 com preço 29165.30, Stop Loss: 32665.14, Take Profit: 22457.28
# Sair de transação (short) em 2023-05-13 13:00:00 com preço 28377.84 (Take Profit Lateral), saldo atualizado: 3735614.50
# Entrar em transação (short normal) em 2023-05-16 12:00:00 com preço 27044.10, Stop Loss: 30289.39, Take Profit: 20823.96
# Sair de transação (short) em 2023-05-27 03:00:00 com preço 26733.50 (Inversão para Long), saldo atualizado: 3776113.69
# Entrar em transação (long) em 2023-05-27 03:00:00 com preço 26733.50, Stop Loss: 26011.70, Take Profit: 29674.19
# Sair de transação (long) em 2023-06-11 14:00:00 com preço 26011.70 (Stoploss Lateral), saldo atualizado: 3674158.62
# Entrar em transação (short normal) em 2023-06-13 19:00:00 com preço 25877.10, Stop Loss: 28982.35, Take Profit: 19925.37
# Sair de transação (short) em 2023-06-16 09:00:00 com preço 25531.50 (Inversão para Long), saldo atualizado: 3720861.83
# Entrar em transação (long) em 2023-06-16 09:00:00 com preço 25531.50, Stop Loss: 24842.15, Take Profit: 28339.97
# Sair de transação (long) em 2023-07-01 05:00:00 com preço 30379.20 (Inversão para Short), saldo atualizado: 4425930.08
# Entrar em transação (short) em 2023-07-01 05:00:00 com preço 30379.20, Stop Loss: 33113.33, Take Profit: 29558.96
# Sair de transação (short) em 2023-07-01 23:00:00 com preço 30567.50 (Inversão para Long), saldo atualizado: 4395673.39
# Entrar em transação (long) em 2023-07-01 23:00:00 com preço 30567.50, Stop Loss: 29742.18, Take Profit: 33929.93
# Sair de transação (long) em 2023-07-05 08:00:00 com preço 30762.00 (Inversão para Short), saldo atualizado: 4422227.35
# Entrar em transação (short) em 2023-07-05 08:00:00 com preço 30762.00, Stop Loss: 33530.58, Take Profit: 29931.43
# Sair de transação (short) em 2023-07-22 04:00:00 com preço 29931.43 (Take Profit Lateral), saldo atualizado: 4540212.37
# Entrar em transação (long) em 2023-07-23 13:00:00 com preço 29906.00, Stop Loss: 29098.54, Take Profit: 33195.66
# Sair de transação (long) em 2023-07-25 03:00:00 com preço 29098.54 (Stoploss Lateral), saldo atualizado: 4417626.64
# Entrar em transação (short normal) em 2023-07-27 18:00:00 com preço 29206.30, Stop Loss: 32711.06, Take Profit: 22488.85
# Sair de transação (short) em 2023-07-29 04:00:00 com preço 29358.80 (Inversão para Long), saldo atualizado: 4391740.66
# Entrar em transação (long) em 2023-07-29 04:00:00 com preço 29358.80, Stop Loss: 28566.11, Take Profit: 32588.27
# Sair de transação (long) em 2023-08-03 06:00:00 com preço 29139.50 (Inversão para Short), saldo atualizado: 4357541.03
# Entrar em transação (short) em 2023-08-03 06:00:00 com preço 29139.50, Stop Loss: 31762.06, Take Profit: 28352.73
# Sair de transação (short) em 2023-08-07 05:00:00 com preço 29169.60 (Inversão para Long), saldo atualizado: 4350252.91
# Entrar em transação (long) em 2023-08-07 05:00:00 com preço 29169.60, Stop Loss: 28382.02, Take Profit: 32378.26
# Sair de transação (long) em 2023-08-10 13:00:00 com preço 29550.00 (Inversão para Short), saldo atualizado: 4405574.21
# Entrar em transação (short) em 2023-08-10 13:00:00 com preço 29550.00, Stop Loss: 33096.00, Take Profit: 22753.50
# Sair de transação (short) em 2023-08-20 07:00:00 com preço 28752.15 (Take Profit Lateral), saldo atualizado: 4523114.93
# Entrar em transação (short) em 2023-08-22 17:00:00 com preço 26006.90, Stop Loss: 29127.73, Take Profit: 20025.31
# Sair de transação (short) em 2023-08-27 16:00:00 com preço 26109.10 (Inversão para Long), saldo atualizado: 4502451.69
# Entrar em transação (long) em 2023-08-27 16:00:00 com preço 26109.10, Stop Loss: 24020.37, Take Profit: 34464.01
# Sair de transação (long) em 2023-09-04 12:00:00 com preço 25881.00 (Inversão para Short), saldo atualizado: 4461688.19
# Entrar em transação (short) em 2023-09-04 12:00:00 com preço 25881.00, Stop Loss: 28986.72, Take Profit: 19928.37
# Sair de transação (short) em 2023-09-30 20:00:00 com preço 27011.50 (Inversão para Long), saldo atualizado: 4264005.90
# Entrar em transação (long) em 2023-09-30 20:00:00 com preço 27011.50, Stop Loss: 24850.58, Take Profit: 35655.18
# Sair de transação (long) em 2023-10-06 06:00:00 com preço 27486.90 (Inversão para Short), saldo atualizado: 4337663.53
# Entrar em transação (short) em 2023-10-06 06:00:00 com preço 27486.90, Stop Loss: 29960.72, Take Profit: 26744.75
# Sair de transação (short) em 2023-10-13 10:00:00 com preço 26744.75 (Take Profit Lateral), saldo atualizado: 4453392.39
# Entrar em transação (long normal) em 2023-10-14 05:00:00 com preço 26893.10, Stop Loss: 24741.65, Take Profit: 35498.89
# Sair de transação (long) em 2023-10-23 22:00:00 com preço 35498.89 (Take Profit), saldo atualizado: 5878477.96
# Entrar em transação (short normal) em 2023-10-27 18:00:00 com preço 33613.60, Stop Loss: 37647.23, Take Profit: 25882.47
# Sair de transação (short) em 2023-10-28 15:00:00 com preço 34108.40 (Inversão para Long), saldo atualizado: 5788211.47
# Entrar em transação (long) em 2023-10-28 15:00:00 com preço 34108.40, Stop Loss: 33187.47, Take Profit: 37860.32
# Sair de transação (long) em 2023-11-25 20:00:00 com preço 37860.32 (Take Profit Lateral), saldo atualizado: 6424914.73
# Entrar em transação (short normal) em 2023-11-30 16:00:00 com preço 37625.00, Stop Loss: 42140.00, Take Profit: 28971.25
# Sair de transação (short) em 2023-12-04 10:00:00 com preço 42140.00 (Stoploss), saldo atualizado: 5651868.99
# Entrar em transação (short normal) em 2023-12-10 12:00:00 com preço 43772.70, Stop Loss: 49025.42, Take Profit: 33704.98
# Sair de transação (short) em 2023-12-24 00:00:00 com preço 43735.70 (Inversão para Long), saldo atualizado: 5653028.23
# Entrar em transação (long) em 2023-12-24 00:00:00 com preço 43735.70, Stop Loss: 42554.84, Take Profit: 48546.63
# Sair de transação (long) em 2023-12-24 21:00:00 com preço 43522.20 (Inversão para Short), saldo atualizado: 5623632.29
# Entrar em transação (short) em 2023-12-24 21:00:00 com preço 43522.20, Stop Loss: 48744.86, Take Profit: 33512.09
# Sair de transação (short) em 2024-01-11 14:00:00 com preço 48744.86 (Stoploss), saldo atualizado: 4946996.86
# Entrar em transação (long normal) em 2024-01-16 13:00:00 com preço 43160.10, Stop Loss: 39707.29, Take Profit: 56971.33
# Sair de transação (long) em 2024-01-20 10:00:00 com preço 41994.78 (Stoploss Lateral), saldo atualizado: 4813427.94
# Entrar em transação (long) em 2024-01-21 13:00:00 com preço 41729.90, Stop Loss: 38391.51, Take Profit: 55083.47
# Sair de transação (long) em 2024-02-25 09:00:00 com preço 46320.19 (Take Profit Lateral), saldo atualizado: 5342905.01
# Entrar em transação (long normal) em 2024-03-06 09:00:00 com preço 67034.40, Stop Loss: 61671.65, Take Profit: 88485.41
# Sair de transação (long) em 2024-03-19 23:00:00 com preço 61671.65 (Stoploss), saldo atualizado: 4915472.61
# Entrar em transação (short normal) em 2024-03-22 02:00:00 com preço 65247.40, Stop Loss: 73077.09, Take Profit: 50240.50
# Sair de transação (short) em 2024-03-30 17:00:00 com preço 70240.20 (Inversão para Long), saldo atualizado: 4536310.42
# Entrar em transação (long) em 2024-03-30 17:00:00 com preço 70240.20, Stop Loss: 68343.71, Take Profit: 77966.62
# Sair de transação (long) em 2024-04-02 13:00:00 com preço 64620.98 (Stoploss), saldo atualizado: 4173405.59
# Entrar em transação (long normal) em 2024-04-10 23:00:00 com preço 70568.50, Stop Loss: 64923.02, Take Profit: 93150.42
# Sair de transação (long) em 2024-04-12 18:00:00 com preço 64923.02 (Stoploss), saldo atualizado: 3839533.14
# Entrar em transação (long normal) em 2024-04-15 10:00:00 com preço 66554.90, Stop Loss: 61230.51, Take Profit: 87852.47
# Sair de transação (long) em 2024-04-17 14:00:00 com preço 61230.51 (Stoploss), saldo atualizado: 3532370.49
# Entrar em transação (long normal) em 2024-04-18 17:00:00 com preço 63488.00, Stop Loss: 58408.96, Take Profit: 83804.16
# Sair de transação (long) em 2024-05-01 07:00:00 com preço 58408.96 (Stoploss), saldo atualizado: 3249780.85
# Entrar em transação (long normal) em 2024-05-03 03:00:00 com preço 59518.30, Stop Loss: 54756.84, Take Profit: 78564.16
# Sair de transação (long) em 2024-05-18 06:00:00 com preço 66065.31 (Take Profit Lateral), saldo atualizado: 3607256.74
# Entrar em transação (long normal) em 2024-05-20 05:00:00 com preço 67116.70, Stop Loss: 61747.36, Take Profit: 88594.04
# Sair de transação (long) em 2024-06-02 11:00:00 com preço 67556.20 (Inversão para Short), saldo atualizado: 3629716.24
# Entrar em transação (short) em 2024-06-02 11:00:00 com preço 67556.20, Stop Loss: 75662.94, Take Profit: 52018.27
# Sair de transação (short) em 2024-06-16 23:00:00 com preço 66719.50 (Inversão para Long), saldo atualizado: 3672334.13
# Entrar em transação (long) em 2024-06-16 23:00:00 com preço 66719.50, Stop Loss: 64918.07, Take Profit: 74058.65
# Sair de transação (long) em 2024-06-22 15:00:00 com preço 64918.07 (Stoploss Lateral), saldo atualizado: 3573181.11
# Entrar em transação (short) em 2024-06-23 15:00:00 com preço 64163.60, Stop Loss: 71863.23, Take Profit: 49405.97
# Sair de transação (short) em 2024-06-29 20:00:00 com preço 62431.18 (Take Profit Lateral), saldo atualizado: 3668513.58
# Entrar em transação (short) em 2024-06-30 04:00:00 com preço 60857.70, Stop Loss: 68160.62, Take Profit: 46860.43
# Sair de transação (short) em 2024-07-20 12:00:00 com preço 66334.89 (Stoploss Lateral), saldo atualizado: 3337173.44
# Entrar em transação (short normal) em 2024-07-23 07:00:00 com preço 66503.00, Stop Loss: 74483.36, Take Profit: 51207.31
# Sair de transação (short) em 2024-08-05 06:00:00 com preço 51207.31 (Take Profit), saldo atualizado: 4103655.43
# Entrar em transação (long normal) em 2024-08-06 21:00:00 com preço 56515.30, Stop Loss: 51994.08, Take Profit: 74600.20
# Total de trades: 105

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib
from itertools import product
from tqdm import tqdm  # Para mostrar uma barra de progresso
import random

# Função para calcular o MACD manualmente
def macd(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

# Função para calcular o ADX manualmente
def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    tr = []
    previous_close = close[0]  # Primeiro valor de fechamento
    
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        # Calcular +DM e -DM
        current_plus_dm = high[i] - high[i-1]
        current_minus_dm = low[i-1] - low[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)
        
        # Calcular True Range (TR)
        tr1 = high[i] - low[i]
        tr2 = abs(high[i] - previous_close)
        tr3 = abs(low[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)
        
        # Atualizar o fechamento anterior
        previous_close = close[i]
    
    # Adiciona um valor NaN para a primeira posição
    tr.insert(0, None)
    plus_dm.insert(0, None)
    minus_dm.insert(0, None)
    
    # Converter listas para Series do pandas
    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)
    
    # Calcular o ATR usando o lookback fornecido para DI
    atr = tr.rolling(window=di_lookback).mean()
    
    # Calcular DI+ e DI- com o lookback de DI
    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    
    # Calcular o DX
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    
    # Calcular o ADX usando o smoothing específico para o ADX
    adx = dx.ewm(alpha=1/adx_smoothing).mean()
    
    return plus_di, minus_di, adx

# Função para detectar crossover (cruzamento ascendente)
def crossover(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] > series2_vals[1:]) & (series1_vals[:-1] <= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False para alinhar os comprimentos
    return pd.Series(cross, index=series1.index)

# Função para detectar crossunder (cruzamento descendente)
def crossunder(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] < series2_vals[1:]) & (series1_vals[:-1] >= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False para alinhar os comprimentos
    return pd.Series(cross, index=series1.index)

# Função de Backtest
def backtest(params, df):
    # Desempacotar parâmetros
    (emaShortLength, emaLongLength, rsiLength, macdShort, macdLong, macdSignal,
     adxLength, adxSmoothing, adxThreshold, bbLength, bbMultiplier,
     lateralThreshold, stopgain_lateral_long, stoploss_lateral_long,
     stopgain_lateral_short, stoploss_lateral_short,
     stopgain_normal_long, stoploss_normal_long,
     stopgain_normal_short, stoploss_normal_short,
     commission) = params
    
    # Atribuir os dados às variáveis
    timestamp = df['time']
    open_price = df['open']
    high_price = df['high']
    low_price = df['low']
    close_price = df['close']
    
    # Cálculo dos Indicadores
    emaShort = talib.EMA(close_price, emaShortLength).round(0)
    emaLong = talib.EMA(close_price, emaLongLength).round(0)
    rsi = talib.RSI(close_price, timeperiod=rsiLength)
    plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
    adx = adx.fillna(0).astype(int)
    macdLine, signalLine, macdHist = macd(close_price, macdShort, macdLong, macdSignal)
    upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)
    
    # Condição de mercado em tendência (baseada no ADX)
    trendingMarket = adx >= adxThreshold
    
    # Condições de lateralização com Bollinger Bands
    bandWidth = (upperBand - lowerBand) / middleBand
    isLateral = bandWidth < lateralThreshold
    
    # Condições de crossover
    longCondition = (crossover(emaShort, emaLong)) & (rsi < 60) & (macdHist > 0.5) & trendingMarket
    shortCondition = (crossunder(emaShort, emaLong)) & (rsi > 40) & (macdHist < -0.5) & trendingMarket
    
    # Inicialização do Backtest
    saldo = 1_000_000  # Saldo inicial de 1.000.000
    quantidade = 0  # Quantidade de BTC comprada/vendida na transação
    position_open = False  # Indica se estamos em uma transação
    current_position = None  # 'long' ou 'short'
    entry_price = None  # Preço de entrada da posição
    trade_count = 0  # Contador de trades
    
    # Loop para verificar e executar as ordens
    for i in range(len(df)):
        # Estratégia de Mean Reversion para mercado lateral
        if isLateral[i]:
            if not position_open:
                if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i] and longCondition[i]:
                    entry_price = close_price[i]
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na compra
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                elif (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i] and shortCondition[i]:
                    entry_price = close_price[i]
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na venda
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
            elif position_open:
                if current_position == 'long':
                    if (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i] and shortCondition[i]:
                        saldo = quantidade * close_price[i]
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Short
                        entry_price = close_price[i]
                        stopLossShort = entry_price * stoploss_lateral_short
                        takeProfitShort = entry_price * stopgain_lateral_short
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'short'
                        trade_count += 1
                elif current_position == 'short':
                    if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i] and longCondition[i]:
                        saldo = saldo + (quantidade * (entry_price - close_price[i]))
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Long
                        entry_price = close_price[i]
                        stopLossLong = entry_price * stoploss_lateral_long
                        takeProfitLong = entry_price * stopgain_lateral_long
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'long'
                        trade_count += 1

        # Estratégia para mercado não lateral
        if not isLateral[i]:
            if not position_open:
                if longCondition[i]:
                    entry_price = close_price[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na compra
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                elif shortCondition[i]:
                    entry_price = close_price[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na venda
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
            elif position_open:
                if current_position == 'long':
                    if shortCondition[i]:
                        saldo = quantidade * close_price[i]
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Short
                        entry_price = close_price[i]
                        stopLossShort = entry_price * stoploss_normal_short
                        takeProfitShort = entry_price * stopgain_normal_short
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'short'
                        trade_count += 1
                elif current_position == 'short':
                    if longCondition[i]:
                        saldo = saldo + (quantidade * (entry_price - close_price[i]))
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Long
                        entry_price = close_price[i]
                        stopLossLong = entry_price * stoploss_normal_long
                        takeProfitLong = entry_price * stopgain_normal_long
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'long'
                        trade_count += 1

                # Gerenciamento de Stop Loss e Take Profit
                if current_position == 'long':
                    if low_price[i] <= stopLossLong:
                        saldo = quantidade * stopLossLong
                        position_open = False
                        current_position = None
                    elif high_price[i] >= takeProfitLong:
                        saldo = quantidade * takeProfitLong
                        position_open = False
                        current_position = None
                elif current_position == 'short':
                    if high_price[i] >= stopLossShort:
                        saldo = saldo - (quantidade * (stopLossShort - entry_price))
                        position_open = False
                        current_position = None
                    elif low_price[i] <= takeProfitShort:
                        saldo = saldo + (quantidade * (entry_price - takeProfitShort))
                        position_open = False
                        current_position = None

    # Fechar posição aberta no final do backtest
    if position_open:
        if current_position == 'long':
            saldo = quantidade * close_price.iloc[-1]
        elif current_position == 'short':
            saldo = saldo + (quantidade * (entry_price - close_price.iloc[-1]))
    
    return saldo, trade_count

# Função para gerar listas de parâmetros com base em [início, fim, passo]
def generate_parameter_list(start, end, step, decimals=0):
    if isinstance(start, float) or isinstance(end, float) or isinstance(step, float):
        num = int(np.floor((end - start) / step)) + 1
        return [round(start + step * i, decimals) for i in range(num)]
    else:
        return list(range(start, end + 1, step))

# Função para realizar Random Search
def random_search(df, param_grid, n_iterations, seed=None):
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)
    
    keys = list(param_grid.keys())
    results = []
    
    print(f"Iniciando Random Search com {n_iterations} iterações...")
    
    for _ in tqdm(range(n_iterations), desc="Random Search"):
        # Selecionar aleatoriamente um valor para cada parâmetro
        params = {key: random.choice(values) for key, values in param_grid.items()}
        
        # Criar uma tupla de parâmetros na ordem esperada pela função backtest
        param_tuple = (
            params['emaShortLength'],
            params['emaLongLength'],
            params['rsiLength'],
            params['macdShort'],
            params['macdLong'],
            params['macdSignal'],
            params['adxLength'],
            params['adxSmoothing'],
            params['adxThreshold'],
            params['bbLength'],
            params['bbMultiplier'],
            params['lateralThreshold'],
            params['stopgain_lateral_long'],
            params['stoploss_lateral_long'],
            params['stopgain_lateral_short'],
            params['stoploss_lateral_short'],
            params['stopgain_normal_long'],
            params['stoploss_normal_long'],
            params['stopgain_normal_short'],
            params['stoploss_normal_short'],
            params['commission']
        )
        
        # Executar o backtest com os parâmetros selecionados
        saldo_final, trade_count = backtest(param_tuple, df)
        
        # Adicionar os resultados
        result = params.copy()
        result['saldo_final'] = saldo_final
        result['trade_count'] = trade_count
        results.append(result)
    
    # Converter os resultados para um DataFrame
    resultados_df = pd.DataFrame(results)
    return resultados_df

# Carregar o CSV com nome atualizado
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')
# df['time'] = pd.to_datetime(df['time'], unit='s')  # Descomente se necessário

# Definir a grade de parâmetros para a Random Search com intervalos e passos
param_grid_definicao = {
    'emaShortLength': [5, 20, 1],
    'emaLongLength': [20, 100, 1],
    'rsiLength': [7, 21, 1],
    'macdShort': [5, 15, 1],
    'macdLong': [20, 35, 1],
    'macdSignal': [5, 12, 1],
    'adxLength': [7, 28, 1],
    'adxSmoothing': [7, 21, 1],
    'adxThreshold': [20, 40, 1],
    'bbLength': [10, 30, 1],
    'bbMultiplier': [1.5, 3.0, 0.1],
    'lateralThreshold': [0.002, 0.01, 0.001],
    'stopgain_lateral_long': [1.02, 1.10, 0.01],
    'stoploss_lateral_long': [0.90, 0.98, 0.01],
    'stopgain_lateral_short': [0.90, 0.98, 0.01],
    'stoploss_lateral_short': [1.02, 1.10, 0.01],
    'stopgain_normal_long': [1.05, 1.35, 0.01],
    'stoploss_normal_long': [0.80, 0.95, 0.01],
    'stopgain_normal_short': [0.70, 0.95, 0.01],
    'stoploss_normal_short': [1.05, 1.15, 0.01],
    'commission': [0.00032]  # Fixa
}

# Gerar listas de valores para cada parâmetro
param_grid = {
    key: generate_parameter_list(*values) if key != 'commission' else values
    for key, values in param_grid_definicao.items()
}

# Definir o número de iterações para a Random Search
n_iterations = 10000  # Ajuste conforme a capacidade computacional

# Executar a Random Search
resultado_random = random_search(df, param_grid, n_iterations, seed=42)

# Ordenar os resultados pelo saldo final em ordem decrescente
resultado_random_sorted = resultado_random.sort_values(by='saldo_final', ascending=False)

# Exibir os top 5 resultados
print("\nTop 5 Resultados da Random Search:")
print(resultado_random_sorted.head(5))

# Salvar os resultados em um arquivo CSV para análise posterior
resultado_random_sorted.to_csv('random_search_resultados.csv', index=False)
# Out:
# Iniciando Random Search com 100 iterações...
# Random Search: 100%|██████████| 100/100 [01:21<00:00,  1.22it/s]
# Top 5 Resultados da Random Search:
#     emaShortLength  emaLongLength  rsiLength  macdShort  macdLong  macdSignal  \
# 70               7             85         17          6        26          10
# 31              10             59          8         14        20           9
# 19              12             54          9          6        32           5
# 58               6             62         10          7        26           6
# 57              19             50         20         10        23          10
#
#     adxLength  adxSmoothing  adxThreshold  bbLength  ...  \
# 70         18            18            40        14  ...
# 31         25            17            32        22  ...
# 19         22            10            26        24  ...
# 58         24            10            38        16  ...
# 57         24            21            40        21  ...
#
#     stoploss_lateral_long  stopgain_lateral_short  stoploss_lateral_short  \
# 70                    1.0                     1.0                     1.0
# 31                    1.0                     1.0                     1.0
# 19                    1.0                     1.0                     1.0
# 58                    1.0                     1.0                     1.0
# 57                    1.0                     1.0                     1.0
#
#     stopgain_normal_long  stoploss_normal_long  stopgain_normal_short  \
# 70                   1.0                   1.0                    1.0
# 31                   1.0                   1.0                    1.0
# 19                   1.0                   1.0                    1.0
# 58                   1.0                   1.0                    1.0
# 57                   1.0                   1.0                    1.0
#
#     stoploss_normal_short  commission  saldo_final  trade_count
# 70                    1.0     0.00032    1000000.0            1
# 31                    1.0     0.00032    1000000.0            0
# 19                    1.0     0.00032    1000000.0            1
# 58                    1.0     0.00032    1000000.0            0
# 57                    1.0     0.00032    1000000.0            0
#
# [5 rows x 23 columns]

# %%
import pandas as pd
import numpy as np
import talib
from numba import njit
from tqdm import tqdm
import time

# Definição da função MACD otimizada com Numba
@njit
def macd_calculation(series, fast_period, slow_period, signal_period):
    n = len(series)
    macd_line = np.empty(n)
    signal_line = np.empty(n)
    macd_hist = np.empty(n)
    ema_fast_arr = np.empty(n)
    ema_slow_arr = np.empty(n)
    
    # Inicialização das EMAs
    ema_fast = series[0]
    ema_slow = series[0]
    macd_line[0] = np.nan  # Diferença inicial como NaN
    signal_line[0] = np.nan  # Inicialização da linha de sinal como NaN
    macd_hist[0] = np.nan  # Inicialização do histograma como NaN
    ema_fast_arr[0] = ema_fast
    ema_slow_arr[0] = ema_slow
    
    multiplier_fast = 2.0 / (fast_period + 1)
    multiplier_slow = 2.0 / (slow_period + 1)
    multiplier_signal = 2.0 / (signal_period + 1)
    
    for i in range(1, n):
        # Cálculo da EMA rápida
        ema_fast = (series[i] - ema_fast) * multiplier_fast + ema_fast
        ema_fast_arr[i] = ema_fast
        # Cálculo da EMA lenta
        ema_slow = (series[i] - ema_slow) * multiplier_slow + ema_slow
        ema_slow_arr[i] = ema_slow
        # Cálculo da linha MACD
        macd_line[i] = ema_fast - ema_slow
        # Cálculo da linha de sinal
        if i < slow_period:
            signal_line[i] = np.nan  # Ainda não há dados suficientes para a linha de sinal
        elif i == slow_period:
            signal_line[i] = macd_line[i]  # Inicializa a linha de sinal com o primeiro valor da linha MACD
        else:
            signal_line[i] = (macd_line[i] - signal_line[i-1]) * multiplier_signal + signal_line[i-1]
        # Cálculo do histograma
        if i < slow_period:
            macd_hist[i] = np.nan  # Ainda não há dados suficientes para o histograma
        else:
            macd_hist[i] = macd_line[i] - signal_line[i]
    
    return ema_fast_arr, ema_slow_arr, macd_line, signal_line, macd_hist

def macd_optimizado_numba(series, fast_period=12, slow_period=26, signal_period=9):
    series_np = np.asarray(series, dtype=np.float64)  # Assegura que a série seja um array NumPy com float64
    return macd_calculation(series_np, fast_period, slow_period, signal_period)

# Definição da função MACD manual usando TA-Lib
def macd_func(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return ema_fast, ema_slow, macd_line, signal_line, macd_hist

def main():
    # Carregar o DataFrame
    try:
        df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')
    except FileNotFoundError:
        print("Erro: O arquivo 'BYBIT_BTCUSDT.P_1h.csv' não foi encontrado.")
        return
    except Exception as e:
        print(f"Erro ao carregar o arquivo CSV: {e}")
        return
    
    # Verificar se a coluna 'close' existe
    if 'close' not in df.columns:
        print("Erro: A coluna 'close' não foi encontrada no DataFrame.")
        return
    
    # Extrair os preços de fechamento
    series = df['close'].values
    
    # Verificar se a série contém dados suficientes
    if len(series) < 1:
        print("Erro: A série de preços de fechamento está vazia.")
        return
    
    # Número de iterações para benchmarking
    num_iterations = 100
    
    # Aquecer a função Numba (primeira chamada inclui tempo de compilação)
    print("Aquecendo a função Numba (primeira chamada pode ser mais lenta devido à compilação)...")
    macd_optimizado_numba(series)
    
    # Calcular MACD com TA-Lib para uma única execução e verificar resultados
    print("\nCalculando MACD usando TA-Lib (macd_func)...")
    ema_fast_manual, ema_slow_manual, macd_line_manual, signal_line_manual, macd_hist_manual = macd_func(series, 12, 26, 9)
    
    # Calcular MACD com Numba otimizado para uma única execução e verificar resultados
    print("Calculando MACD usando Numba otimizado (macd_optimizado_numba)...")
    ema_fast_numba, ema_slow_numba, macd_line_numba, signal_line_numba, macd_hist_numba = macd_optimizado_numba(series, 12, 26, 9)
    
    # Imprimir os primeiros 10 valores de cada linha para comparação
    print("\n📊 Primeiros 10 valores das linhas MACD, Sinal e Histograma:")
    print("🔹 MACD (TA-Lib):", macd_line_manual[:10])
    print("🔹 MACD (Numba):   ", macd_line_numba[:10])
    print("🔹 Sinal (TA-Lib):", signal_line_manual[:10])
    print("🔹 Sinal (Numba):  ", signal_line_numba[:10])
    print("🔹 Histograma (TA-Lib):", macd_hist_manual[:10])
    print("🔹 Histograma (Numba):  ", macd_hist_numba[:10])
    
    # Verificar se os resultados são similares, ignorando NaNs
    similarity_threshold = 1e-6
    comparison_mask = ~np.isnan(macd_line_manual) & ~np.isnan(macd_line_numba) & \
                      ~np.isnan(signal_line_manual) & ~np.isnan(signal_line_numba) & \
                      ~np.isnan(macd_hist_manual) & ~np.isnan(macd_hist_numba)
    
    if np.allclose(macd_line_manual[comparison_mask], macd_line_numba[comparison_mask], atol=similarity_threshold) and \
       np.allclose(signal_line_manual[comparison_mask], signal_line_numba[comparison_mask], atol=similarity_threshold) and \
       np.allclose(macd_hist_manual[comparison_mask], macd_hist_numba[comparison_mask], atol=similarity_threshold):
        print("✅ Ambas as implementações do MACD produzem resultados similares.")
    else:
        print("❌ As implementações do MACD produzem resultados diferentes.")
    
    # Benchmarking da função macd_func (TA-Lib)
    print("\n🔍 Iniciando o benchmark da função macd_func (TA-Lib)...")
    start_time = time.time()
    for _ in tqdm(range(num_iterations), desc='Benchmarking macd_func'):
        macd_func(series, 12, 26, 9)
    end_time = time.time()
    total_time_func = end_time - start_time
    iterations_per_sec_func = num_iterations / total_time_func
    print(f"🕒 macd_func: Tempo total para {num_iterations} iterações: {total_time_func:.4f} segundos")
    print(f"🚀 macd_func: Iterações por segundo: {iterations_per_sec_func:.2f}")
    
    # Benchmarking da função macd_optimizado_numba (Numba)
    print("\n🔍 Iniciando o benchmark da função macd_optimizado_numba (Numba otimizado)...")
    start_time = time.time()
    for _ in tqdm(range(num_iterations), desc='Benchmarking macd_optimizado_numba'):
        macd_optimizado_numba(series, 12, 26, 9)
    end_time = time.time()
    total_time_numba = end_time - start_time
    iterations_per_sec_numba = num_iterations / total_time_numba
    print(f"🕒 macd_optimizado_numba: Tempo total para {num_iterations} iterações: {total_time_numba:.4f} segundos")
    print(f"🚀 macd_optimizado_numba: Iterações por segundo: {iterations_per_sec_numba:.2f}")
    
    # Cálculo da velocidade de aceleração (Speedup)
    if total_time_numba > 0:
        speedup = total_time_func / total_time_numba
        print(f"\n⚡ Velocidade de aceleração (macd_func / macd_optimizado_numba): {speedup:.2f}x")
    else:
        print("\n⚡ Velocidade de aceleração não pode ser calculada (tempo de Numba otimizado é zero).")
    
    # Exibir métricas adicionais se necessário
    # Por exemplo, verificar a diferença média entre os resultados
    difference_macd = np.mean(np.abs(macd_line_manual[comparison_mask] - macd_line_numba[comparison_mask]))
    difference_signal = np.mean(np.abs(signal_line_manual[comparison_mask] - signal_line_numba[comparison_mask]))
    difference_hist = np.mean(np.abs(macd_hist_manual[comparison_mask] - macd_hist_numba[comparison_mask]))
    print("\n📊 Métricas adicionais de similaridade:")
    print(f"🔹 Diferença média na linha MACD: {difference_macd:.10f}")
    print(f"🔹 Diferença média na linha de sinal: {difference_signal:.10f}")
    print(f"🔹 Diferença média no histograma: {difference_hist:.10f}")

if __name__ == "__main__":
    main()
# Out:
# Aquecendo a função Numba (primeira chamada pode ser mais lenta devido à compilação)...
#
# Calculando MACD usando TA-Lib (macd_func)...
# Calculando MACD usando Numba otimizado (macd_optimizado_numba)...
#
# 📊 Primeiros 10 valores das linhas MACD, Sinal e Histograma:
# 🔹 MACD (TA-Lib): [nan nan nan nan nan nan nan nan nan nan]
# 🔹 MACD (Numba):    [        nan -6.38176638 -5.56540937 -4.74273184 -3.64527528 -0.74960106
#   5.47634999  9.13512815 12.09701842 11.84668152]
# 🔹 Sinal (TA-Lib): [nan nan nan nan nan nan nan nan nan nan]
# 🔹 Sinal (Numba):   [nan nan nan nan nan nan nan nan nan nan]
# 🔹 Histograma (TA-Lib): [nan nan nan nan nan nan nan nan nan nan]
# 🔹 Histograma (Numba):   [nan nan nan nan nan nan nan nan nan nan]
# ❌ As implementações do MACD produzem resultados diferentes.
#
# 🔍 Iniciando o benchmark da função macd_func (TA-Lib)...
# Benchmarking macd_func: 100%|██████████| 100/100 [00:00<00:00, 3824.83it/s]
# 🕒 macd_func: Tempo total para 100 iterações: 0.0282 segundos
# 🚀 macd_func: Iterações por segundo: 3551.00
#
# 🔍 Iniciando o benchmark da função macd_optimizado_numba (Numba otimizado)...
# Benchmarking macd_optimizado_numba: 100%|██████████| 100/100 [00:00<00:00, 6235.96it/s]
# 🕒 macd_optimizado_numba: Tempo total para 100 iterações: 0.0180 segundos
# 🚀 macd_optimizado_numba: Iterações por segundo: 5543.99
#
# ⚡ Velocidade de aceleração (macd_func / macd_optimizado_numba): 1.56x
#
# 📊 Métricas adicionais de similaridade:
# 🔹 Diferença média na linha MACD: 0.0004701391
# 🔹 Diferença média na linha de sinal: 0.0007324493
# 🔹 Diferença média no histograma: 0.0002623102
