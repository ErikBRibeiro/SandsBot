# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib

# Carregar o CSV com nome atualizado
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')

# Converter o timestamp para datetime (descomente se necessário)
if 'time' in df.columns:
    try:
        df['time'] = pd.to_datetime(df['time'], unit='s')
    except:
        pass  # Se o timestamp já estiver em formato datetime

# Atribuir os dados às variáveis
timestamp = df['time']
open_price = df['open']
high_price = df['high']
low_price = df['low']
close_price = df['close']

# Parâmetros configuráveis
emaShortLength = 11  # Período da EMA Curta
emaLongLength = 55  # Período da EMA Longa
rsiLength = 22  # Período do RSI
macdShort = 15  # Período Curto MACD
macdLong = 34  # Período Longo MACD
macdSignal = 11  # Período de Sinal MACD
adxLength = 16  # Período ADX (igual ao DI Length)
adxSmoothing = 13  # ADX Smoothing
adxThreshold = 12  # Nível de ADX para indicar tendência
bbLength = 14  # Período do Bollinger Bands
bbMultiplier = 1.7  # Multiplicador do Bollinger Bands
lateralThreshold = 0.005  # Limite de Lateralização
stopgain_lateral_long = 1.11
stoploss_lateral_long = 0.973
stopgain_lateral_short = 0.973
stoploss_lateral_short = 1.09
stopgain_normal_long = 1.32
stoploss_normal_long = 0.92
stopgain_normal_short = 0.77
stoploss_normal_short = 1.12

# Funções para cálculo manual do MACD
def macd_func(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    tr = []
    previous_close = close.iloc[0]
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        current_plus_dm = high.iloc[i] - high.iloc[i-1]
        current_minus_dm = low.iloc[i-1] - low.iloc[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)

        tr1 = high.iloc[i] - low.iloc[i]
        tr2 = abs(high.iloc[i] - previous_close)
        tr3 = abs(low.iloc[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)

        previous_close = close.iloc[i]

    tr.insert(0, np.nan)
    plus_dm.insert(0, np.nan)
    minus_dm.insert(0, np.nan)

    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)

    atr = tr.rolling(window=di_lookback).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback, adjust=False).mean() / atr)

    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.ewm(alpha=1/adx_smoothing, adjust=False).mean()

    return plus_di, minus_di, adx

# Cálculo dos indicadores
emaShort = talib.EMA(close_price, emaShortLength)
emaLong = talib.EMA(close_price, emaLongLength)
rsi = talib.RSI(close_price, timeperiod=rsiLength)
plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
adx = adx.fillna(0).astype(int)
macdLine, signalLine, macdHist = macd_func(close_price, macdShort, macdLong, macdSignal)
upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)

# Função para detectar crossover (cruzamento ascendente)
def crossover(series1, series2):
    return (series1.shift(1) <= series2.shift(1)) & (series1 > series2)

# Função para detectar crossunder (cruzamento descendente)
def crossunder(series1, series2):
    return (series1.shift(1) >= series2.shift(1)) & (series1 < series2)

# Condição de mercado em tendência (baseada no ADX)
trendingMarket = adx >= adxThreshold

# Condições de lateralização com Bollinger Bands
bandWidth = (upperBand - lowerBand) / middleBand
isLateral = bandWidth < lateralThreshold

# Saldo inicial
saldo = 1_000_000  # Saldo inicial de 1.000.000
quantidade = 0  # Quantidade de BTC comprada/vendida na transação
position_open = False  # Indica se estamos em uma transação
current_position = None  # 'long' ou 'short'
entry_price = None  # Preço de entrada da posição
orders = []
trade_count = 0  # Contador de trades

# Condição Long
longCondition = (crossover(emaShort, emaLong)) & (rsi < 60) & (macdHist > 0.5) & trendingMarket

# Condição Short
shortCondition = (crossunder(emaShort, emaLong)) & (rsi > 40) & (macdHist < -0.5) & trendingMarket

commission = 0.00032  # 0,032%

# Loop para verificar e executar as ordens
for i in range(1, len(df)):
    adjusted_timestamp = timestamp.iloc[i]

    # Determinar a condição de lateralização da vela anterior
    lateral_prev = isLateral.iloc[i-1]

    # Estratégia de Mean Reversion para mercado lateral
    if lateral_prev:
        if not position_open:
            # Condição para entrar em Long
            if (close_price.iloc[i-1] < lowerBand.iloc[i-1]) and crossover(close_price, lowerBand).iloc[i-1] and longCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]  # Executa no candle atual
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (long lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                position_open = True
                current_position = 'long'
                trade_count += 1
                print(f"Trade LONG lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            # Condição para entrar em Short
            elif (close_price.iloc[i-1] > upperBand.iloc[i-1]) and crossunder(close_price, upperBand).iloc[i-1] and shortCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (short lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                position_open = True
                current_position = 'short'
                trade_count += 1
                print(f"Trade SHORT lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
        elif position_open:
            if current_position == 'long':
                # Condição para inverter para Short
                if (close_price.iloc[i] > upperBand.iloc[i]) and crossover(close_price, upperBand).iloc[i] and shortCondition.iloc[i-1]:
                    saldo = quantidade * close_price.iloc[i]
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Short), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]  # Executa no candle atual
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif current_position == 'short':
                # Condição para inverter para Long
                if (close_price.iloc[i] < lowerBand.iloc[i]) and crossover(close_price, lowerBand).iloc[i] and longCondition.iloc[i-1]:
                    saldo += quantidade * (entry_price - close_price.iloc[i])
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Long), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long lateral) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG lateral executado em {adjusted_timestamp_entry} a {entry_price:.2f}")

            # Gerenciamento de posições abertas com base nos parâmetros laterais da vela anterior
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                if low_price.iloc[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss LONG atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                elif high_price.iloc[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit LONG atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short  # Corrigido para takeProfitShort
                if high_price.iloc[i] >= stopLossShort:
                    saldo -= quantidade * (stopLossShort - entry_price)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {stopLossShort:.2f} (Stoploss Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss SHORT atingido em {adjusted_timestamp} a {close_price.iloc[i]:.2f}")
                elif low_price.iloc[i] <= takeProfitShort:
                    saldo += quantidade * (entry_price - takeProfitShort)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit Lateral), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit SHORT atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")

    # Estratégia para mercado não lateral
    if not lateral_prev:
        if not position_open:
            # Condição para entrar em Long
            if longCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (long normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                position_open = True
                current_position = 'long'
                trade_count += 1
                print(f"Trade LONG normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            # Condição para entrar em Short
            elif shortCondition.iloc[i-1]:
                entry_price = open_price.iloc[i]
                adjusted_timestamp_entry = timestamp.iloc[i]
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short
                quantidade = saldo / entry_price
                saldo -= saldo * commission
                orders.append(f"Entrar em transação (short normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                position_open = True
                current_position = 'short'
                trade_count += 1
                print(f"Trade SHORT normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
        elif position_open:
            if current_position == 'long':
                # Condição para inverter para Short
                if shortCondition.iloc[i-1]:
                    saldo = quantidade * open_price.iloc[i]
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Short), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (short normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossShort:.2f}, Take Profit: {takeProfitShort:.2f}")
                    current_position = 'short'
                    trade_count += 1
                    print(f"Trade SHORT normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")
            elif current_position == 'short':
                # Condição para inverter para Long
                if longCondition.iloc[i-1]:
                    saldo += quantidade * (entry_price - open_price.iloc[i])
                    saldo -= saldo * commission
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Inversão para Long), saldo atualizado: {saldo:.2f}")
                    entry_price = open_price.iloc[i]
                    adjusted_timestamp_entry = timestamp.iloc[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    saldo -= saldo * commission
                    orders.append(f"Entrar em transação (long normal) em {adjusted_timestamp_entry} com preço {entry_price:.2f}, Stop Loss: {stopLossLong:.2f}, Take Profit: {takeProfitLong:.2f}")
                    current_position = 'long'
                    trade_count += 1
                    print(f"Trade LONG normal executado em {adjusted_timestamp_entry} a {entry_price:.2f}")

            # Gerenciamento de posições abertas com base nos parâmetros não laterais
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                if low_price.iloc[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {stopLossLong:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss LONG normal atingido em {adjusted_timestamp} a {stopLossLong:.2f}")
                elif high_price.iloc[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"Sair de transação (long) em {adjusted_timestamp} com preço {takeProfitLong:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit LONG normal atingido em {adjusted_timestamp} a {takeProfitLong:.2f}")
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short  # Corrigido para takeProfitShort
                if high_price.iloc[i] >= stopLossShort:
                    saldo -= quantidade * (stopLossShort - entry_price)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {open_price.iloc[i]:.2f} (Stoploss), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Stop Loss SHORT normal atingido em {adjusted_timestamp} a {stopLossShort:.2f}")
                elif low_price.iloc[i] <= takeProfitShort:
                    saldo += quantidade * (entry_price - takeProfitShort)
                    orders.append(f"Sair de transação (short) em {adjusted_timestamp} com preço {takeProfitShort:.2f} (Take Profit), saldo atualizado: {saldo:.2f}")
                    position_open = False
                    print(f"Take Profit SHORT normal atingido em {adjusted_timestamp} a {takeProfitShort:.2f}")

# Exibir as ordens geradas
for order in orders:
    print(order)

# Exibir o número total de trades
print(f"Total de trades: {trade_count}")
# Out:
# Trade SHORT normal executado em 2020-04-01 07:00:00 a 6289.50
# Stop Loss SHORT normal atingido em 2020-04-02 17:00:00 a 7044.24
# Trade SHORT normal executado em 2020-04-10 04:00:00 a 7175.50
# Trade LONG normal executado em 2020-04-14 06:00:00 a 6881.00
# Take Profit LONG normal atingido em 2020-04-30 03:00:00 a 9082.92
# Trade SHORT normal executado em 2020-05-04 01:00:00 a 8806.00
# Trade LONG normal executado em 2020-05-04 22:00:00 a 8938.00
# Trade SHORT normal executado em 2020-05-09 23:00:00 a 9604.50
# Trade LONG normal executado em 2020-05-12 18:00:00 a 8872.50
# Trade SHORT normal executado em 2020-05-16 00:00:00 a 9315.00
# Trade LONG normal executado em 2020-05-16 13:00:00 a 9466.50
# Trade SHORT normal executado em 2020-05-19 05:00:00 a 9535.50
# Trade LONG normal executado em 2020-05-24 09:00:00 a 9263.00
# Trade SHORT normal executado em 2020-06-01 00:00:00 a 9449.50
# Trade LONG normal executado em 2020-06-04 05:00:00 a 9644.00
# Trade SHORT normal executado em 2020-06-05 23:00:00 a 9677.00
# Trade LONG normal executado em 2020-06-08 00:00:00 a 9741.00
# Trade SHORT normal executado em 2020-06-09 11:00:00 a 9672.00
# Take Profit SHORT atingido em 2020-06-13 19:00:00 a 9410.86
# Trade LONG normal executado em 2020-06-15 22:00:00 a 9427.50
# Trade SHORT normal executado em 2020-06-21 22:00:00 a 9336.00
# Take Profit SHORT atingido em 2020-06-27 16:00:00 a 9083.93
# Trade LONG normal executado em 2020-06-29 02:00:00 a 9144.00
# Trade SHORT normal executado em 2020-07-05 07:00:00 a 9059.00
# Trade LONG normal executado em 2020-07-11 06:00:00 a 9258.50
# Trade SHORT normal executado em 2020-07-12 15:00:00 a 9215.50
# Trade LONG normal executado em 2020-07-15 00:00:00 a 9249.50
# Trade SHORT normal executado em 2020-08-02 11:00:00 a 11259.00
# Trade LONG normal executado em 2020-08-03 18:00:00 a 11423.00
# Trade SHORT normal executado em 2020-08-09 14:00:00 a 11620.50
# Trade LONG normal executado em 2020-08-13 22:00:00 a 11703.00
# Trade SHORT normal executado em 2020-08-18 20:00:00 a 11990.00
# Take Profit SHORT atingido em 2020-08-22 20:00:00 a 11666.27
# Trade LONG normal executado em 2020-08-23 21:00:00 a 11675.50
# Stop Loss LONG normal atingido em 2020-09-03 12:00:00 a 10741.46
# Trade LONG normal executado em 2020-09-08 01:00:00 a 10326.00
# Sair de transação (long) em 2020-04-30 03:00:00 com preço 9082.92 (Take Profit), saldo atualizado: 1208076.87
# Entrar em transação (short normal) em 2020-05-04 01:00:00 com preço 8806.00, Stop Loss: 9862.72, Take Profit: 6780.62
# Sair de transação (short) em 2020-05-04 22:00:00 com preço 8938.00 (Inversão para Long), saldo atualizado: 1189200.82
# Entrar em transação (long normal) em 2020-05-04 22:00:00 com preço 8938.00, Stop Loss: 8222.96, Take Profit: 11798.16
# Sair de transação (long) em 2020-05-09 23:00:00 com preço 9604.50 (Inversão para Short), saldo atualizado: 1277469.71
# Entrar em transação (short normal) em 2020-05-09 23:00:00 com preço 9604.50, Stop Loss: 10757.04, Take Profit: 7395.47
# Sair de transação (short) em 2020-05-12 18:00:00 com preço 8872.50 (Inversão para Long), saldo atualizado: 1373982.53
# Entrar em transação (long normal) em 2020-05-12 18:00:00 com preço 8872.50, Stop Loss: 8162.70, Take Profit: 11711.70
# Sair de transação (long) em 2020-05-16 00:00:00 com preço 9315.00 (Inversão para Short), saldo atualizado: 1442045.84
# Entrar em transação (short normal) em 2020-05-16 00:00:00 com preço 9315.00, Stop Loss: 10432.80, Take Profit: 7172.55
# Sair de transação (short) em 2020-05-16 13:00:00 com preço 9466.50 (Inversão para Long), saldo atualizado: 1417677.02
# Entrar em transação (long normal) em 2020-05-16 13:00:00 com preço 9466.50, Stop Loss: 8709.18, Take Profit: 12495.78
# Sair de transação (long) em 2020-05-19 05:00:00 com preço 9535.50 (Inversão para Short), saldo atualizado: 1427553.31
# Entrar em transação (short normal) em 2020-05-19 05:00:00 com preço 9535.50, Stop Loss: 10679.76, Take Profit: 7342.34
# Sair de transação (short) em 2020-05-24 09:00:00 com preço 9263.00 (Inversão para Long), saldo atualizado: 1467422.56
# Entrar em transação (long normal) em 2020-05-24 09:00:00 com preço 9263.00, Stop Loss: 8521.96, Take Profit: 12227.16
# Sair de transação (long) em 2020-06-01 00:00:00 com preço 9449.50 (Inversão para Short), saldo atualizado: 1496488.42
# Entrar em transação (short normal) em 2020-06-01 00:00:00 com preço 9449.50, Stop Loss: 10583.44, Take Profit: 7276.11
# Sair de transação (short) em 2020-06-04 05:00:00 com preço 9644.00 (Inversão para Long), saldo atualizado: 1464738.31
# Entrar em transação (long normal) em 2020-06-04 05:00:00 com preço 9644.00, Stop Loss: 8872.48, Take Profit: 12730.08
# Sair de transação (long) em 2020-06-05 23:00:00 com preço 9677.00 (Inversão para Short), saldo atualizado: 1469280.05
# Entrar em transação (short normal) em 2020-06-05 23:00:00 com preço 9677.00, Stop Loss: 10838.24, Take Profit: 7451.29
# Sair de transação (short) em 2020-06-08 00:00:00 com preço 9741.00 (Inversão para Long), saldo atualizado: 1458625.71
# Entrar em transação (long normal) em 2020-06-08 00:00:00 com preço 9741.00, Stop Loss: 8961.72, Take Profit: 12858.12
# Sair de transação (long) em 2020-06-09 11:00:00 com preço 9672.00 (Inversão para Short), saldo atualizado: 1447830.14
# Entrar em transação (short normal) em 2020-06-09 11:00:00 com preço 9672.00, Stop Loss: 10832.64, Take Profit: 7447.44
# Sair de transação (short) em 2020-06-13 19:00:00 com preço 9410.86 (Take Profit Lateral), saldo atualizado: 1486458.25
# Entrar em transação (long normal) em 2020-06-15 22:00:00 com preço 9427.50, Stop Loss: 8673.30, Take Profit: 12444.30
# Sair de transação (long) em 2020-06-21 22:00:00 com preço 9336.00 (Inversão para Short), saldo atualizado: 1471560.16
# Entrar em transação (short normal) em 2020-06-21 22:00:00 com preço 9336.00, Stop Loss: 10456.32, Take Profit: 7188.72
# Sair de transação (short) em 2020-06-27 16:00:00 com preço 9083.93 (Take Profit Lateral), saldo atualizado: 1510821.38
# Entrar em transação (long normal) em 2020-06-29 02:00:00 com preço 9144.00, Stop Loss: 8412.48, Take Profit: 12070.08
# Sair de transação (long) em 2020-07-05 07:00:00 com preço 9059.00 (Inversão para Short), saldo atualizado: 1496298.25
# Entrar em transação (short normal) em 2020-07-05 07:00:00 com preço 9059.00, Stop Loss: 10146.08, Take Profit: 6975.43
# Sair de transação (short) em 2020-07-11 06:00:00 com preço 9258.50 (Inversão para Long), saldo atualizado: 1462399.39
# Entrar em transação (long normal) em 2020-07-11 06:00:00 com preço 9258.50, Stop Loss: 8517.82, Take Profit: 12221.22
# Sair de transação (long) em 2020-07-12 15:00:00 com preço 9215.50 (Inversão para Short), saldo atualizado: 1455141.66
# Entrar em transação (short normal) em 2020-07-12 15:00:00 com preço 9215.50, Stop Loss: 10321.36, Take Profit: 7095.94
# Sair de transação (short) em 2020-07-15 00:00:00 com preço 9249.50 (Inversão para Long), saldo atualizado: 1448843.58
# Entrar em transação (long normal) em 2020-07-15 00:00:00 com preço 9249.50, Stop Loss: 8509.54, Take Profit: 12209.34
# Sair de transação (long) em 2020-08-02 11:00:00 com preço 11259.00 (Inversão para Short), saldo atualizado: 1763047.72
# Entrar em transação (short normal) em 2020-08-02 11:00:00 com preço 11259.00, Stop Loss: 12610.08, Take Profit: 8669.43
# Sair de transação (short) em 2020-08-03 18:00:00 com preço 11423.00 (Inversão para Long), saldo atualizado: 1736246.99
# Entrar em transação (long normal) em 2020-08-03 18:00:00 com preço 11423.00, Stop Loss: 10509.16, Take Profit: 15078.36
# Sair de transação (long) em 2020-08-09 14:00:00 com preço 11620.50 (Inversão para Short), saldo atualizado: 1765700.94
# Entrar em transação (short normal) em 2020-08-09 14:00:00 com preço 11620.50, Stop Loss: 13014.96, Take Profit: 8947.78
# Sair de transação (short) em 2020-08-13 22:00:00 com preço 11703.00 (Inversão para Long), saldo atualizado: 1752039.45
# Entrar em transação (long normal) em 2020-08-13 22:00:00 com preço 11703.00, Stop Loss: 10766.76, Take Profit: 15447.96
# Sair de transação (long) em 2020-08-18 20:00:00 com preço 11990.00 (Inversão para Short), saldo atualizado: 1794431.41
# Entrar em transação (short normal) em 2020-08-18 20:00:00 com preço 11990.00, Stop Loss: 13428.80, Take Profit: 9232.30
# Sair de transação (short) em 2020-08-22 20:00:00 com preço 11666.27 (Take Profit Lateral), saldo atualizado: 1842306.84
# Entrar em transação (long normal) em 2020-08-23 21:00:00 com preço 11675.50, Stop Loss: 10741.46, Take Profit: 15411.66
# Sair de transação (long) em 2020-09-03 12:00:00 com preço 10741.46 (Stoploss), saldo atualizado: 1694922.29
# Entrar em transação (long normal) em 2020-09-08 01:00:00 com preço 10326.00, Stop Loss: 9499.92, Take Profit: 13630.32
# Sair de transação (long) em 2020-09-08 10:00:00 com preço 10025.00 (Inversão para Short), saldo atualizado: 1644989.22
# Entrar em transação (short normal) em 2020-09-08 10:00:00 com preço 10025.00, Stop Loss: 11228.00, Take Profit: 7719.25
# Sair de transação (short) em 2020-09-09 14:00:00 com preço 10213.00 (Inversão para Long), saldo atualizado: 1613097.79
# Entrar em transação (long normal) em 2020-09-09 14:00:00 com preço 10213.00, Stop Loss: 9395.96, Take Profit: 13481.16
# Sair de transação (long) em 2020-10-10 02:00:00 com preço 11336.43 (Take Profit Lateral), saldo atualizado: 1790538.55
# Entrar em transação (short normal) em 2020-10-13 20:00:00 com preço 11401.50, Stop Loss: 12769.68, Take Profit: 8779.16
# Sair de transação (short) em 2020-10-14 14:00:00 com preço 11532.00 (Inversão para Long), saldo atualizado: 1768905.09
# Entrar em transação (long normal) em 2020-10-14 14:00:00 com preço 11532.00, Stop Loss: 10609.44, Take Profit: 15222.24
# Sair de transação (long) em 2020-10-14 16:00:00 com preço 11322.50 (Inversão para Short), saldo atualizado: 1736213.90
# Entrar em transação (short normal) em 2020-10-14 16:00:00 com preço 11322.50, Stop Loss: 12681.20, Take Profit: 8718.33
# Sair de transação (short) em 2020-10-15 19:00:00 com preço 11468.00 (Inversão para Long), saldo atualizado: 1712798.80
# Entrar em transação (long normal) em 2020-10-15 19:00:00 com preço 11468.00, Stop Loss: 10550.56, Take Profit: 15137.76
# Sair de transação (long) em 2020-10-16 07:00:00 com preço 11326.00 (Inversão para Short), saldo atualizado: 1691049.13
# Entrar em transação (short normal) em 2020-10-16 07:00:00 com preço 11326.00, Stop Loss: 12685.12, Take Profit: 8721.02
# Sair de transação (short) em 2020-10-18 03:00:00 com preço 11375.50 (Inversão para Long), saldo atualizado: 1682578.71
# Entrar em transação (long normal) em 2020-10-18 03:00:00 com preço 11375.50, Stop Loss: 10465.46, Take Profit: 15015.66
# Sair de transação (long) em 2020-10-26 19:00:00 com preço 12956.00 (Inversão para Short), saldo atualizado: 1915741.19
# Entrar em transação (short normal) em 2020-10-26 19:00:00 com preço 12956.00, Stop Loss: 14510.72, Take Profit: 9976.12
# Sair de transação (short) em 2020-10-29 17:00:00 com preço 13534.50 (Inversão para Long), saldo atualizado: 1829002.68
# Entrar em transação (long normal) em 2020-10-29 17:00:00 com preço 13534.50, Stop Loss: 12451.74, Take Profit: 17865.54
# Sair de transação (long) em 2020-10-30 09:00:00 com preço 13237.00 (Inversão para Short), saldo atualizado: 1788227.21
# Entrar em transação (short normal) em 2020-10-30 09:00:00 com preço 13237.00, Stop Loss: 14825.44, Take Profit: 10192.49
# Sair de transação (short) em 2020-10-30 16:00:00 com preço 13532.50 (Inversão para Long), saldo atualizado: 1747175.69
# Entrar em transação (long normal) em 2020-10-30 16:00:00 com preço 13532.50, Stop Loss: 12449.90, Take Profit: 17862.90
# Sair de transação (long) em 2020-11-09 18:00:00 com preço 15225.50 (Inversão para Short), saldo atualizado: 1965129.21
# Entrar em transação (short normal) em 2020-11-09 18:00:00 com preço 15225.50, Stop Loss: 17052.56, Take Profit: 11723.64
# Sair de transação (short) em 2020-11-15 10:00:00 com preço 16059.00 (Inversão para Long), saldo atualizado: 1856327.73
# Entrar em transação (long normal) em 2020-11-15 10:00:00 com preço 16059.00, Stop Loss: 14774.28, Take Profit: 21197.88
# Sair de transação (long) em 2020-11-22 11:00:00 com preço 18212.50 (Inversão para Short), saldo atualizado: 2104586.22
# Entrar em transação (short normal) em 2020-11-22 11:00:00 com preço 18212.50, Stop Loss: 20398.00, Take Profit: 14023.62
# Sair de transação (short) em 2020-11-22 21:00:00 com preço 18586.00 (Inversão para Long), saldo atualizado: 2060092.69
# Entrar em transação (long normal) em 2020-11-22 21:00:00 com preço 18586.00, Stop Loss: 17099.12, Take Profit: 24533.52
# Sair de transação (long) em 2020-11-23 20:00:00 com preço 18467.00 (Inversão para Short), saldo atualizado: 2046247.59
# Entrar em transação (short normal) em 2020-11-23 20:00:00 com preço 18467.00, Stop Loss: 20683.04, Take Profit: 14219.59
# Sair de transação (short) em 2020-12-05 18:00:00 com preço 19123.50 (Inversão para Long), saldo atualizado: 1972217.58
# Entrar em transação (long normal) em 2020-12-05 18:00:00 com preço 19123.50, Stop Loss: 17593.62, Take Profit: 25243.02
# Sair de transação (long) em 2020-12-06 14:00:00 com preço 18949.00 (Inversão para Short), saldo atualizado: 1953595.94
# Entrar em transação (short normal) em 2020-12-06 14:00:00 com preço 18949.00, Stop Loss: 21222.88, Take Profit: 14590.73
# Sair de transação (short) em 2020-12-12 05:00:00 com preço 18362.00 (Inversão para Long), saldo atualizado: 2012844.75
# Entrar em transação (long normal) em 2020-12-12 05:00:00 com preço 18362.00, Stop Loss: 16893.04, Take Profit: 24237.84
# Sair de transação (long) em 2020-12-19 16:00:00 com preço 24237.84 (Take Profit), saldo atualizado: 2656955.07
# Entrar em transação (long normal) em 2020-12-22 17:00:00 com preço 23363.00, Stop Loss: 21493.96, Take Profit: 30839.16
# Sair de transação (long) em 2020-12-24 01:00:00 com preço 23049.00 (Inversão para Short), saldo atualizado: 2620406.65
# Entrar em transação (short normal) em 2020-12-24 01:00:00 com preço 23049.00, Stop Loss: 25814.88, Take Profit: 17747.73
# Sair de transação (short) em 2020-12-24 21:00:00 com preço 23530.50 (Inversão para Long), saldo atualizado: 2564006.36
# Entrar em transação (long normal) em 2020-12-24 21:00:00 com preço 23530.50, Stop Loss: 21648.06, Take Profit: 31060.26
# Sair de transação (long) em 2021-01-02 13:00:00 com preço 31060.26 (Take Profit), saldo atualizado: 3384488.39
# Entrar em transação (long normal) em 2021-01-05 17:00:00 com preço 32455.00, Stop Loss: 29858.60, Take Profit: 42840.60
# Sair de transação (long) em 2021-01-10 17:00:00 com preço 39295.00 (Inversão para Short), saldo atualizado: 4096469.37
# Entrar em transação (short normal) em 2021-01-10 17:00:00 com preço 39295.00, Stop Loss: 44010.40, Take Profit: 30257.15
# Sair de transação (short) em 2021-01-13 20:00:00 com preço 36036.00 (Inversão para Long), saldo atualizado: 4433487.23
# Entrar em transação (long normal) em 2021-01-13 20:00:00 com preço 36036.00, Stop Loss: 33153.12, Take Profit: 47567.52
# Sair de transação (long) em 2021-01-15 17:00:00 com preço 36135.50 (Inversão para Short), saldo atualizado: 4444306.02
# Entrar em transação (short normal) em 2021-01-15 17:00:00 com preço 36135.50, Stop Loss: 40471.76, Take Profit: 27824.33
# Sair de transação (short) em 2021-01-16 15:00:00 com preço 37246.50 (Inversão para Long), saldo atualizado: 4304863.93
# Entrar em transação (long normal) em 2021-01-16 15:00:00 com preço 37246.50, Stop Loss: 34266.78, Take Profit: 49165.38
# Sair de transação (long) em 2021-01-17 09:00:00 com preço 34266.78 (Stoploss), saldo atualizado: 3960474.81
# Entrar em transação (long normal) em 2021-01-18 13:00:00 com preço 37083.00, Stop Loss: 34116.36, Take Profit: 48949.56
# Sair de transação (long) em 2021-01-20 02:00:00 com preço 36181.50 (Inversão para Short), saldo atualizado: 3862957.82
# Entrar em transação (short normal) em 2021-01-20 02:00:00 com preço 36181.50, Stop Loss: 40523.28, Take Profit: 27859.76
# Sair de transação (short) em 2021-01-24 09:00:00 com preço 32659.00 (Inversão para Long), saldo atualizado: 4236449.18
# Entrar em transação (long normal) em 2021-01-24 09:00:00 com preço 32659.00, Stop Loss: 30046.28, Take Profit: 43109.88
# Sair de transação (long) em 2021-01-26 03:00:00 com preço 32356.50 (Inversão para Short), saldo atualizado: 4195866.48
# Entrar em transação (short normal) em 2021-01-26 03:00:00 com preço 32356.50, Stop Loss: 36239.28, Take Profit: 24914.51
# Sair de transação (short) em 2021-01-28 16:00:00 com preço 31916.00 (Inversão para Long), saldo atualizado: 4250285.62
# Entrar em transação (long normal) em 2021-01-28 16:00:00 com preço 31916.00, Stop Loss: 29362.72, Take Profit: 42129.12
# Sair de transação (long) em 2021-02-07 16:00:00 com preço 37951.00 (Inversão para Short), saldo atualizado: 5052355.33
# Entrar em transação (short normal) em 2021-02-07 16:00:00 com preço 37951.00, Stop Loss: 42505.12, Take Profit: 29222.27
# Sair de transação (short) em 2021-02-08 08:00:00 com preço 39290.00 (Inversão para Long), saldo atualizado: 4870920.47
# Entrar em transação (long normal) em 2021-02-08 08:00:00 com preço 39290.00, Stop Loss: 36146.80, Take Profit: 51862.80
# Sair de transação (long) em 2021-02-11 02:00:00 com preço 44249.50 (Inversão para Short), saldo atualizado: 5484011.81
# Entrar em transação (short normal) em 2021-02-11 02:00:00 com preço 44249.50, Stop Loss: 49559.44, Take Profit: 34072.11
# Sair de transação (short) em 2021-02-11 10:00:00 com preço 45521.00 (Inversão para Long), saldo atualizado: 5322971.11
# Entrar em transação (long normal) em 2021-02-11 10:00:00 com preço 45521.00, Stop Loss: 41879.32, Take Profit: 60087.72
# Sair de transação (long) em 2021-02-13 20:00:00 com preço 46904.00 (Inversão para Short), saldo atualizado: 5482936.30
# Entrar em transação (short normal) em 2021-02-13 20:00:00 com preço 46904.00, Stop Loss: 52532.48, Take Profit: 36116.08
# Sair de transação (short) em 2021-02-15 17:00:00 com preço 48488.00 (Inversão para Long), saldo atualizado: 5294322.20
# Entrar em transação (long normal) em 2021-02-15 17:00:00 com preço 48488.00, Stop Loss: 44608.96, Take Profit: 64004.16
# Sair de transação (long) em 2021-02-22 10:00:00 com preço 54895.50 (Inversão para Short), saldo atualizado: 5992028.16
# Entrar em transação (short normal) em 2021-02-22 10:00:00 com preço 54895.50, Stop Loss: 61482.96, Take Profit: 42269.54
# Sair de transação (short) em 2021-02-25 14:00:00 com preço 51385.00 (Inversão para Long), saldo atualizado: 6371254.12
# Entrar em transação (long normal) em 2021-02-25 14:00:00 com preço 51385.00, Stop Loss: 47274.20, Take Profit: 67828.20
# Sair de transação (long) em 2021-02-25 19:00:00 com preço 49624.00 (Inversão para Short), saldo atualizado: 6150937.84
# Entrar em transação (short normal) em 2021-02-25 19:00:00 com preço 49624.00, Stop Loss: 55578.88, Take Profit: 38210.48
# Sair de transação (short) em 2021-03-01 09:00:00 com preço 47014.00 (Inversão para Long), saldo atualizado: 6470410.11
# Entrar em transação (long normal) em 2021-03-01 09:00:00 com preço 47014.00, Stop Loss: 43252.88, Take Profit: 62058.48
# Sair de transação (long) em 2021-03-04 18:00:00 com preço 48595.00 (Inversão para Short), saldo atualizado: 6685858.72
# Entrar em transação (short normal) em 2021-03-04 18:00:00 com preço 48595.00, Stop Loss: 54426.40, Take Profit: 37418.15
# Sair de transação (short) em 2021-03-05 23:00:00 com preço 49100.00 (Inversão para Long), saldo atualizado: 6612123.14
# Entrar em transação (long normal) em 2021-03-05 23:00:00 com preço 49100.00, Stop Loss: 45172.00, Take Profit: 64812.00
# Sair de transação (long) em 2021-03-21 04:00:00 com preço 57890.00 (Inversão para Short), saldo atualizado: 7793346.65
# Entrar em transação (short normal) em 2021-03-21 04:00:00 com preço 57890.00, Stop Loss: 64836.80, Take Profit: 44575.30
# Sair de transação (short) em 2021-03-24 12:00:00 com preço 56580.50 (Inversão para Long), saldo atualizado: 7964592.59
# Entrar em transação (long normal) em 2021-03-24 12:00:00 com preço 56580.50, Stop Loss: 52054.06, Take Profit: 74686.26
# Sair de transação (long) em 2021-03-24 21:00:00 com preço 54088.50 (Inversão para Short), saldo atualizado: 7611368.10
# Entrar em transação (short normal) em 2021-03-24 21:00:00 com preço 54088.50, Stop Loss: 60579.12, Take Profit: 41648.15
# Sair de transação (short) em 2021-03-26 18:00:00 com preço 53810.00 (Inversão para Long), saldo atualizado: 7645675.76
# Entrar em transação (long normal) em 2021-03-26 18:00:00 com preço 53810.00, Stop Loss: 49505.20, Take Profit: 71029.20
# Sair de transação (long) em 2021-04-06 17:00:00 com preço 58150.50 (Inversão para Short), saldo atualizado: 8259758.34
# Entrar em transação (short normal) em 2021-04-06 17:00:00 com preço 58150.50, Stop Loss: 65128.56, Take Profit: 44775.89
# Sair de transação (short) em 2021-04-08 18:00:00 com preço 57700.00 (Inversão para Long), saldo atualizado: 8318441.96
# Entrar em transação (long normal) em 2021-04-08 18:00:00 com preço 57700.00, Stop Loss: 53084.00, Take Profit: 76164.00
# Sair de transação (long) em 2021-04-16 06:00:00 com preço 61951.50 (Inversão para Short), saldo atualizado: 8928510.36
# Entrar em transação (short normal) em 2021-04-16 06:00:00 com preço 61951.50, Stop Loss: 69385.68, Take Profit: 47702.65
# Sair de transação (short) em 2021-04-23 08:00:00 com preço 47702.65 (Take Profit), saldo atualizado: 10979210.62
# Entrar em transação (short normal) em 2021-04-29 15:00:00 com preço 53768.00, Stop Loss: 60220.16, Take Profit: 41401.36
# Sair de transação (short) em 2021-04-30 09:00:00 com preço 54497.50 (Inversão para Long), saldo atualizado: 10823271.74
# Entrar em transação (long normal) em 2021-04-30 09:00:00 com preço 54497.50, Stop Loss: 50137.70, Take Profit: 71936.70
# Sair de transação (long) em 2021-05-07 01:00:00 com preço 56400.50 (Inversão para Short), saldo atualizado: 11197625.53
# Entrar em transação (short normal) em 2021-05-07 01:00:00 com preço 56400.50, Stop Loss: 63168.56, Take Profit: 43428.39
# Sair de transação (short) em 2021-05-07 14:00:00 com preço 56990.50 (Inversão para Long), saldo atualizado: 11073360.44
# Entrar em transação (long normal) em 2021-05-07 14:00:00 com preço 56990.50, Stop Loss: 52431.26, Take Profit: 75227.46
# Sair de transação (long) em 2021-05-09 14:00:00 com preço 57322.00 (Inversão para Short), saldo atualizado: 11134207.42
# Entrar em transação (short normal) em 2021-05-09 14:00:00 com preço 57322.00, Stop Loss: 64200.64, Take Profit: 44137.94
# Sair de transação (short) em 2021-05-10 01:00:00 com preço 58877.00 (Inversão para Long), saldo atualizado: 10825136.61
# Entrar em transação (long normal) em 2021-05-10 01:00:00 com preço 58877.00, Stop Loss: 54166.84, Take Profit: 77717.64
# ...
# Entrar em transação (short normal) em 2024-01-05 17:00:00 com preço 43224.40, Stop Loss: 48411.33, Take Profit: 33282.79
# Sair de transação (short) em 2024-01-05 22:00:00 com preço 43957.70 (Inversão para Long), saldo atualizado: 46613221.16
# Entrar em transação (long normal) em 2024-01-05 22:00:00 com preço 43957.70, Stop Loss: 40441.08, Take Profit: 58024.16
# Sair de transação (long) em 2024-01-06 09:00:00 com preço 43715.80 (Inversão para Short), saldo atualizado: 46341873.64
# Entrar em transação (short normal) em 2024-01-06 09:00:00 com preço 43715.80, Stop Loss: 48961.70, Take Profit: 33661.17
# Sair de transação (short) em 2024-01-10 19:00:00 com preço 46562.10 (Inversão para Long), saldo atualizado: 43295903.61
# Entrar em transação (long normal) em 2024-01-10 19:00:00 com preço 46562.10, Stop Loss: 42837.13, Take Profit: 61461.97
# Sair de transação (long) em 2024-01-12 22:00:00 com preço 42837.13 (Stoploss), saldo atualizado: 39832231.32
# Entrar em transação (long normal) em 2024-01-16 13:00:00 com preço 43160.10, Stop Loss: 39707.29, Take Profit: 56971.33
# Sair de transação (long) em 2024-01-20 10:00:00 com preço 41994.78 (Stoploss Lateral), saldo atualizado: 38756761.07
# Entrar em transação (long normal) em 2024-01-25 09:00:00 com preço 40072.50, Stop Loss: 36866.70, Take Profit: 52895.70
# Sair de transação (long) em 2024-01-25 14:00:00 com preço 39901.30 (Inversão para Short), saldo atualizado: 38578833.07
# Entrar em transação (short normal) em 2024-01-25 14:00:00 com preço 39901.30, Stop Loss: 44689.46, Take Profit: 30724.00
# Sair de transação (short) em 2024-01-31 17:00:00 com preço 43456.60 (Inversão para Long), saldo atualizado: 35117781.48
# Entrar em transação (long normal) em 2024-01-31 17:00:00 com preço 43456.60, Stop Loss: 39980.07, Take Profit: 57362.71
# Sair de transação (long) em 2024-01-31 23:00:00 com preço 42625.50 (Inversão para Short), saldo atualizado: 34435137.18
# Entrar em transação (short normal) em 2024-01-31 23:00:00 com preço 42625.50, Stop Loss: 47740.56, Take Profit: 32821.64
# Sair de transação (short) em 2024-02-01 21:00:00 com preço 42985.90 (Inversão para Long), saldo atualizado: 34122045.17
# Entrar em transação (long normal) em 2024-02-01 21:00:00 com preço 42985.90, Stop Loss: 39547.03, Take Profit: 56741.39
# Sair de transação (long) em 2024-02-04 06:00:00 com preço 42870.10 (Inversão para Short), saldo atualizado: 34019233.93
# Entrar em transação (short normal) em 2024-02-04 06:00:00 com preço 42870.10, Stop Loss: 48014.51, Take Profit: 33009.98
# Sair de transação (short) em 2024-02-05 11:00:00 com preço 43128.50 (Inversão para Long), saldo atualizado: 33792479.41
# Entrar em transação (long normal) em 2024-02-05 11:00:00 com preço 43128.50, Stop Loss: 39678.22, Take Profit: 56929.62
# Sair de transação (long) em 2024-02-05 19:00:00 com preço 42718.20 (Inversão para Short), saldo atualizado: 33460286.28
# Entrar em transação (short normal) em 2024-02-05 19:00:00 com preço 42718.20, Stop Loss: 47844.38, Take Profit: 32893.01
# Sair de transação (short) em 2024-02-09 18:00:00 com preço 47632.40 (Stoploss), saldo atualizado: 29434344.63
# Entrar em transação (long normal) em 2024-02-18 10:00:00 com preço 52007.00, Stop Loss: 47846.44, Take Profit: 68649.24
# Sair de transação (long) em 2024-02-20 01:00:00 com preço 51663.50 (Inversão para Short), saldo atualizado: 29230577.54
# Entrar em transação (short normal) em 2024-02-20 01:00:00 com preço 51663.50, Stop Loss: 57863.12, Take Profit: 39780.90
# Sair de transação (short) em 2024-02-20 12:00:00 com preço 52323.00 (Inversão para Long), saldo atualizado: 28838855.32
# Entrar em transação (long normal) em 2024-02-20 12:00:00 com preço 52323.00, Stop Loss: 48137.16, Take Profit: 69066.36
# Sair de transação (long) em 2024-02-20 18:00:00 com preço 51351.80 (Inversão para Short), saldo atualizado: 28294502.11
# Entrar em transação (short normal) em 2024-02-20 18:00:00 com preço 51351.80, Stop Loss: 57514.02, Take Profit: 39540.89
# Sair de transação (short) em 2024-02-20 23:00:00 com preço 52188.00 (Inversão para Long), saldo atualizado: 27815803.29
# Entrar em transação (long normal) em 2024-02-20 23:00:00 com preço 52188.00, Stop Loss: 48012.96, Take Profit: 68888.16
# Sair de transação (long) em 2024-03-05 14:00:00 com preço 68888.16 (Take Profit), saldo atualizado: 36716860.34
# Entrar em transação (long normal) em 2024-03-06 09:00:00 com preço 67034.40, Stop Loss: 61671.65, Take Profit: 88485.41
# Sair de transação (long) em 2024-03-14 17:00:00 com preço 71415.20 (Inversão para Short), saldo atualizado: 39103845.78
# Entrar em transação (short normal) em 2024-03-14 17:00:00 com preço 71415.20, Stop Loss: 79985.02, Take Profit: 54989.70
# Sair de transação (short) em 2024-03-17 23:00:00 com preço 68266.50 (Inversão para Long), saldo atualizado: 40802362.27
# Entrar em transação (long normal) em 2024-03-17 23:00:00 com preço 68266.50, Stop Loss: 62805.18, Take Profit: 90111.78
# Sair de transação (long) em 2024-03-18 15:00:00 com preço 67034.00 (Inversão para Short), saldo atualizado: 40052885.47
# Entrar em transação (short normal) em 2024-03-18 15:00:00 com preço 67034.00, Stop Loss: 75078.08, Take Profit: 51616.18
# Sair de transação (short) em 2024-03-23 17:00:00 com preço 65667.40 (Inversão para Long), saldo atualizado: 40843539.37
# Entrar em transação (long normal) em 2024-03-23 17:00:00 com preço 65667.40, Stop Loss: 60414.01, Take Profit: 86680.97
# Sair de transação (long) em 2024-03-29 16:00:00 com preço 69236.40 (Inversão para Short), saldo atualizado: 43049591.03
# Entrar em transação (short normal) em 2024-03-29 16:00:00 com preço 69236.40, Stop Loss: 77544.77, Take Profit: 53312.03
# Sair de transação (short) em 2024-04-10 23:00:00 com preço 70568.50 (Inversão para Long), saldo atualizado: 42194039.80
# Entrar em transação (long normal) em 2024-04-10 23:00:00 com preço 70568.50, Stop Loss: 64923.02, Take Profit: 93150.42
# Sair de transação (long) em 2024-04-12 16:00:00 com preço 69375.90 (Inversão para Short), saldo atualizado: 41467691.19
# Entrar em transação (short normal) em 2024-04-12 16:00:00 com preço 69375.90, Stop Loss: 77701.01, Take Profit: 53419.44
# Sair de transação (short) em 2024-04-15 10:00:00 com preço 66554.90 (Inversão para Long), saldo atualizado: 43126798.00
# Entrar em transação (long normal) em 2024-04-15 10:00:00 com preço 66554.90, Stop Loss: 61230.51, Take Profit: 87852.47
# Sair de transação (long) em 2024-04-17 14:00:00 com preço 61230.51 (Stoploss), saldo atualizado: 39676654.16
# Entrar em transação (long normal) em 2024-04-18 17:00:00 com preço 63488.00, Stop Loss: 58408.96, Take Profit: 83804.16
# Sair de transação (long) em 2024-04-19 03:00:00 com preço 61340.00 (Inversão para Short), saldo atualizado: 38322000.40
# Entrar em transação (short normal) em 2024-04-19 03:00:00 com preço 61340.00, Stop Loss: 68700.80, Take Profit: 47231.80
# Sair de transação (short) em 2024-04-19 07:00:00 com preço 64600.10 (Inversão para Long), saldo atualizado: 36261391.27
# Entrar em transação (long normal) em 2024-04-19 07:00:00 com preço 64600.10, Stop Loss: 59432.09, Take Profit: 85272.13
# Sair de transação (long) em 2024-04-28 23:00:00 com preço 63118.30 (Inversão para Short), saldo atualizado: 35418288.37
# Entrar em transação (short normal) em 2024-04-28 23:00:00 com preço 63118.30, Stop Loss: 70692.50, Take Profit: 48601.09
# Sair de transação (short) em 2024-05-03 03:00:00 com preço 59518.30 (Inversão para Long), saldo atualizado: 37415086.73
# Entrar em transação (long normal) em 2024-05-03 03:00:00 com preço 59518.30, Stop Loss: 54756.84, Take Profit: 78564.16
# Sair de transação (long) em 2024-05-07 00:00:00 com preço 63149.30 (Inversão para Short), saldo atualizado: 39684944.98
# Entrar em transação (short normal) em 2024-05-07 00:00:00 com preço 63149.30, Stop Loss: 70727.22, Take Profit: 48624.96
# Sair de transação (short) em 2024-05-11 11:00:00 com preço 61444.27 (Take Profit Lateral), saldo atualizado: 40743739.31
# Entrar em transação (long normal) em 2024-05-12 20:00:00 com preço 61379.90, Stop Loss: 56469.51, Take Profit: 81021.47
# Sair de transação (long) em 2024-05-14 13:00:00 com preço 61550.10 (Inversão para Short), saldo atualizado: 40843643.26
# Entrar em transação (short normal) em 2024-05-14 13:00:00 com preço 61550.10, Stop Loss: 68936.11, Take Profit: 47393.58
# Sair de transação (short) em 2024-05-15 09:00:00 com preço 62120.30 (Inversão para Long), saldo atualizado: 40439253.16
# Entrar em transação (long normal) em 2024-05-15 09:00:00 com preço 62120.30, Stop Loss: 57150.68, Take Profit: 81998.80
# Sair de transação (long) em 2024-05-26 01:00:00 com preço 68953.53 (Take Profit Lateral), saldo atualizado: 44887571.01
# Entrar em transação (short normal) em 2024-05-26 22:00:00 com preço 68536.10, Stop Loss: 76760.43, Take Profit: 52772.80
# Sair de transação (short) em 2024-05-30 16:00:00 com preço 68558.90 (Inversão para Long), saldo atualizado: 44843919.53
# Entrar em transação (long normal) em 2024-05-30 16:00:00 com preço 68558.90, Stop Loss: 63074.19, Take Profit: 90497.75
# Sair de transação (long) em 2024-06-02 22:00:00 com preço 67815.20 (Inversão para Short), saldo atualizado: 44343275.93
# Entrar em transação (short normal) em 2024-06-02 22:00:00 com preço 67815.20, Stop Loss: 75953.02, Take Profit: 52217.70
# Sair de transação (short) em 2024-06-03 02:00:00 com preço 68498.20 (Inversão para Long), saldo atualizado: 43868440.89
# Entrar em transação (long normal) em 2024-06-03 02:00:00 com preço 68498.20, Stop Loss: 63018.34, Take Profit: 90417.62
# Sair de transação (long) em 2024-06-10 23:00:00 com preço 69492.10 (Inversão para Short), saldo atualizado: 44490724.69
# Entrar em transação (short normal) em 2024-06-10 23:00:00 com preço 69492.10, Stop Loss: 77831.15, Take Profit: 53508.92
# Sair de transação (short) em 2024-06-12 09:00:00 com preço 67615.81 (Take Profit Lateral), saldo atualizado: 45677737.23
# Entrar em transação (short normal) em 2024-06-13 03:00:00 com preço 67708.00, Stop Loss: 75832.96, Take Profit: 52135.16
# Sair de transação (short) em 2024-06-15 20:00:00 com preço 65879.88 (Take Profit Lateral), saldo atualizado: 46896419.26
# Entrar em transação (long normal) em 2024-06-16 15:00:00 com preço 66491.20, Stop Loss: 61171.90, Take Profit: 87768.38
# Sair de transação (long) em 2024-06-17 04:00:00 com preço 66188.90 (Inversão para Short), saldo atualizado: 46668267.64
# Entrar em transação (short normal) em 2024-06-17 04:00:00 com preço 66188.90, Stop Loss: 74131.57, Take Profit: 50965.45
# Sair de transação (short) em 2024-06-17 23:00:00 com preço 66631.60 (Inversão para Long), saldo atualizado: 46326367.05
# Entrar em transação (long normal) em 2024-06-17 23:00:00 com preço 66631.60, Stop Loss: 61301.07, Take Profit: 87953.71
# Sair de transação (long) em 2024-06-20 17:00:00 com preço 64863.40 (Inversão para Short), saldo atualizado: 45082575.13
# Entrar em transação (short normal) em 2024-06-20 17:00:00 com preço 64863.40, Stop Loss: 72647.01, Take Profit: 49944.82
# Sair de transação (short) em 2024-06-27 17:00:00 com preço 61687.30 (Inversão para Long), saldo atualizado: 47260533.00
# Entrar em transação (long normal) em 2024-06-27 17:00:00 com preço 61687.30, Stop Loss: 56752.32, Take Profit: 81427.24
# Sair de transação (long) em 2024-06-28 15:00:00 com preço 60881.30 (Inversão para Short), saldo atualizado: 46628105.91
# Entrar em transação (short normal) em 2024-06-28 15:00:00 com preço 60881.30, Stop Loss: 68187.06, Take Profit: 46878.60
# Sair de transação (short) em 2024-07-09 05:00:00 com preço 57264.70 (Inversão para Long), saldo atualizado: 49367283.88
# Entrar em transação (long normal) em 2024-07-09 05:00:00 com preço 57264.70, Stop Loss: 52683.52, Take Profit: 75589.40
# Sair de transação (long) em 2024-07-18 18:00:00 com preço 63534.70 (Inversão para Short), saldo atualizado: 54755056.43
# Entrar em transação (short normal) em 2024-07-18 18:00:00 com preço 63534.70, Stop Loss: 71158.86, Take Profit: 48921.72
# Sair de transação (short) em 2024-07-19 14:00:00 com preço 65099.10 (Inversão para Long), saldo atualizado: 53372229.34
# Entrar em transação (long normal) em 2024-07-19 14:00:00 com preço 65099.10, Stop Loss: 59891.17, Take Profit: 85930.81
# Sair de transação (long) em 2024-07-23 07:00:00 com preço 66503.00 (Inversão para Short), saldo atualizado: 54505785.11
# Entrar em transação (short normal) em 2024-07-23 07:00:00 com preço 66503.00, Stop Loss: 74483.36, Take Profit: 51207.31
# Sair de transação (short) em 2024-07-26 02:00:00 com preço 66400.00 (Inversão para Long), saldo atualizado: 54555298.66
# Entrar em transação (long normal) em 2024-07-26 02:00:00 com preço 66400.00, Stop Loss: 61088.00, Take Profit: 87648.00
# Sair de transação (long) em 2024-07-29 19:00:00 com preço 67399.90 (Inversão para Short), saldo atualizado: 55359111.85
# Entrar em transação (short normal) em 2024-07-29 19:00:00 com preço 67399.90, Stop Loss: 75487.89, Take Profit: 51897.92
# Sair de transação (short) em 2024-08-05 06:00:00 com preço 51897.92 (Take Profit), saldo atualizado: 68073992.66
# Entrar em transação (long normal) em 2024-08-06 21:00:00 com preço 56515.30, Stop Loss: 51994.08, Take Profit: 74600.20
# Sair de transação (long) em 2024-08-07 19:00:00 com preço 54784.30 (Inversão para Short), saldo atualizado: 65967846.45
# Entrar em transação (short normal) em 2024-08-07 19:00:00 com preço 54784.30, Stop Loss: 61358.42, Take Profit: 42183.91
# Sair de transação (short) em 2024-08-08 05:00:00 com preço 56746.10 (Inversão para Long), saldo atualizado: 63564112.18
# Entrar em transação (long normal) em 2024-08-08 05:00:00 com preço 56746.10, Stop Loss: 52206.41, Take Profit: 74904.85
# Sair de transação (long) em 2024-08-14 18:00:00 com preço 59131.20 (Inversão para Short), saldo atualizado: 66214585.16
# Entrar em transação (short normal) em 2024-08-14 18:00:00 com preço 59131.20, Stop Loss: 66226.94, Take Profit: 45531.02
# Sair de transação (short) em 2024-08-16 20:00:00 com preço 59653.90 (Inversão para Long), saldo atualizado: 65587087.16
# Entrar em transação (long normal) em 2024-08-16 20:00:00 com preço 59653.90, Stop Loss: 54881.59, Take Profit: 78743.15
# Sair de transação (long) em 2024-08-20 22:00:00 com preço 59257.70 (Inversão para Short), saldo atualizado: 65130632.56
# Entrar em transação (short normal) em 2024-08-20 22:00:00 com preço 59257.70, Stop Loss: 66368.62, Take Profit: 45628.43
# Sair de transação (short) em 2024-08-21 14:00:00 com preço 59898.00 (Inversão para Long), saldo atualizado: 64385421.76
# Entrar em transação (long normal) em 2024-08-21 14:00:00 com preço 59898.00, Stop Loss: 55106.16, Take Profit: 79065.36
# Sair de transação (long) em 2024-08-26 18:00:00 com preço 63361.60 (Inversão para Short), saldo atualizado: 68086712.06
# Entrar em transação (short normal) em 2024-08-26 18:00:00 com preço 63361.60, Stop Loss: 70964.99, Take Profit: 48788.43
# Sair de transação (short) em 2024-09-01 01:00:00 com preço 61650.84 (Take Profit Lateral), saldo atualizado: 69903265.54
# Entrar em transação (long normal) em 2024-09-02 21:00:00 com preço 58953.30, Stop Loss: 54237.04, Take Profit: 77818.36
# Sair de transação (long) em 2024-09-03 16:00:00 com preço 57700.40 (Inversão para Short), saldo atualizado: 68395758.68
# Entrar em transação (short normal) em 2024-09-03 16:00:00 com preço 57700.40, Stop Loss: 64624.45, Take Profit: 44429.31
# Sair de transação (short) em 2024-09-05 00:00:00 com preço 57937.80 (Inversão para Long), saldo atualizado: 68070677.93
# Entrar em transação (long normal) em 2024-09-05 00:00:00 com preço 57937.80, Stop Loss: 53302.78, Take Profit: 76477.90
# Sair de transação (long) em 2024-09-06 19:00:00 com preço 53302.78 (Stoploss), saldo atualizado: 62625023.69
# Entrar em transação (long normal) em 2024-09-09 02:00:00 com preço 55079.20, Stop Loss: 50672.86, Take Profit: 72704.54
# Sair de transação (long) em 2024-09-11 15:00:00 com preço 55949.70 (Inversão para Short), saldo atualizado: 63594425.04
# Entrar em transação (short normal) em 2024-09-11 15:00:00 com preço 55949.70, Stop Loss: 62663.66, Take Profit: 43081.27
# Total de trades: 384

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib

# Load the CSV with updated name
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')
# df['time'] = pd.to_datetime(df['time'], unit='s')

# Assign data to variables
timestamp = df['time']
open_price = df['open']
high_price = df['high']
low_price = df['low']
close_price = df['close']
# volume = df['Volume']

# Configurable parameters
emaShortLength = 11  # Short EMA period
emaLongLength = 55  # Long EMA period
rsiLength = 22  # RSI period
macdShort = 15  # MACD short period
macdLong = 34  # MACD long period
macdSignal = 11  # MACD signal period
adxLength = 16  # ADX period (equal to DI Length)
adxSmoothing = 13  # ADX Smoothing
adxThreshold = 12  # ADX level to indicate trend
bbLength = 14  # Bollinger Bands period
bbMultiplier = 1.7  # Bollinger Bands multiplier
lateralThreshold = 0.005  # Lateralization limit
stopgain_lateral_long = 1.11
stoploss_lateral_long = 0.973
stopgain_lateral_short = 0.973
stoploss_lateral_short = 1.09
stopgain_normal_long = 1.32
stoploss_normal_long = 0.92
stopgain_normal_short = 0.77
stoploss_normal_short = 1.12

# Functions for manual MACD calculation
def macd(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    # Initialize lists to store results
    tr = []
    previous_close = close[0]  # First closing value
    
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        # Calculate +DM and -DM
        current_plus_dm = high[i] - high[i-1]
        current_minus_dm = low[i-1] - low[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)
        
        # Calculate True Range (TR)
        tr1 = high[i] - low[i]
        tr2 = abs(high[i] - previous_close)
        tr3 = abs(low[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)
        
        # Update previous close
        previous_close = close[i]
    
    # Add a NaN value to the first position since there's no previous close for the first candle
    tr.insert(0, None)
    plus_dm.insert(0, None)
    minus_dm.insert(0, None)
    
    # Convert lists to pandas Series
    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)
    
    # Calculate ATR using the provided DI lookback
    atr = tr.rolling(window=di_lookback).mean()
    
    # Calculate +DI and -DI with DI lookback
    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    
    # Calculate DX
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    
    # Calculate ADX using specific smoothing
    adx = dx.ewm(alpha=1/adx_smoothing).mean()
    
    # Return calculated values
    return plus_di, minus_di, adx

# Calculate indicators
emaShort = np.ceil(talib.EMA(close_price, emaShortLength))
emaLong = np.ceil(talib.EMA(close_price, emaLongLength))

rsi = talib.RSI(close_price, timeperiod=rsiLength)
plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
adx = adx.fillna(0).astype(int)
macdLine, signalLine, macdHist = macd(close_price, macdShort, macdLong, macdSignal)
upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)

# Function to detect crossover (upward crossing)
def crossover(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] > series2_vals[1:]) & (series1_vals[:-1] <= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False to align lengths
    return pd.Series(cross, index=series1.index)

# Function to detect crossunder (downward crossing)
def crossunder(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] < series2_vals[1:]) & (series1_vals[:-1] >= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False to align lengths
    return pd.Series(cross, index=series1.index)

# Market trending condition (based on ADX)
trendingMarket = adx >= adxThreshold

# Lateralization conditions with Bollinger Bands
bandWidth = (upperBand - lowerBand) / middleBand

isLateral = bandWidth < lateralThreshold

# Define EMA crossover and crossunder states
ema_crossover_state = emaShort > emaLong
ema_crossunder_state = emaShort < emaLong

# Long and Short Conditions
longCondition = ema_crossover_state & (rsi < 60) & (macdHist > 0.5) & trendingMarket
shortCondition = ema_crossunder_state & (rsi > 40) & (macdHist < -0.5) & trendingMarket

# Initial balance and trading variables
saldo = 1_000_000  # Initial balance of 1,000,000
quantidade = 0  # Quantity of BTC bought/sold in the transaction
position_open = False  # Indicates if we are in a transaction
current_position = None  # 'long' or 'short'
entry_price = None  # Entry price of the position
orders = []
trade_count = 0  # Trade counter
commission = 0.00032  # 0.032%

# Loop to check and execute orders
for i in range(len(df)):
    adjusted_timestamp = timestamp[i]
    
    # Determine the lateralization condition of the previous candle
    if i == 0:
        lateral_prev = False  # No previous candle for the first candle
    else:
        lateral_prev = isLateral[i-1]
    
    if lateral_prev:
        if not position_open:
            if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i] and longCondition[i]:
                entry_price = close_price[i]
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                quantidade = saldo / entry_price
                # Apply commission on buy
                saldo -= saldo * commission
                orders.append(f"enter long position (lateral) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossLong}, Take Profit: {takeProfitLong}")
                position_open = True
                current_position = 'long'
                trade_count += 1
            elif (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i] and shortCondition[i]:
                entry_price = close_price[i]
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short
                quantidade = saldo / entry_price
                # Apply commission on buy
                saldo -= saldo * commission
                orders.append(f"enter short position (lateral) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossShort}, Take Profit: {takeProfitShort}")
                position_open = True
                current_position = 'short'
                trade_count += 1
        elif position_open:
            if current_position == 'long':
                if (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i]:
                    if shortCondition[i]:
                        saldo = quantidade * close_price[i]
                        # Apply commission on sell
                        saldo -= saldo * commission
                        orders.append(f"exit long position at {adjusted_timestamp} with price {close_price[i]} (Reverse to Short), updated balance: {saldo:.2f}")
                        entry_price = close_price[i]
                        stopLossShort = entry_price * stoploss_lateral_short
                        takeProfitShort = entry_price * stopgain_lateral_short
                        quantidade = saldo / entry_price
                        # Apply commission on buy
                        saldo -= saldo * commission
                        orders.append(f"enter short position (lateral) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossShort}, Take Profit: {takeProfitShort}")
                        current_position = 'short'
                        trade_count += 1
            elif current_position == 'short':
                if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i]:
                    if longCondition[i]:
                        saldo = saldo + (quantidade * (entry_price - close_price[i]))
                        # Apply commission on sell
                        saldo -= saldo * commission
                        orders.append(f"exit short position at {adjusted_timestamp} with price {close_price[i]} (Reverse to Long), updated balance: {saldo:.2f}")
                        entry_price = close_price[i]
                        stopLossLong = entry_price * stoploss_lateral_long
                        takeProfitLong = entry_price * stopgain_lateral_long
                        quantidade = saldo / entry_price
                        # Apply commission on buy
                        saldo -= saldo * commission
                        orders.append(f"enter long position (lateral) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossLong}, Take Profit: {takeProfitLong}")
                        current_position = 'long'
                        trade_count += 1
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_lateral_long
                takeProfitLong = entry_price * stopgain_lateral_long
                if low_price[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"exit long position at {adjusted_timestamp} with price {stopLossLong} (Stoploss Lateral), updated balance: {saldo:.2f}")
                    position_open = False
                elif high_price[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"exit long position at {adjusted_timestamp} with price {takeProfitLong} (Take Profit Lateral), updated balance: {saldo:.2f}")
                    position_open = False
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_lateral_short
                takeProfitShort = entry_price * stopgain_lateral_short
                if high_price[i] >= stopLossShort:
                    saldo = saldo - (quantidade * (stopLossShort - entry_price))
                    orders.append(f"exit short position at {adjusted_timestamp} with price {close_price[i]} (Stoploss Lateral), updated balance: {saldo:.2f}")
                    position_open = False
                elif low_price[i] <= takeProfitShort:
                    saldo = saldo + (quantidade * (entry_price - takeProfitShort))
                    orders.append(f"exit short position at {adjusted_timestamp} with price {close_price[i]} (Take Profit Lateral), updated balance: {saldo:.2f}")
                    position_open = False    
    else:  # Not lateral
        if not position_open:
            if longCondition[i]:
                entry_price = close_price[i]
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                quantidade = saldo / entry_price
                orders.append(f"enter long position (normal) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossLong}, Take Profit: {takeProfitLong}")
                position_open = True
                current_position = 'long'
                trade_count += 1
            elif shortCondition[i]:
                entry_price = close_price[i]
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short
                quantidade = saldo / entry_price
                orders.append(f"enter short position (normal) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossShort}, Take Profit: {takeProfitShort}")
                position_open = True
                current_position = 'short'
                trade_count += 1
        elif position_open:
            if current_position == 'long':
                if shortCondition[i]:
                    saldo = quantidade * close_price[i]
                    orders.append(f"exit long position at {adjusted_timestamp} with price {close_price[i]} (Reverse to Short), updated balance: {saldo:.2f}")
                    entry_price = close_price[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    orders.append(f"enter short position (normal) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossShort}, Take Profit: {takeProfitShort}")
                    current_position = 'short'
                    trade_count += 1
            elif current_position == 'short':
                if longCondition[i]:
                    saldo = saldo + (quantidade * (entry_price - close_price[i]))
                    orders.append(f"exit short position at {adjusted_timestamp} with price {close_price[i]} (Reverse to Long), updated balance: {saldo:.2f}")
                    entry_price = close_price[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    orders.append(f"enter long position (normal) at {adjusted_timestamp} with price {entry_price}, Stop Loss: {stopLossLong}, Take Profit: {takeProfitLong}")
                    current_position = 'long'
                    trade_count += 1
            if current_position == 'long':
                stopLossLong = entry_price * stoploss_normal_long
                takeProfitLong = entry_price * stopgain_normal_long
                if low_price[i] <= stopLossLong:
                    saldo = quantidade * stopLossLong
                    orders.append(f"exit long position at {adjusted_timestamp} with price {stopLossLong} (Stoploss), updated balance: {saldo:.2f}")
                    position_open = False
                elif high_price[i] >= takeProfitLong:
                    saldo = quantidade * takeProfitLong
                    orders.append(f"exit long position at {adjusted_timestamp} with price {takeProfitLong} (Take Profit), updated balance: {saldo:.2f}")
                    position_open = False
            elif current_position == 'short':
                stopLossShort = entry_price * stoploss_normal_short
                takeProfitShort = entry_price * stopgain_normal_short
                if high_price[i] >= stopLossShort:
                    saldo = saldo - (quantidade * (stopLossShort - entry_price))
                    orders.append(f"exit short position at {adjusted_timestamp} with price {stopLossShort} (Stoploss), updated balance: {saldo:.2f}")
                    position_open = False
                elif low_price[i] <= takeProfitShort:
                    saldo = saldo + (quantidade * (entry_price - takeProfitShort))
                    orders.append(f"exit short position at {adjusted_timestamp} with price {takeProfitShort} (Take Profit), updated balance: {saldo:.2f}")
                    position_open = False

# Display the generated orders
for order in orders:
    print(order)

# Display the total number of trades
print(f"Total trades: {trade_count}")
# Out:
# enter short position (normal) at 2020-03-27 16:00:00 with price 6638.5, Stop Loss: 7435.120000000001, Take Profit: 5111.645
# exit short position at 2020-03-30 12:00:00 with price 6302.5 (Reverse to Long), updated balance: 1050613.84
# enter long position (normal) at 2020-03-30 12:00:00 with price 6302.5, Stop Loss: 5798.3, Take Profit: 8319.300000000001
# exit long position at 2020-04-01 06:00:00 with price 6289.5 (Reverse to Short), updated balance: 1048446.77
# enter short position (normal) at 2020-04-01 06:00:00 with price 6289.5, Stop Loss: 7044.240000000001, Take Profit: 4842.915
# exit short position at 2020-04-02 17:00:00 with price 7044.240000000001 (Stoploss), updated balance: 922633.16
# enter long position (normal) at 2020-04-02 18:00:00 with price 6787.0, Stop Loss: 6244.04, Take Profit: 8958.84
# exit long position at 2020-04-10 03:00:00 with price 7175.5 (Reverse to Short), updated balance: 975446.33
# enter short position (normal) at 2020-04-10 03:00:00 with price 7175.5, Stop Loss: 8036.56, Take Profit: 5525.135
# exit short position at 2020-04-12 22:00:00 with price 7020.0 (Reverse to Long), updated balance: 996585.19
# enter long position (normal) at 2020-04-12 22:00:00 with price 7020.0, Stop Loss: 6458.400000000001, Take Profit: 9266.4
# exit long position at 2020-04-13 06:00:00 with price 6727.0 (Reverse to Short), updated balance: 954989.82
# enter short position (normal) at 2020-04-13 06:00:00 with price 6727.0, Stop Loss: 7534.240000000001, Take Profit: 5179.79
# exit short position at 2020-04-14 05:00:00 with price 6881.0 (Reverse to Long), updated balance: 933127.41
# enter long position (normal) at 2020-04-14 05:00:00 with price 6881.0, Stop Loss: 6330.52, Take Profit: 9082.92
# exit long position at 2020-04-15 11:00:00 with price 6774.0 (Reverse to Short), updated balance: 918617.22
# enter short position (normal) at 2020-04-15 11:00:00 with price 6774.0, Stop Loss: 7586.880000000001, Take Profit: 5215.9800000000005
# exit short position at 2020-04-16 10:00:00 with price 6948.0 (Reverse to Long), updated balance: 895021.21
# enter long position (normal) at 2020-04-16 10:00:00 with price 6948.0, Stop Loss: 6392.16, Take Profit: 9171.36
# exit long position at 2020-04-20 12:00:00 with price 7037.0 (Reverse to Short), updated balance: 906485.93
# enter short position (normal) at 2020-04-20 12:00:00 with price 7037.0, Stop Loss: 7881.4400000000005, Take Profit: 5418.49
# exit short position at 2020-04-23 05:00:00 with price 7097.5 (Reverse to Long), updated balance: 898692.50
# enter long position (normal) at 2020-04-23 05:00:00 with price 7097.5, Stop Loss: 6529.700000000001, Take Profit: 9368.7
# exit long position at 2020-04-30 05:00:00 with price 9368.7 (Take Profit), updated balance: 1186274.09
# enter long position (normal) at 2020-05-01 11:00:00 with price 8994.0, Stop Loss: 8274.48, Take Profit: 11872.08
# exit long position at 2020-05-04 00:00:00 with price 8806.0 (Reverse to Short), updated balance: 1161477.62
# enter short position (normal) at 2020-05-04 00:00:00 with price 8806.0, Stop Loss: 9862.720000000001, Take Profit: 6780.62
# exit short position at 2020-05-04 21:00:00 with price 8938.0 (Reverse to Long), updated balance: 1144067.32
# enter long position (normal) at 2020-05-04 21:00:00 with price 8938.0, Stop Loss: 8222.960000000001, Take Profit: 11798.16
# exit long position at 2020-05-09 22:00:00 with price 9604.5 (Reverse to Short), updated balance: 1229379.57
# enter short position (normal) at 2020-05-09 22:00:00 with price 9604.5, Stop Loss: 10757.04, Take Profit: 7395.465
# exit short position at 2020-05-12 18:00:00 with price 8891.5 (Reverse to Long), updated balance: 1320643.83
# enter long position (normal) at 2020-05-12 18:00:00 with price 8891.5, Stop Loss: 8180.18, Take Profit: 11736.78
# exit long position at 2020-05-15 23:00:00 with price 9315.0 (Reverse to Short), updated balance: 1383545.78
# enter short position (normal) at 2020-05-15 23:00:00 with price 9315.0, Stop Loss: 10432.800000000001, Take Profit: 7172.55
# exit short position at 2020-05-16 12:00:00 with price 9466.5 (Reverse to Long), updated balance: 1361043.67
# enter long position (normal) at 2020-05-16 12:00:00 with price 9466.5, Stop Loss: 8709.18, Take Profit: 12495.78
# exit long position at 2020-05-16 16:00:00 with price 9383.0 (Reverse to Short), updated balance: 1349038.48
# enter short position (normal) at 2020-05-16 16:00:00 with price 9383.0, Stop Loss: 10508.960000000001, Take Profit: 7224.91
# exit short position at 2020-05-17 02:00:00 with price 9510.0 (Reverse to Long), updated balance: 1330779.08
# enter long position (normal) at 2020-05-17 02:00:00 with price 9510.0, Stop Loss: 8749.2, Take Profit: 12553.2
# exit long position at 2020-05-19 04:00:00 with price 9535.5 (Reverse to Short), updated balance: 1334347.42
# enter short position (normal) at 2020-05-19 04:00:00 with price 9535.5, Stop Loss: 10679.76, Take Profit: 7342.335
# exit short position at 2020-05-19 09:00:00 with price 9788.5 (Reverse to Long), updated balance: 1298943.94
# enter long position (normal) at 2020-05-19 09:00:00 with price 9788.5, Stop Loss: 9005.42, Take Profit: 12920.82
# exit long position at 2020-05-20 16:00:00 with price 9493.5 (Reverse to Short), updated balance: 1259797.14
# enter short position (normal) at 2020-05-20 16:00:00 with price 9493.5, Stop Loss: 10632.720000000001, Take Profit: 7309.995
# exit short position at 2020-05-24 08:00:00 with price 9263.0 (Reverse to Long), updated balance: 1290384.72
# enter long position (normal) at 2020-05-24 08:00:00 with price 9263.0, Stop Loss: 8521.960000000001, Take Profit: 12227.16
# exit long position at 2020-05-24 12:00:00 with price 9157.5 (Reverse to Short), updated balance: 1275688.02
# enter short position (normal) at 2020-05-24 12:00:00 with price 9157.5, Stop Loss: 10256.400000000001, Take Profit: 7051.275000000001
# exit short position at 2020-05-27 21:00:00 with price 9061.5 (Reverse to Long), updated balance: 1289061.32
# enter long position (normal) at 2020-05-27 21:00:00 with price 9061.5, Stop Loss: 8336.58, Take Profit: 11961.18
# exit long position at 2020-05-31 23:00:00 with price 9449.5 (Reverse to Short), updated balance: 1344257.02
# enter short position (normal) at 2020-05-31 23:00:00 with price 9449.5, Stop Loss: 10583.44, Take Profit: 7276.115
# exit short position at 2020-06-04 04:00:00 with price 9644.0 (Reverse to Long), updated balance: 1316588.04
# enter long position (normal) at 2020-06-04 04:00:00 with price 9644.0, Stop Loss: 8872.48, Take Profit: 12730.08
# exit long position at 2020-06-05 22:00:00 with price 9677.0 (Reverse to Short), updated balance: 1321093.16
# enter short position (normal) at 2020-06-05 22:00:00 with price 9677.0, Stop Loss: 10838.240000000002, Take Profit: 7451.29
# exit short position at 2020-06-07 23:00:00 with price 9741.0 (Reverse to Long), updated balance: 1312355.96
# enter long position (normal) at 2020-06-07 23:00:00 with price 9741.0, Stop Loss: 8961.720000000001, Take Profit: 12858.12
# exit long position at 2020-06-09 10:00:00 with price 9672.0 (Reverse to Short), updated balance: 1303059.93
# enter short position (normal) at 2020-06-09 10:00:00 with price 9672.0, Stop Loss: 10832.640000000001, Take Profit: 7447.4400000000005
# exit short position at 2020-06-09 15:00:00 with price 9714.5 (Reverse to Long), updated balance: 1297334.12
# enter long position (normal) at 2020-06-09 15:00:00 with price 9714.5, Stop Loss: 8937.34, Take Profit: 12823.140000000001
# exit long position at 2020-06-13 14:00:00 with price 9452.2085 (Stoploss Lateral), updated balance: 1262306.10
# enter short position (normal) at 2020-06-14 13:00:00 with price 9410.0, Stop Loss: 10539.2, Take Profit: 7245.7
# exit short position at 2020-06-15 21:00:00 with price 9427.5 (Reverse to Long), updated balance: 1259958.56
# enter long position (normal) at 2020-06-15 21:00:00 with price 9427.5, Stop Loss: 8673.300000000001, Take Profit: 12444.300000000001
# exit long position at 2020-06-17 20:00:00 with price 9378.5 (Reverse to Short), updated balance: 1253409.85
# enter short position (normal) at 2020-06-17 20:00:00 with price 9378.5, Stop Loss: 10503.920000000002, Take Profit: 7221.445000000001
# exit short position at 2020-06-21 02:00:00 with price 9370.5 (Reverse to Long), updated balance: 1254479.03
# enter long position (normal) at 2020-06-21 02:00:00 with price 9370.5, Stop Loss: 8620.86, Take Profit: 12369.060000000001
# exit long position at 2020-06-21 21:00:00 with price 9336.0 (Reverse to Short), updated balance: 1249860.33
# enter short position (normal) at 2020-06-21 21:00:00 with price 9336.0, Stop Loss: 10456.320000000002, Take Profit: 7188.72
# exit short position at 2020-06-22 03:00:00 with price 9382.5 (Reverse to Long), updated balance: 1243635.12
# enter long position (normal) at 2020-06-22 03:00:00 with price 9382.5, Stop Loss: 8631.9, Take Profit: 12384.900000000001
# exit long position at 2020-06-26 09:00:00 with price 9214.5 (Reverse to Short), updated balance: 1221367.00
# enter short position (normal) at 2020-06-26 09:00:00 with price 9214.5, Stop Loss: 10320.240000000002, Take Profit: 7095.165
# exit short position at 2020-06-29 01:00:00 with price 9144.0 (Reverse to Long), updated balance: 1230711.66
# enter long position (normal) at 2020-06-29 01:00:00 with price 9144.0, Stop Loss: 8412.48, Take Profit: 12070.08
# exit long position at 2020-06-29 08:00:00 with price 9092.5 (Reverse to Short), updated balance: 1223780.15
# enter short position (normal) at 2020-06-29 08:00:00 with price 9092.5, Stop Loss: 10183.6, Take Profit: 7001.225
# exit short position at 2020-06-29 22:00:00 with price 9186.5 (Reverse to Long), updated balance: 1211128.48
# enter long position (normal) at 2020-06-29 22:00:00 with price 9186.5, Stop Loss: 8451.58, Take Profit: 12126.18
# exit long position at 2020-07-02 21:00:00 with price 9122.5 (Reverse to Short), updated balance: 1202690.86
# enter short position (normal) at 2020-07-02 21:00:00 with price 9122.5, Stop Loss: 10217.2, Take Profit: 7024.325
# exit short position at 2020-07-04 20:00:00 with price 9127.5 (Reverse to Long), updated balance: 1202031.67
# enter long position (normal) at 2020-07-04 20:00:00 with price 9127.5, Stop Loss: 8397.300000000001, Take Profit: 12048.300000000001
# exit long position at 2020-07-05 06:00:00 with price 9059.0 (Reverse to Short), updated balance: 1193010.67
# enter short position (normal) at 2020-07-05 06:00:00 with price 9059.0, Stop Loss: 10146.080000000002, Take Profit: 6975.43
# exit short position at 2020-07-08 12:00:00 with price 9291.0 (Reverse to Long), updated balance: 1162457.80
# enter long position (normal) at 2020-07-08 12:00:00 with price 9291.0, Stop Loss: 8547.720000000001, Take Profit: 12264.12
# exit long position at 2020-07-09 20:00:00 with price 9233.5 (Reverse to Short), updated balance: 1155263.60
# enter short position (normal) at 2020-07-09 20:00:00 with price 9233.5, Stop Loss: 10341.52, Take Profit: 7109.795
# exit short position at 2020-07-11 07:00:00 with price 9263.0 (Reverse to Long), updated balance: 1151572.66
# enter long position (normal) at 2020-07-11 07:00:00 with price 9263.0, Stop Loss: 8521.960000000001, Take Profit: 12227.16
# exit long position at 2020-07-11 11:00:00 with price 9199.5 (Reverse to Short), updated balance: 1143678.36
# enter short position (normal) at 2020-07-11 11:00:00 with price 9199.5, Stop Loss: 10303.44, Take Profit: 7083.615
# exit short position at 2020-07-12 03:00:00 with price 9267.0 (Reverse to Long), updated balance: 1135286.79
# enter long position (normal) at 2020-07-12 03:00:00 with price 9267.0, Stop Loss: 8525.640000000001, Take Profit: 12232.44
# exit long position at 2020-07-12 14:00:00 with price 9215.5 (Reverse to Short), updated balance: 1128977.60
# enter short position (normal) at 2020-07-12 14:00:00 with price 9215.5, Stop Loss: 10321.36, Take Profit: 7095.935
# exit short position at 2020-07-13 00:00:00 with price 9272.0 (Reverse to Long), updated balance: 1122055.86
# enter long position (normal) at 2020-07-13 00:00:00 with price 9272.0, Stop Loss: 8530.24, Take Profit: 12239.04
# exit long position at 2020-07-14 00:00:00 with price 9222.0 (Reverse to Short), updated balance: 1116005.09
# enter short position (normal) at 2020-07-14 00:00:00 with price 9222.0, Stop Loss: 10328.640000000001, Take Profit: 7100.9400000000005
# exit short position at 2020-07-15 00:00:00 with price 9254.0 (Reverse to Long), updated balance: 1112132.59
# enter long position (normal) at 2020-07-15 00:00:00 with price 9254.0, Stop Loss: 8513.68, Take Profit: 12215.28
# exit long position at 2020-07-15 19:00:00 with price 9183.5 (Reverse to Short), updated balance: 1103660.00
# enter short position (normal) at 2020-07-15 19:00:00 with price 9183.5, Stop Loss: 10285.52, Take Profit: 7071.295
# exit short position at 2020-07-19 21:00:00 with price 9173.0 (Reverse to Long), updated balance: 1104921.88
# enter long position (normal) at 2020-07-19 21:00:00 with price 9173.0, Stop Loss: 8439.16, Take Profit: 12108.36
# exit long position at 2020-08-02 04:00:00 with price 12108.36 (Take Profit), updated balance: 1458496.88
# enter short position (normal) at 2020-08-02 10:00:00 with price 11259.0, Stop Loss: 12610.080000000002, Take Profit: 8669.43
# exit short position at 2020-08-03 17:00:00 with price 11423.0 (Reverse to Long), updated balance: 1437252.23
# enter long position (normal) at 2020-08-03 17:00:00 with price 11423.0, Stop Loss: 10509.16, Take Profit: 15078.36
# exit long position at 2020-08-04 08:00:00 with price 11251.0 (Reverse to Short), updated balance: 1415611.03
# enter short position (normal) at 2020-08-04 08:00:00 with price 11251.0, Stop Loss: 12601.12, Take Profit: 8663.27
# exit short position at 2020-08-05 09:00:00 with price 11389.5 (Reverse to Long), updated balance: 1398184.84
# enter long position (normal) at 2020-08-05 09:00:00 with price 11389.5, Stop Loss: 10478.34, Take Profit: 15034.140000000001
# exit long position at 2020-08-07 20:00:00 with price 11566.5 (Reverse to Short), updated balance: 1419913.51
# enter short position (normal) at 2020-08-07 20:00:00 with price 11566.5, Stop Loss: 12954.480000000001, Take Profit: 8906.205
# exit short position at 2020-08-08 11:00:00 with price 11774.5 (Reverse to Long), updated balance: 1394379.25
# enter long position (normal) at 2020-08-08 11:00:00 with price 11774.5, Stop Loss: 10832.54, Take Profit: 15542.34
# exit long position at 2020-08-09 13:00:00 with price 11620.5 (Reverse to Short), updated balance: 1376142.01
# enter short position (normal) at 2020-08-09 13:00:00 with price 11620.5, Stop Loss: 13014.960000000001, Take Profit: 8947.785
# exit short position at 2020-08-10 10:00:00 with price 11690.5 (Reverse to Long), updated balance: 1367852.35
# enter long position (normal) at 2020-08-10 10:00:00 with price 11690.5, Stop Loss: 10755.26, Take Profit: 15431.460000000001
# exit short position at 2020-09-25 05:00:00 with price 10641.0 (Reverse to Long), updated balance: 1568650.67
# enter long position (normal) at 2020-09-25 05:00:00 with price 10641.0, Stop Loss: 9789.720000000001, Take Profit: 14046.12
# exit long position at 2020-09-29 04:00:00 with price 10694.0 (Reverse to Short), updated balance: 1576463.70
# enter short position (normal) at 2020-09-29 04:00:00 with price 10694.0, Stop Loss: 11977.28, Take Profit: 8234.380000000001
# exit short position at 2020-09-30 00:00:00 with price 10810.5 (Reverse to Long), updated balance: 1559289.77
# enter long position (normal) at 2020-09-30 00:00:00 with price 10810.5, Stop Loss: 9945.66, Take Profit: 14269.86
# exit long position at 2020-09-30 06:00:00 with price 10720.5 (Reverse to Short), updated balance: 1546308.31
# enter short position (normal) at 2020-09-30 06:00:00 with price 10720.5, Stop Loss: 12006.960000000001, Take Profit: 8254.785
# exit short position at 2020-10-01 01:00:00 with price 10822.0 (Reverse to Long), updated balance: 1531668.10
# enter long position (normal) at 2020-10-01 01:00:00 with price 10822.0, Stop Loss: 9956.24, Take Profit: 14285.04
# exit long position at 2020-10-01 22:00:00 with price 10603.0 (Reverse to Short), updated balance: 1500672.42
# enter short position (normal) at 2020-10-01 22:00:00 with price 10603.0, Stop Loss: 11875.36, Take Profit: 8164.31
# exit short position at 2020-10-04 09:00:00 with price 10591.0 (Reverse to Long), updated balance: 1502370.81
# enter long position (normal) at 2020-10-04 09:00:00 with price 10591.0, Stop Loss: 9743.720000000001, Take Profit: 13980.12
# exit long position at 2020-10-06 22:00:00 with price 10585.0 (Reverse to Short), updated balance: 1501519.69
# enter short position (normal) at 2020-10-06 22:00:00 with price 10585.0, Stop Loss: 11855.2, Take Profit: 8150.45
# exit short position at 2020-10-07 23:00:00 with price 10656.5 (Reverse to Long), updated balance: 1491377.16
# enter long position (normal) at 2020-10-07 23:00:00 with price 10656.5, Stop Loss: 9803.98, Take Profit: 14066.58
# exit long position at 2020-10-08 10:00:00 with price 10604.5 (Reverse to Short), updated balance: 1484099.76
# enter short position (normal) at 2020-10-08 10:00:00 with price 10604.5, Stop Loss: 11877.04, Take Profit: 8165.465
# exit short position at 2020-10-12 23:00:00 with price 11545.0 (Reverse to Long), updated balance: 1352476.79
# enter long position (normal) at 2020-10-12 23:00:00 with price 11545.0, Stop Loss: 10621.4, Take Profit: 15239.400000000001
# exit long position at 2020-10-13 19:00:00 with price 11401.5 (Reverse to Short), updated balance: 1335666.01
# enter short position (normal) at 2020-10-13 19:00:00 with price 11401.5, Stop Loss: 12769.680000000002, Take Profit: 8779.155
# exit short position at 2020-10-14 13:00:00 with price 11532.0 (Reverse to Long), updated balance: 1320378.16
# enter long position (normal) at 2020-10-14 13:00:00 with price 11532.0, Stop Loss: 10609.44, Take Profit: 15222.240000000002
# exit long position at 2020-10-14 15:00:00 with price 11322.5 (Reverse to Short), updated balance: 1296391.06
# enter short position (normal) at 2020-10-14 15:00:00 with price 11322.5, Stop Loss: 12681.2, Take Profit: 8718.325
# exit short position at 2020-10-15 18:00:00 with price 11468.0 (Reverse to Long), updated balance: 1279731.77
# enter long position (normal) at 2020-10-15 18:00:00 with price 11468.0, Stop Loss: 10550.560000000001, Take Profit: 15137.76
# exit long position at 2020-10-16 06:00:00 with price 11326.0 (Reverse to Short), updated balance: 1263885.77
# enter short position (normal) at 2020-10-16 06:00:00 with price 11326.0, Stop Loss: 12685.12, Take Profit: 8721.02
# exit short position at 2020-10-18 03:00:00 with price 11366.0 (Reverse to Long), updated balance: 1259422.11
# enter long position (normal) at 2020-10-18 03:00:00 with price 11366.0, Stop Loss: 10456.720000000001, Take Profit: 15003.12
# exit long position at 2020-10-26 18:00:00 with price 12956.0 (Reverse to Short), updated balance: 1435603.80
# enter short position (normal) at 2020-10-26 18:00:00 with price 12956.0, Stop Loss: 14510.720000000001, Take Profit: 9976.12
# exit short position at 2020-10-27 01:00:00 with price 13083.5 (Reverse to Long), updated balance: 1421476.02
# enter long position (normal) at 2020-10-27 01:00:00 with price 13083.5, Stop Loss: 12036.82, Take Profit: 17270.22
# exit long position at 2020-10-28 16:00:00 with price 13146.5 (Reverse to Short), updated balance: 1428320.75
# enter short position (normal) at 2020-10-28 16:00:00 with price 13146.5, Stop Loss: 14724.080000000002, Take Profit: 10122.805
# exit short position at 2020-10-29 16:00:00 with price 13534.5 (Reverse to Long), updated balance: 1386165.92
# enter long position (normal) at 2020-10-29 16:00:00 with price 13534.5, Stop Loss: 12451.74, Take Profit: 17865.54
# exit long position at 2020-10-30 08:00:00 with price 13237.0 (Reverse to Short), updated balance: 1355696.80
# enter short position (normal) at 2020-10-30 08:00:00 with price 13237.0, Stop Loss: 14825.44, Take Profit: 10192.49
# exit short position at 2020-10-30 15:00:00 with price 13532.5 (Reverse to Long), updated balance: 1325432.51
# enter long position (normal) at 2020-10-30 15:00:00 with price 13532.5, Stop Loss: 12449.9, Take Profit: 17862.9
# exit long position at 2020-11-02 09:00:00 with price 13560.0 (Reverse to Short), updated balance: 1328125.98
# enter short position (normal) at 2020-11-02 09:00:00 with price 13560.0, Stop Loss: 15187.2, Take Profit: 10441.2
# exit short position at 2020-11-03 15:00:00 with price 13705.5 (Reverse to Long), updated balance: 1313875.07
# enter long position (normal) at 2020-11-03 15:00:00 with price 13705.5, Stop Loss: 12609.060000000001, Take Profit: 18091.260000000002
# exit long position at 2020-11-08 00:00:00 with price 14911.0 (Reverse to Short), updated balance: 1429440.09
# enter short position (normal) at 2020-11-08 00:00:00 with price 14911.0, Stop Loss: 16700.320000000003, Take Profit: 11481.470000000001
# exit short position at 2020-11-08 14:00:00 with price 15341.0 (Reverse to Long), updated balance: 1388218.23
# enter long position (normal) at 2020-11-08 14:00:00 with price 15341.0, Stop Loss: 14113.720000000001, Take Profit: 20250.120000000003
# exit long position at 2020-11-09 17:00:00 with price 15225.5 (Reverse to Short), updated balance: 1377766.55
# enter short position (normal) at 2020-11-09 17:00:00 with price 15225.5, Stop Loss: 17052.56, Take Profit: 11723.635
# exit short position at 2020-11-11 13:00:00 with price 15574.5 (Reverse to Long), updated balance: 1346185.28
# enter long position (normal) at 2020-11-11 13:00:00 with price 15574.5, Stop Loss: 14328.54, Take Profit: 20558.34
# exit long position at 2020-11-14 11:00:00 with price 15916.5 (Reverse to Short), updated balance: 1375746.13
# enter short position (normal) at 2020-11-14 11:00:00 with price 15916.5, Stop Loss: 17826.480000000003, Take Profit: 12255.705
# exit short position at 2020-11-15 09:00:00 with price 16059.0 (Reverse to Long), updated balance: 1363429.11
# enter long position (normal) at 2020-11-15 09:00:00 with price 16059.0, Stop Loss: 14774.28, Take Profit: 21197.88
# exit long position at 2020-11-15 18:00:00 with price 15890.0 (Reverse to Short), updated balance: 1349080.80
# enter short position (normal) at 2020-11-15 18:00:00 with price 15890.0, Stop Loss: 17796.800000000003, Take Profit: 12235.300000000001
# exit short position at 2020-11-16 11:00:00 with price 16233.0 (Reverse to Long), updated balance: 1319959.67
# enter long position (normal) at 2020-11-16 11:00:00 with price 16233.0, Stop Loss: 14934.36, Take Profit: 21427.56
# exit long position at 2020-11-22 10:00:00 with price 18212.5 (Reverse to Short), updated balance: 1480919.45
# enter short position (normal) at 2020-11-22 10:00:00 with price 18212.5, Stop Loss: 20398.000000000004, Take Profit: 14023.625
# exit short position at 2020-11-22 20:00:00 with price 18586.0 (Reverse to Long), updated balance: 1450548.92
# enter long position (normal) at 2020-11-22 20:00:00 with price 18586.0, Stop Loss: 17099.12, Take Profit: 24533.52
# exit long position at 2020-11-23 01:00:00 with price 18248.5 (Reverse to Short), updated balance: 1424208.65
# enter short position (normal) at 2020-11-23 01:00:00 with price 18248.5, Stop Loss: 20438.320000000003, Take Profit: 14051.345000000001
# exit short position at 2020-11-23 06:00:00 with price 18564.0 (Reverse to Long), updated balance: 1399585.37
# enter long position (normal) at 2020-11-23 06:00:00 with price 18564.0, Stop Loss: 17078.88, Take Profit: 24504.48
# exit long position at 2020-11-23 20:00:00 with price 18395.5 (Reverse to Short), updated balance: 1386881.75
# enter short position (normal) at 2020-11-23 20:00:00 with price 18395.5, Stop Loss: 20602.960000000003, Take Profit: 14164.535
# exit short position at 2020-11-24 10:00:00 with price 18867.0 (Reverse to Long), updated balance: 1351334.21
# enter long position (normal) at 2020-11-24 10:00:00 with price 18867.0, Stop Loss: 17357.64, Take Profit: 24904.440000000002
# exit long position at 2020-11-26 03:00:00 with price 17357.64 (Stoploss), updated balance: 1243227.47
# enter short position (normal) at 2020-11-26 20:00:00 with price 17137.0, Stop Loss: 19193.440000000002, Take Profit: 13195.49
# exit short position at 2020-11-28 20:00:00 with price 17680.0 (Reverse to Long), updated balance: 1203834.78
# enter long position (normal) at 2020-11-28 20:00:00 with price 17680.0, Stop Loss: 16265.6, Take Profit: 23337.600000000002
# exit long position at 2020-12-02 03:00:00 with price 18604.0 (Reverse to Short), updated balance: 1266750.13
# enter short position (normal) at 2020-12-02 03:00:00 with price 18604.0, Stop Loss: 20836.480000000003, Take Profit: 14325.08
# exit short position at 2020-12-02 09:00:00 with price 19053.0 (Reverse to Long), updated balance: 1236177.63
# enter long position (normal) at 2020-12-02 09:00:00 with price 19053.0, Stop Loss: 17528.760000000002, Take Profit: 25149.960000000003
# exit long position at 2020-12-04 12:00:00 with price 19018.0 (Reverse to Short), updated balance: 1233906.79
# enter short position (normal) at 2020-12-04 12:00:00 with price 19018.0, Stop Loss: 21300.160000000003, Take Profit: 14643.86
# exit short position at 2020-12-05 17:00:00 with price 19123.5 (Reverse to Long), updated balance: 1227061.85
# enter long position (normal) at 2020-12-05 17:00:00 with price 19123.5, Stop Loss: 17593.62, Take Profit: 25243.02
# exit long position at 2020-12-06 13:00:00 with price 18949.0 (Reverse to Short), updated balance: 1215865.03
# enter short position (normal) at 2020-12-06 13:00:00 with price 18949.0, Stop Loss: 21222.88, Take Profit: 14590.73
# exit short position at 2020-12-06 20:00:00 with price 19170.0 (Reverse to Long), updated balance: 1201684.54
# enter long position (normal) at 2020-12-06 20:00:00 with price 19170.0, Stop Loss: 17636.4, Take Profit: 25304.4
# exit long position at 2020-12-07 19:00:00 with price 18970.0 (Reverse to Short), updated balance: 1189147.40
# enter short position (normal) at 2020-12-07 19:00:00 with price 18970.0, Stop Loss: 21246.4, Take Profit: 14606.9
# exit short position at 2020-12-08 03:00:00 with price 19167.0 (Reverse to Long), updated balance: 1176798.32
# enter long position (normal) at 2020-12-08 03:00:00 with price 19167.0, Stop Loss: 17633.64, Take Profit: 25300.440000000002
# exit long position at 2020-12-08 13:00:00 with price 18909.5 (Reverse to Short), updated balance: 1160988.57
# enter short position (normal) at 2020-12-08 13:00:00 with price 18909.5, Stop Loss: 21178.640000000003, Take Profit: 14560.315
# exit short position at 2020-12-12 04:00:00 with price 18362.0 (Reverse to Long), updated balance: 1194603.48
# enter long position (normal) at 2020-12-12 04:00:00 with price 18362.0, Stop Loss: 16893.04, Take Profit: 24237.84
# exit long position at 2020-12-19 16:00:00 with price 24237.84 (Take Profit), updated balance: 1576876.60
# enter long position (normal) at 2020-12-20 00:00:00 with price 23503.5, Stop Loss: 21623.22, Take Profit: 31024.620000000003
# exit long position at 2020-12-21 13:00:00 with price 22801.0 (Reverse to Short), updated balance: 1529745.07
# enter short position (normal) at 2020-12-21 13:00:00 with price 22801.0, Stop Loss: 25537.120000000003, Take Profit: 17556.77
# exit short position at 2020-12-22 16:00:00 with price 23363.0 (Reverse to Long), updated balance: 1492039.85
# enter long position (normal) at 2020-12-22 16:00:00 with price 23363.0, Stop Loss: 21493.96, Take Profit: 30839.16
# exit long position at 2020-12-24 00:00:00 with price 23049.0 (Reverse to Short), updated balance: 1471986.75
# enter short position (normal) at 2020-12-24 00:00:00 with price 23049.0, Stop Loss: 25814.88, Take Profit: 17747.73
# exit short position at 2020-12-24 20:00:00 with price 23530.5 (Reverse to Long), updated balance: 1441236.54
# enter long position (normal) at 2020-12-24 20:00:00 with price 23530.5, Stop Loss: 21648.06, Take Profit: 31060.260000000002
# exit long position at 2021-01-02 13:00:00 with price 31060.260000000002 (Take Profit), updated balance: 1902432.24
# enter long position (normal) at 2021-01-02 20:00:00 with price 30906.0, Stop Loss: 28433.52, Take Profit: 40795.920000000006
# exit long position at 2021-01-04 10:00:00 with price 28433.52 (Stoploss), updated balance: 1750237.66
# enter short position (normal) at 2021-01-04 12:00:00 with price 31171.0, Stop Loss: 34911.520000000004, Take Profit: 24001.670000000002
# exit short position at 2021-01-05 16:00:00 with price 32455.0 (Reverse to Long), updated balance: 1678141.63
# enter long position (normal) at 2021-01-05 16:00:00 with price 32455.0, Stop Loss: 29858.600000000002, Take Profit: 42840.6
# exit long position at 2021-01-10 16:00:00 with price 39295.0 (Reverse to Short), updated balance: 2031815.61
# enter short position (normal) at 2021-01-10 16:00:00 with price 39295.0, Stop Loss: 44010.4, Take Profit: 30257.15
# exit short position at 2021-01-13 19:00:00 with price 36036.0 (Reverse to Long), updated balance: 2200327.81
# enter long position (normal) at 2021-01-13 19:00:00 with price 36036.0, Stop Loss: 33153.12, Take Profit: 47567.520000000004
# exit long position at 2021-01-15 16:00:00 with price 36135.5 (Reverse to Short), updated balance: 2206403.20
# enter short position (normal) at 2021-01-15 16:00:00 with price 36135.5, Stop Loss: 40471.76, Take Profit: 27824.335
# exit short position at 2021-01-16 14:00:00 with price 37246.5 (Reverse to Long), updated balance: 2138566.47
# enter long position (normal) at 2021-01-16 14:00:00 with price 37246.5, Stop Loss: 34266.78, Take Profit: 49165.380000000005
# exit long position at 2021-01-16 21:00:00 with price 35949.0 (Reverse to Short), updated balance: 2064068.47
# enter short position (normal) at 2021-01-16 21:00:00 with price 35949.0, Stop Loss: 40262.880000000005, Take Profit: 27680.73
# exit short position at 2021-01-18 12:00:00 with price 37083.0 (Reverse to Long), updated balance: 1998958.07
# enter long position (normal) at 2021-01-18 12:00:00 with price 37083.0, Stop Loss: 34116.36, Take Profit: 48949.560000000005
# exit long position at 2021-01-20 01:00:00 with price 36181.5 (Reverse to Short), updated balance: 1950362.74
# enter short position (normal) at 2021-01-20 01:00:00 with price 36181.5, Stop Loss: 40523.280000000006, Take Profit: 27859.755
# exit short position at 2021-01-24 08:00:00 with price 32659.0 (Reverse to Long), updated balance: 2140243.00
# enter long position (normal) at 2021-01-24 08:00:00 with price 32659.0, Stop Loss: 30046.280000000002, Take Profit: 43109.880000000005
# exit long position at 2021-01-24 16:00:00 with price 31741.5 (Reverse to Short), updated balance: 2080116.45
# enter short position (normal) at 2021-01-24 16:00:00 with price 31741.5, Stop Loss: 35550.48, Take Profit: 24440.955
# exit short position at 2021-01-25 05:00:00 with price 33377.0 (Reverse to Long), updated balance: 1972937.19
# enter long position (normal) at 2021-01-25 05:00:00 with price 33377.0, Stop Loss: 30706.84, Take Profit: 44057.64
# exit long position at 2021-01-26 02:00:00 with price 32356.5 (Reverse to Short), updated balance: 1912614.74
# enter short position (normal) at 2021-01-26 02:00:00 with price 32356.5, Stop Loss: 36239.280000000006, Take Profit: 24914.505
# exit short position at 2021-01-28 15:00:00 with price 31916.0 (Reverse to Long), updated balance: 1938653.00
# enter long position (normal) at 2021-01-28 15:00:00 with price 31916.0, Stop Loss: 29362.72, Take Profit: 42129.12
# exit long position at 2021-01-31 08:00:00 with price 33619.5 (Reverse to Short), updated balance: 2042127.60
# enter short position (normal) at 2021-01-31 08:00:00 with price 33619.5, Stop Loss: 37653.840000000004, Take Profit: 25887.015
# exit short position at 2021-02-01 08:00:00 with price 34484.0 (Reverse to Long), updated balance: 1989615.83
# enter long position (normal) at 2021-02-01 08:00:00 with price 34484.0, Stop Loss: 31725.280000000002, Take Profit: 45518.880000000005
# exit long position at 2021-02-07 15:00:00 with price 37951.0 (Reverse to Short), updated balance: 2189650.58
# enter short position (normal) at 2021-02-07 15:00:00 with price 37951.0, Stop Loss: 42505.12, Take Profit: 29222.27
# exit short position at 2021-02-08 07:00:00 with price 39290.0 (Reverse to Long), updated balance: 2112394.59
# enter long position (normal) at 2021-02-08 07:00:00 with price 39290.0, Stop Loss: 36146.8, Take Profit: 51862.8
# exit long position at 2021-02-11 01:00:00 with price 44251.0 (Reverse to Short), updated balance: 2379118.68
# enter short position (normal) at 2021-02-11 01:00:00 with price 44251.0, Stop Loss: 49561.12, Take Profit: 34073.270000000004
# exit short position at 2021-02-11 09:00:00 with price 45521.0 (Reverse to Long), updated balance: 2310838.17
# enter long position (normal) at 2021-02-11 09:00:00 with price 45521.0, Stop Loss: 41879.32, Take Profit: 60087.72
# exit long position at 2021-02-13 19:00:00 with price 46904.0 (Reverse to Short), updated balance: 2381045.09
# enter short position (normal) at 2021-02-13 19:00:00 with price 46904.0, Stop Loss: 52532.48, Take Profit: 36116.08
# exit short position at 2021-02-14 00:00:00 with price 47612.5 (Reverse to Long), updated balance: 2345078.64
# enter long position (normal) at 2021-02-14 00:00:00 with price 47612.5, Stop Loss: 43803.5, Take Profit: 62848.5
# exit long position at 2021-02-15 06:00:00 with price 46959.0 (Reverse to Short), updated balance: 2312891.53
# enter short position (normal) at 2021-02-15 06:00:00 with price 46959.0, Stop Loss: 52594.08, Take Profit: 36158.43
# exit short position at 2021-02-15 16:00:00 with price 48488.0 (Reverse to Long), updated balance: 2237583.04
# enter long position (normal) at 2021-02-15 16:00:00 with price 48488.0, Stop Loss: 44608.96, Take Profit: 64004.16
# exit long position at 2021-02-22 10:00:00 with price 54957.5 (Reverse to Short), updated balance: 2536132.03
# enter short position (normal) at 2021-02-22 10:00:00 with price 54957.5, Stop Loss: 61552.40000000001, Take Profit: 42317.275
# exit short position at 2021-02-25 13:00:00 with price 51385.0 (Reverse to Long), updated balance: 2700992.73
# enter long position (normal) at 2021-02-25 13:00:00 with price 51385.0, Stop Loss: 47274.200000000004, Take Profit: 67828.2
# exit long position at 2021-02-25 18:00:00 with price 49624.0 (Reverse to Short), updated balance: 2608427.81
# enter short position (normal) at 2021-02-25 18:00:00 with price 49624.0, Stop Loss: 55578.880000000005, Take Profit: 38210.48
# exit short position at 2021-03-01 08:00:00 with price 47014.0 (Reverse to Long), updated balance: 2745619.42
# enter long position (normal) at 2021-03-01 08:00:00 with price 47014.0, Stop Loss: 43252.880000000005, Take Profit: 62058.48
# exit long position at 2021-03-04 17:00:00 with price 48595.0 (Reverse to Short), updated balance: 2837949.89
# enter short position (normal) at 2021-03-04 17:00:00 with price 48595.0, Stop Loss: 54426.40000000001, Take Profit: 37418.15
# exit short position at 2021-03-05 22:00:00 with price 49100.0 (Reverse to Long), updated balance: 2808457.87
# enter long position (normal) at 2021-03-05 22:00:00 with price 49100.0, Stop Loss: 45172.0, Take Profit: 64812.0
# exit long position at 2021-03-06 13:00:00 with price 47402.5 (Reverse to Short), updated balance: 2711363.01
# enter short position (normal) at 2021-03-06 13:00:00 with price 47402.5, Stop Loss: 53090.8, Take Profit: 36499.925
# exit short position at 2021-03-06 23:00:00 with price 48874.0 (Reverse to Long), updated balance: 2627195.08
# enter long position (normal) at 2021-03-06 23:00:00 with price 48874.0, Stop Loss: 44964.08, Take Profit: 64513.68
# exit long position at 2021-03-15 21:00:00 with price 56747.0 (Reverse to Short), updated balance: 3050403.88
# enter short position (normal) at 2021-03-15 21:00:00 with price 56747.0, Stop Loss: 63556.64000000001, Take Profit: 43695.19
# exit short position at 2021-03-17 20:00:00 with price 57744.0 (Reverse to Long), updated balance: 2996810.69
# enter long position (normal) at 2021-03-17 20:00:00 with price 57744.0, Stop Loss: 53124.48, Take Profit: 76222.08
# exit long position at 2021-03-21 03:00:00 with price 57890.0 (Reverse to Short), updated balance: 3004387.83
# enter short position (normal) at 2021-03-21 03:00:00 with price 57890.0, Stop Loss: 64836.8, Take Profit: 44575.3
# exit short position at 2021-03-24 11:00:00 with price 56580.5 (Reverse to Long), updated balance: 3072348.54
# enter long position (normal) at 2021-03-24 11:00:00 with price 56580.5, Stop Loss: 52054.060000000005, Take Profit: 74686.26000000001
# exit long position at 2021-03-24 20:00:00 with price 54088.5 (Reverse to Short), updated balance: 2937031.74
# enter short position (normal) at 2021-03-24 20:00:00 with price 54088.5, Stop Loss: 60579.12, Take Profit: 41648.145000000004
# exit short position at 2021-03-26 17:00:00 with price 53810.0 (Reverse to Long), updated balance: 2952154.42
# enter long position (normal) at 2021-03-26 17:00:00 with price 53810.0, Stop Loss: 49505.200000000004, Take Profit: 71029.2
# exit long position at 2021-04-03 18:00:00 with price 58491.0 (Reverse to Short), updated balance: 3208966.07
# enter short position (normal) at 2021-04-03 18:00:00 with price 58491.0, Stop Loss: 65509.920000000006, Take Profit: 45038.07
# exit short position at 2021-04-05 18:00:00 with price 58880.0 (Reverse to Long), updated balance: 3187624.53
# enter long position (normal) at 2021-04-05 18:00:00 with price 58880.0, Stop Loss: 54169.600000000006, Take Profit: 77721.6
# exit long position at 2021-04-06 16:00:00 with price 58150.5 (Reverse to Short), updated balance: 3148131.12
# enter short position (normal) at 2021-04-06 16:00:00 with price 58150.5, Stop Loss: 65128.560000000005, Take Profit: 44775.885
# exit short position at 2021-04-08 17:00:00 with price 57700.0 (Reverse to Long), updated balance: 3172520.13
# enter long position (normal) at 2021-04-08 17:00:00 with price 57700.0, Stop Loss: 53084.0, Take Profit: 76164.0
# enter short position (normal) at 2021-05-17 07:00:00 with price 45169.0, Stop Loss: 50589.280000000006, Take Profit: 34780.13
# exit short position at 2021-05-19 12:00:00 with price 34780.13 (Take Profit), updated balance: 5211525.50
# enter short position (normal) at 2021-05-19 16:00:00 with price 39690.5, Stop Loss: 44453.36000000001, Take Profit: 30561.685
# exit short position at 2021-05-21 00:00:00 with price 41670.5 (Reverse to Long), updated balance: 4951543.38
# enter long position (normal) at 2021-05-21 00:00:00 with price 41670.5, Stop Loss: 38336.86, Take Profit: 55005.060000000005
# exit long position at 2021-05-21 05:00:00 with price 39820.0 (Reverse to Short), updated balance: 4731655.66
# enter short position (normal) at 2021-05-21 05:00:00 with price 39820.0, Stop Loss: 44598.4, Take Profit: 30661.4
# exit short position at 2021-05-24 13:00:00 with price 37563.0 (Reverse to Long), updated balance: 4999846.19
# enter long position (normal) at 2021-05-24 13:00:00 with price 37563.0, Stop Loss: 34557.96, Take Profit: 49583.16
# exit long position at 2021-05-27 03:00:00 with price 37625.0 (Reverse to Short), updated balance: 5008098.74
# enter short position (normal) at 2021-05-27 03:00:00 with price 37625.0, Stop Loss: 42140.00000000001, Take Profit: 28971.25
# exit short position at 2021-05-27 10:00:00 with price 39174.5 (Reverse to Long), updated balance: 4801851.59
# enter long position (normal) at 2021-05-27 10:00:00 with price 39174.5, Stop Loss: 36040.54, Take Profit: 51710.340000000004
# exit long position at 2021-05-28 04:00:00 with price 37372.0 (Reverse to Short), updated balance: 4580908.44
# enter short position (normal) at 2021-05-28 04:00:00 with price 37372.0, Stop Loss: 41856.64000000001, Take Profit: 28776.440000000002
# exit short position at 2021-05-30 20:00:00 with price 36066.0 (Reverse to Long), updated balance: 4740992.63
# enter long position (normal) at 2021-05-30 20:00:00 with price 36066.0, Stop Loss: 33180.72, Take Profit: 47607.12
# exit long position at 2021-05-31 01:00:00 with price 34812.0 (Reverse to Short), updated balance: 4576150.27
# enter short position (normal) at 2021-05-31 01:00:00 with price 34812.0, Stop Loss: 38989.44, Take Profit: 26805.24
# exit short position at 2021-05-31 10:00:00 with price 36829.5 (Reverse to Long), updated balance: 4310943.35
# enter long position (normal) at 2021-05-31 10:00:00 with price 36829.5, Stop Loss: 33883.14, Take Profit: 48614.94
# exit long position at 2021-06-01 19:00:00 with price 35958.5 (Reverse to Short), updated balance: 4208991.61
# enter short position (normal) at 2021-06-01 19:00:00 with price 35958.5, Stop Loss: 40273.520000000004, Take Profit: 27688.045000000002
# exit short position at 2021-06-02 06:00:00 with price 36766.0 (Reverse to Long), updated balance: 4114472.63
# enter long position (normal) at 2021-06-02 06:00:00 with price 36766.0, Stop Loss: 33824.72, Take Profit: 48531.12
# exit long position at 2021-06-04 09:00:00 with price 36865.0 (Reverse to Short), updated balance: 4125551.69
# enter short position (normal) at 2021-06-04 09:00:00 with price 36865.0, Stop Loss: 41288.8, Take Profit: 28386.05
# exit short position at 2021-06-05 07:00:00 with price 37583.5 (Reverse to Long), updated balance: 4045144.56
# enter long position (normal) at 2021-06-05 07:00:00 with price 37583.5, Stop Loss: 34576.82, Take Profit: 49610.22
# exit long position at 2021-06-05 10:00:00 with price 36458.0 (Reverse to Short), updated balance: 3924006.02
# enter short position (normal) at 2021-06-05 10:00:00 with price 36458.0, Stop Loss: 40832.96000000001, Take Profit: 28072.66
# exit short position at 2021-06-07 13:00:00 with price 36327.0 (Reverse to Long), updated balance: 3938105.67
# enter long position (normal) at 2021-06-07 13:00:00 with price 36327.0, Stop Loss: 33420.840000000004, Take Profit: 47951.64
# ...
# enter long position (normal) at 2024-04-30 01:00:00 with price 63583.4, Stop Loss: 58496.728, Take Profit: 83930.088
# exit long position at 2024-04-30 22:00:00 with price 60562.8 (Reverse to Short), updated balance: 1177180.04
# enter short position (normal) at 2024-04-30 22:00:00 with price 60562.8, Stop Loss: 67830.33600000001, Take Profit: 46633.356
# exit short position at 2024-05-03 02:00:00 with price 59518.3 (Reverse to Long), updated balance: 1197482.34
# enter long position (normal) at 2024-05-03 02:00:00 with price 59518.3, Stop Loss: 54756.836, Take Profit: 78564.156
# exit long position at 2024-05-06 23:00:00 with price 63149.3 (Reverse to Short), updated balance: 1270536.49
# enter short position (normal) at 2024-05-06 23:00:00 with price 63149.3, Stop Loss: 70727.21600000001, Take Profit: 48624.961
# exit short position at 2024-05-07 08:00:00 with price 64211.1 (Reverse to Long), updated balance: 1249173.53
# enter long position (normal) at 2024-05-07 08:00:00 with price 64211.1, Stop Loss: 59074.212, Take Profit: 84758.652
# exit long position at 2024-05-07 19:00:00 with price 63041.4 (Reverse to Short), updated balance: 1226417.99
# enter short position (normal) at 2024-05-07 19:00:00 with price 63041.4, Stop Loss: 70606.368, Take Profit: 48541.878000000004
# exit short position at 2024-05-09 23:00:00 with price 63035.5 (Reverse to Long), updated balance: 1226532.77
# enter long position (normal) at 2024-05-09 23:00:00 with price 63035.5, Stop Loss: 57992.66, Take Profit: 83206.86
# exit long position at 2024-05-11 01:00:00 with price 60857.4 (Reverse to Short), updated balance: 1184151.72
# enter short position (normal) at 2024-05-11 01:00:00 with price 60857.4, Stop Loss: 68160.28800000002, Take Profit: 46860.198000000004
# exit short position at 2024-05-12 19:00:00 with price 61379.9 (Reverse to Long), updated balance: 1173985.01
# enter long position (normal) at 2024-05-12 19:00:00 with price 61379.9, Stop Loss: 56469.508, Take Profit: 81021.46800000001
# exit long position at 2024-05-13 04:00:00 with price 60966.7 (Reverse to Short), updated balance: 1166081.92
# enter short position (normal) at 2024-05-13 04:00:00 with price 60966.7, Stop Loss: 68282.704, Take Profit: 46944.359
# exit short position at 2024-05-13 22:00:00 with price 62728.4 (Reverse to Long), updated balance: 1132386.70
# enter long position (normal) at 2024-05-13 22:00:00 with price 62728.4, Stop Loss: 57710.128000000004, Take Profit: 82801.48800000001
# exit long position at 2024-05-14 12:00:00 with price 61550.1 (Reverse to Short), updated balance: 1111115.77
# enter short position (normal) at 2024-05-14 12:00:00 with price 61550.1, Stop Loss: 68936.11200000001, Take Profit: 47393.577
# exit short position at 2024-05-15 08:00:00 with price 62120.3 (Reverse to Long), updated balance: 1100822.40
# enter long position (normal) at 2024-05-15 08:00:00 with price 62120.3, Stop Loss: 57150.67600000001, Take Profit: 81998.796
# exit long position at 2024-05-19 21:00:00 with price 66257.2 (Reverse to Short), updated balance: 1174131.64
# enter short position (normal) at 2024-05-19 21:00:00 with price 66257.2, Stop Loss: 74208.064, Take Profit: 51018.044
# exit short position at 2024-05-20 04:00:00 with price 67116.7 (Reverse to Long), updated balance: 1158900.60
# enter long position (normal) at 2024-05-20 04:00:00 with price 67116.7, Stop Loss: 61747.364, Take Profit: 88594.044
# exit long position at 2024-05-23 21:00:00 with price 68031.5 (Reverse to Short), updated balance: 1174696.41
# enter short position (normal) at 2024-05-23 21:00:00 with price 68031.5, Stop Loss: 76195.28000000001, Take Profit: 52384.255000000005
# exit short position at 2024-05-24 21:00:00 with price 68897.2 (Reverse to Long), updated balance: 1159748.41
# enter long position (normal) at 2024-05-24 21:00:00 with price 68897.2, Stop Loss: 63385.424, Take Profit: 90944.304
# exit long position at 2024-05-26 21:00:00 with price 68536.1 (Reverse to Short), updated balance: 1153670.00
# enter short position (normal) at 2024-05-26 21:00:00 with price 68536.1, Stop Loss: 76760.43200000002, Take Profit: 52772.797000000006
# exit short position at 2024-05-27 19:00:00 with price 69305.9 (Reverse to Long), updated balance: 1140711.94
# enter long position (normal) at 2024-05-27 19:00:00 with price 69305.9, Stop Loss: 63761.428, Take Profit: 91483.788
# exit long position at 2024-05-28 05:00:00 with price 68055.5 (Reverse to Short), updated balance: 1120131.49
# enter short position (normal) at 2024-05-28 05:00:00 with price 68055.5, Stop Loss: 76222.16, Take Profit: 52402.735
# exit short position at 2024-05-30 15:00:00 with price 68558.9 (Reverse to Long), updated balance: 1111845.99
# enter long position (normal) at 2024-05-30 15:00:00 with price 68558.9, Stop Loss: 63074.187999999995, Take Profit: 90497.74799999999
# exit long position at 2024-05-31 17:00:00 with price 67372.3 (Reverse to Short), updated balance: 1092602.44
# enter short position (normal) at 2024-05-31 17:00:00 with price 67372.3, Stop Loss: 75456.97600000001, Take Profit: 51876.671
# exit short position at 2024-06-02 13:00:00 with price 68175.6 (Reverse to Long), updated balance: 1079575.02
# enter long position (normal) at 2024-06-02 13:00:00 with price 68175.6, Stop Loss: 62721.55200000001, Take Profit: 89991.79200000002
# exit long position at 2024-06-02 23:00:00 with price 67776.3 (Reverse to Short), updated balance: 1073252.02
# enter short position (normal) at 2024-06-02 23:00:00 with price 67776.3, Stop Loss: 75909.456, Take Profit: 52187.751000000004
# exit short position at 2024-06-03 01:00:00 with price 68498.2 (Reverse to Long), updated balance: 1061820.58
# enter long position (normal) at 2024-06-03 01:00:00 with price 68498.2, Stop Loss: 63018.344, Take Profit: 90417.624
# exit long position at 2024-06-08 07:00:00 with price 69609.0 (Reverse to Short), updated balance: 1079039.58
# enter short position (normal) at 2024-06-08 07:00:00 with price 69609.0, Stop Loss: 77962.08, Take Profit: 53598.93
# exit short position at 2024-06-10 16:00:00 with price 69970.0 (Reverse to Long), updated balance: 1073443.56
# enter long position (normal) at 2024-06-10 16:00:00 with price 69970.0, Stop Loss: 64372.4, Take Profit: 92360.40000000001
# exit long position at 2024-06-10 22:00:00 with price 69492.1 (Reverse to Short), updated balance: 1066111.86
# enter short position (normal) at 2024-06-10 22:00:00 with price 69492.1, Stop Loss: 77831.15200000002, Take Profit: 53508.91700000001
# exit short position at 2024-06-12 09:00:00 with price 67703.5 (Take Profit Lateral), updated balance: 1094896.88
# enter long position (normal) at 2024-06-12 18:00:00 with price 68791.8, Stop Loss: 63288.456000000006, Take Profit: 90805.176
# exit long position at 2024-06-13 02:00:00 with price 67708.0 (Reverse to Short), updated balance: 1077647.02
# enter short position (normal) at 2024-06-13 02:00:00 with price 67708.0, Stop Loss: 75832.96, Take Profit: 52135.16
# exit short position at 2024-06-15 20:00:00 with price 66014.0 (Take Profit Lateral), updated balance: 1106743.49
# enter long position (normal) at 2024-06-16 14:00:00 with price 66491.2, Stop Loss: 61171.904, Take Profit: 87768.384
# exit long position at 2024-06-17 03:00:00 with price 66188.9 (Reverse to Short), updated balance: 1101711.72
# enter short position (normal) at 2024-06-17 03:00:00 with price 66188.9, Stop Loss: 74131.568, Take Profit: 50965.452999999994
# exit short position at 2024-06-17 22:00:00 with price 66631.6 (Reverse to Long), updated balance: 1094342.99
# enter long position (normal) at 2024-06-17 22:00:00 with price 66631.6, Stop Loss: 61301.07200000001, Take Profit: 87953.71200000001
# exit long position at 2024-06-18 02:00:00 with price 65438.2 (Reverse to Short), updated balance: 1074742.85
# enter short position (normal) at 2024-06-18 02:00:00 with price 65438.2, Stop Loss: 73290.784, Take Profit: 50387.414
# exit short position at 2024-06-20 08:00:00 with price 65666.2 (Reverse to Long), updated balance: 1070998.22
# enter long position (normal) at 2024-06-20 08:00:00 with price 65666.2, Stop Loss: 60412.904, Take Profit: 86679.384
# exit long position at 2024-06-20 16:00:00 with price 64863.4 (Reverse to Short), updated balance: 1057904.77
# enter short position (normal) at 2024-06-20 16:00:00 with price 64863.4, Stop Loss: 72647.008, Take Profit: 49944.818
# exit short position at 2024-06-27 16:00:00 with price 61687.3 (Reverse to Long), updated balance: 1109706.11
# enter long position (normal) at 2024-06-27 16:00:00 with price 61687.3, Stop Loss: 56752.316000000006, Take Profit: 81427.236
# exit long position at 2024-06-28 14:00:00 with price 60881.3 (Reverse to Short), updated balance: 1095206.81
# enter short position (normal) at 2024-06-28 14:00:00 with price 60881.3, Stop Loss: 68187.05600000001, Take Profit: 46878.601
# exit short position at 2024-06-30 09:00:00 with price 61489.1 (Reverse to Long), updated balance: 1084272.96
# enter long position (normal) at 2024-06-30 09:00:00 with price 61489.1, Stop Loss: 56569.972, Take Profit: 81165.61200000001
# exit long position at 2024-07-02 17:00:00 with price 62135.7 (Reverse to Short), updated balance: 1095674.84
# enter short position (normal) at 2024-07-02 17:00:00 with price 62135.7, Stop Loss: 69591.984, Take Profit: 47844.489
# exit short position at 2024-07-06 18:00:00 with price 57758.7 (Reverse to Long), updated balance: 1172857.01
# enter long position (normal) at 2024-07-06 18:00:00 with price 57758.7, Stop Loss: 53138.004, Take Profit: 76241.484
# exit long position at 2024-07-07 14:00:00 with price 56742.4 (Reverse to Short), updated balance: 1152219.87
# enter short position (normal) at 2024-07-07 14:00:00 with price 56742.4, Stop Loss: 63551.488000000005, Take Profit: 43691.648
# exit short position at 2024-07-09 04:00:00 with price 57264.7 (Reverse to Long), updated balance: 1141613.97
# enter long position (normal) at 2024-07-09 04:00:00 with price 57264.7, Stop Loss: 52683.524, Take Profit: 75589.404
# exit long position at 2024-07-12 04:00:00 with price 56989.6 (Reverse to Short), updated balance: 1136129.65
# enter short position (normal) at 2024-07-12 04:00:00 with price 56989.6, Stop Loss: 63828.352000000006, Take Profit: 43881.992
# exit short position at 2024-07-12 16:00:00 with price 58081.5 (Reverse to Long), updated balance: 1114361.82
# enter long position (normal) at 2024-07-12 16:00:00 with price 58081.5, Stop Loss: 53434.98, Take Profit: 76667.58
# exit long position at 2024-07-18 17:00:00 with price 63534.7 (Reverse to Short), updated balance: 1218987.86
# enter short position (normal) at 2024-07-18 17:00:00 with price 63534.7, Stop Loss: 71158.864, Take Profit: 48921.719
# exit short position at 2024-07-19 13:00:00 with price 65099.1 (Reverse to Long), updated balance: 1188973.01
# enter long position (normal) at 2024-07-19 13:00:00 with price 65099.1, Stop Loss: 59891.172, Take Profit: 85930.812
# exit long position at 2024-07-23 06:00:00 with price 66503.0 (Reverse to Short), updated balance: 1214613.91
# enter short position (normal) at 2024-07-23 06:00:00 with price 66503.0, Stop Loss: 74483.36, Take Profit: 51207.31
# exit short position at 2024-07-26 01:00:00 with price 66400.0 (Reverse to Long), updated balance: 1216495.10
# enter long position (normal) at 2024-07-26 01:00:00 with price 66400.0, Stop Loss: 61088.0, Take Profit: 87648.0
# exit long position at 2024-07-29 18:00:00 with price 67399.9 (Reverse to Short), updated balance: 1234813.98
# enter short position (normal) at 2024-07-29 18:00:00 with price 67399.9, Stop Loss: 75487.888, Take Profit: 51897.922999999995
# exit short position at 2024-08-05 06:00:00 with price 51897.922999999995 (Take Profit), updated balance: 1518821.20
# enter short position (normal) at 2024-08-05 14:00:00 with price 54030.5, Stop Loss: 60514.16, Take Profit: 41603.485
# exit short position at 2024-08-06 20:00:00 with price 56515.3 (Reverse to Long), updated balance: 1448972.37
# enter long position (normal) at 2024-08-06 20:00:00 with price 56515.3, Stop Loss: 51994.07600000001, Take Profit: 74600.19600000001
# exit long position at 2024-08-07 18:00:00 with price 54784.3 (Reverse to Short), updated balance: 1404591.98
# enter short position (normal) at 2024-08-07 18:00:00 with price 54784.3, Stop Loss: 61358.41600000001, Take Profit: 42183.911
# exit short position at 2024-08-08 04:00:00 with price 56746.1 (Reverse to Long), updated balance: 1354294.20
# enter long position (normal) at 2024-08-08 04:00:00 with price 56746.1, Stop Loss: 52206.412000000004, Take Profit: 74904.852
# exit long position at 2024-08-12 10:00:00 with price 58947.6 (Reverse to Short), updated balance: 1406834.88
# enter short position (normal) at 2024-08-12 10:00:00 with price 58947.6, Stop Loss: 66021.312, Take Profit: 45389.652
# exit short position at 2024-08-13 18:00:00 with price 60766.3 (Reverse to Long), updated balance: 1363430.05
# enter long position (normal) at 2024-08-13 18:00:00 with price 60766.3, Stop Loss: 55904.99600000001, Take Profit: 80211.516
# exit long position at 2024-08-14 17:00:00 with price 59131.2 (Reverse to Short), updated balance: 1326742.87
# enter short position (normal) at 2024-08-14 17:00:00 with price 59131.2, Stop Loss: 66226.944, Take Profit: 45531.024
# exit short position at 2024-08-16 19:00:00 with price 59653.9 (Reverse to Long), updated balance: 1315014.91
# enter long position (normal) at 2024-08-16 19:00:00 with price 59653.9, Stop Loss: 54881.588, Take Profit: 78743.148
# exit long position at 2024-08-19 02:00:00 with price 58628.3 (Reverse to Short), updated balance: 1292406.50
# enter short position (normal) at 2024-08-19 02:00:00 with price 58628.3, Stop Loss: 65663.69600000001, Take Profit: 45143.791000000005
# exit short position at 2024-08-21 13:00:00 with price 59898.0 (Reverse to Long), updated balance: 1264417.15
# enter long position (normal) at 2024-08-21 13:00:00 with price 59898.0, Stop Loss: 55106.16, Take Profit: 79065.36
# exit long position at 2024-08-26 17:00:00 with price 63361.6 (Reverse to Short), updated balance: 1337532.03
# enter short position (normal) at 2024-08-26 17:00:00 with price 63361.6, Stop Loss: 70964.992, Take Profit: 48788.432
# exit short position at 2024-09-01 01:00:00 with price 58803.9 (Take Profit Lateral), updated balance: 1373645.39
# enter short position (normal) at 2024-09-01 02:00:00 with price 58523.5, Stop Loss: 65546.32, Take Profit: 45063.095
# exit short position at 2024-09-02 20:00:00 with price 58953.3 (Reverse to Long), updated balance: 1363557.26
# enter long position (normal) at 2024-09-02 20:00:00 with price 58953.3, Stop Loss: 54237.03600000001, Take Profit: 77818.35600000001
# exit long position at 2024-09-03 15:00:00 with price 57700.4 (Reverse to Short), updated balance: 1334578.38
# enter short position (normal) at 2024-09-03 15:00:00 with price 57700.4, Stop Loss: 64624.44800000001, Take Profit: 44429.308000000005
# exit short position at 2024-09-04 23:00:00 with price 57937.8 (Reverse to Long), updated balance: 1329087.45
# enter long position (normal) at 2024-09-04 23:00:00 with price 57937.8, Stop Loss: 53302.776000000005, Take Profit: 76477.89600000001
# exit long position at 2024-09-05 05:00:00 with price 57169.0 (Reverse to Short), updated balance: 1311451.25
# enter short position (normal) at 2024-09-05 05:00:00 with price 57169.0, Stop Loss: 64029.280000000006, Take Profit: 44020.13
# exit short position at 2024-09-09 01:00:00 with price 55079.2 (Reverse to Long), updated balance: 1359391.06
# enter long position (normal) at 2024-09-09 01:00:00 with price 55079.2, Stop Loss: 50672.864, Take Profit: 72704.544
# exit long position at 2024-09-11 14:00:00 with price 55949.7 (Reverse to Short), updated balance: 1380875.57
# enter short position (normal) at 2024-09-11 14:00:00 with price 55949.7, Stop Loss: 62663.664000000004, Take Profit: 43081.269
# exit short position at 2024-09-11 17:00:00 with price 57675.2 (Reverse to Long), updated balance: 1338289.09
# enter long position (normal) at 2024-09-11 17:00:00 with price 57675.2, Stop Loss: 53061.184, Take Profit: 76131.264
# Total trades: 795

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import talib
from itertools import product
from tqdm import tqdm  # Para mostrar uma barra de progresso
import random

# Função para calcular o MACD manualmente
def macd(series, fast_period, slow_period, signal_period):
    ema_fast = talib.EMA(series, fast_period)
    ema_slow = talib.EMA(series, slow_period)
    macd_line = ema_fast - ema_slow
    signal_line = talib.EMA(macd_line, signal_period)
    macd_hist = macd_line - signal_line
    return macd_line, signal_line, macd_hist

# Função para calcular o ADX manualmente
def get_adx_manual(high, low, close, di_lookback, adx_smoothing):
    tr = []
    previous_close = close[0]  # Primeiro valor de fechamento
    
    plus_dm = []
    minus_dm = []

    for i in range(1, len(close)):
        # Calcular +DM e -DM
        current_plus_dm = high[i] - high[i-1]
        current_minus_dm = low[i-1] - low[i]
        plus_dm.append(max(current_plus_dm, 0) if current_plus_dm > current_minus_dm else 0)
        minus_dm.append(max(current_minus_dm, 0) if current_minus_dm > current_plus_dm else 0)
        
        # Calcular True Range (TR)
        tr1 = high[i] - low[i]
        tr2 = abs(high[i] - previous_close)
        tr3 = abs(low[i] - previous_close)
        true_range = max(tr1, tr2, tr3)
        tr.append(true_range)
        
        # Atualizar o fechamento anterior
        previous_close = close[i]
    
    # Adiciona um valor NaN para a primeira posição
    tr.insert(0, None)
    plus_dm.insert(0, None)
    minus_dm.insert(0, None)
    
    # Converter listas para Series do pandas
    tr = pd.Series(tr)
    plus_dm = pd.Series(plus_dm)
    minus_dm = pd.Series(minus_dm)
    
    # Calcular o ATR usando o lookback fornecido para DI
    atr = tr.rolling(window=di_lookback).mean()
    
    # Calcular DI+ e DI- com o lookback de DI
    plus_di = 100 * (plus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=1/di_lookback).mean() / atr)
    
    # Calcular o DX
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    
    # Calcular o ADX usando o smoothing específico para o ADX
    adx = dx.ewm(alpha=1/adx_smoothing).mean()
    
    return plus_di, minus_di, adx

# Função para detectar crossover (cruzamento ascendente)
def crossover(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] > series2_vals[1:]) & (series1_vals[:-1] <= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False para alinhar os comprimentos
    return pd.Series(cross, index=series1.index)

# Função para detectar crossunder (cruzamento descendente)
def crossunder(series1, series2):
    series1_vals = series1.values
    series2_vals = series2.values
    cross = (series1_vals[1:] < series2_vals[1:]) & (series1_vals[:-1] >= series2_vals[:-1])
    cross = np.concatenate(([False], cross))  # Prepend False para alinhar os comprimentos
    return pd.Series(cross, index=series1.index)

# Função de Backtest
def backtest(params, df):
    # Desempacotar parâmetros
    (emaShortLength, emaLongLength, rsiLength, macdShort, macdLong, macdSignal,
     adxLength, adxSmoothing, adxThreshold, bbLength, bbMultiplier,
     lateralThreshold, stopgain_lateral_long, stoploss_lateral_long,
     stopgain_lateral_short, stoploss_lateral_short,
     stopgain_normal_long, stoploss_normal_long,
     stopgain_normal_short, stoploss_normal_short,
     commission) = params
    
    # Atribuir os dados às variáveis
    timestamp = df['time']
    open_price = df['open']
    high_price = df['high']
    low_price = df['low']
    close_price = df['close']
    
    # Cálculo dos Indicadores
    emaShort = talib.EMA(close_price, emaShortLength).round(0)
    emaLong = talib.EMA(close_price, emaLongLength).round(0)
    rsi = talib.RSI(close_price, timeperiod=rsiLength)
    plus_di, minus_di, adx = get_adx_manual(high_price, low_price, close_price, adxLength, adxSmoothing)
    adx = adx.fillna(0).astype(int)
    macdLine, signalLine, macdHist = macd(close_price, macdShort, macdLong, macdSignal)
    upperBand, middleBand, lowerBand = talib.BBANDS(close_price, timeperiod=bbLength, nbdevup=bbMultiplier, nbdevdn=bbMultiplier, matype=0)
    
    # Condição de mercado em tendência (baseada no ADX)
    trendingMarket = adx >= adxThreshold
    
    # Condições de lateralização com Bollinger Bands
    bandWidth = (upperBand - lowerBand) / middleBand
    isLateral = bandWidth < lateralThreshold
    
    # Condições de crossover
    longCondition = (crossover(emaShort, emaLong)) & (rsi < 60) & (macdHist > 0.5) & trendingMarket
    shortCondition = (crossunder(emaShort, emaLong)) & (rsi > 40) & (macdHist < -0.5) & trendingMarket
    
    # Inicialização do Backtest
    saldo = 1_000_000  # Saldo inicial de 1.000.000
    quantidade = 0  # Quantidade de BTC comprada/vendida na transação
    position_open = False  # Indica se estamos em uma transação
    current_position = None  # 'long' ou 'short'
    entry_price = None  # Preço de entrada da posição
    trade_count = 0  # Contador de trades
    
    # Loop para verificar e executar as ordens
    for i in range(len(df)):
        # Estratégia de Mean Reversion para mercado lateral
        if isLateral[i]:
            if not position_open:
                if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i] and longCondition[i]:
                    entry_price = close_price[i]
                    stopLossLong = entry_price * stoploss_lateral_long
                    takeProfitLong = entry_price * stopgain_lateral_long
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na compra
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                elif (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i] and shortCondition[i]:
                    entry_price = close_price[i]
                    stopLossShort = entry_price * stoploss_lateral_short
                    takeProfitShort = entry_price * stopgain_lateral_short
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na venda
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
            elif position_open:
                if current_position == 'long':
                    if (close_price[i] > upperBand[i]) and crossover(close_price, upperBand)[i] and shortCondition[i]:
                        saldo = quantidade * close_price[i]
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Short
                        entry_price = close_price[i]
                        stopLossShort = entry_price * stoploss_lateral_short
                        takeProfitShort = entry_price * stopgain_lateral_short
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'short'
                        trade_count += 1
                elif current_position == 'short':
                    if (close_price[i] < lowerBand[i]) and crossover(close_price, lowerBand)[i] and longCondition[i]:
                        saldo = saldo + (quantidade * (entry_price - close_price[i]))
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Long
                        entry_price = close_price[i]
                        stopLossLong = entry_price * stoploss_lateral_long
                        takeProfitLong = entry_price * stopgain_lateral_long
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'long'
                        trade_count += 1

        # Estratégia para mercado não lateral
        if not isLateral[i]:
            if not position_open:
                if longCondition[i]:
                    entry_price = close_price[i]
                    stopLossLong = entry_price * stoploss_normal_long
                    takeProfitLong = entry_price * stopgain_normal_long
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na compra
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'long'
                    trade_count += 1
                elif shortCondition[i]:
                    entry_price = close_price[i]
                    stopLossShort = entry_price * stoploss_normal_short
                    takeProfitShort = entry_price * stopgain_normal_short
                    quantidade = saldo / entry_price
                    # Aplicar taxa de corretora na venda
                    saldo -= saldo * commission
                    position_open = True
                    current_position = 'short'
                    trade_count += 1
            elif position_open:
                if current_position == 'long':
                    if shortCondition[i]:
                        saldo = quantidade * close_price[i]
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Short
                        entry_price = close_price[i]
                        stopLossShort = entry_price * stoploss_normal_short
                        takeProfitShort = entry_price * stopgain_normal_short
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'short'
                        trade_count += 1
                elif current_position == 'short':
                    if longCondition[i]:
                        saldo = saldo + (quantidade * (entry_price - close_price[i]))
                        # Aplicar taxa de corretora na venda
                        saldo -= saldo * commission
                        # Inversão para Long
                        entry_price = close_price[i]
                        stopLossLong = entry_price * stoploss_normal_long
                        takeProfitLong = entry_price * stopgain_normal_long
                        quantidade = saldo / entry_price
                        # Aplicar taxa de corretora na compra
                        saldo -= saldo * commission
                        current_position = 'long'
                        trade_count += 1

                # Gerenciamento de Stop Loss e Take Profit
                if current_position == 'long':
                    if low_price[i] <= stopLossLong:
                        saldo = quantidade * stopLossLong
                        position_open = False
                        current_position = None
                    elif high_price[i] >= takeProfitLong:
                        saldo = quantidade * takeProfitLong
                        position_open = False
                        current_position = None
                elif current_position == 'short':
                    if high_price[i] >= stopLossShort:
                        saldo = saldo - (quantidade * (stopLossShort - entry_price))
                        position_open = False
                        current_position = None
                    elif low_price[i] <= takeProfitShort:
                        saldo = saldo + (quantidade * (entry_price - takeProfitShort))
                        position_open = False
                        current_position = None

    # Fechar posição aberta no final do backtest
    if position_open:
        if current_position == 'long':
            saldo = quantidade * close_price.iloc[-1]
        elif current_position == 'short':
            saldo = saldo + (quantidade * (entry_price - close_price.iloc[-1]))
    
    return saldo, trade_count

# Função para gerar listas de parâmetros com base em [início, fim, passo]
def generate_parameter_list(start, end, step, decimals=0):
    if isinstance(start, float) or isinstance(end, float) or isinstance(step, float):
        num = int(np.floor((end - start) / step)) + 1
        return [round(start + step * i, decimals) for i in range(num)]
    else:
        return list(range(start, end + 1, step))

# Função para realizar Random Search
def random_search(df, param_grid, n_iterations, seed=None):
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)
    
    keys = list(param_grid.keys())
    results = []
    
    print(f"Iniciando Random Search com {n_iterations} iterações...")
    
    for _ in tqdm(range(n_iterations), desc="Random Search"):
        # Selecionar aleatoriamente um valor para cada parâmetro
        params = {key: random.choice(values) for key, values in param_grid.items()}
        
        # Criar uma tupla de parâmetros na ordem esperada pela função backtest
        param_tuple = (
            params['emaShortLength'],
            params['emaLongLength'],
            params['rsiLength'],
            params['macdShort'],
            params['macdLong'],
            params['macdSignal'],
            params['adxLength'],
            params['adxSmoothing'],
            params['adxThreshold'],
            params['bbLength'],
            params['bbMultiplier'],
            params['lateralThreshold'],
            params['stopgain_lateral_long'],
            params['stoploss_lateral_long'],
            params['stopgain_lateral_short'],
            params['stoploss_lateral_short'],
            params['stopgain_normal_long'],
            params['stoploss_normal_long'],
            params['stopgain_normal_short'],
            params['stoploss_normal_short'],
            params['commission']
        )
        
        # Executar o backtest com os parâmetros selecionados
        saldo_final, trade_count = backtest(param_tuple, df)
        
        # Adicionar os resultados
        result = params.copy()
        result['saldo_final'] = saldo_final
        result['trade_count'] = trade_count
        results.append(result)
    
    # Converter os resultados para um DataFrame
    resultados_df = pd.DataFrame(results)
    return resultados_df

# Carregar o CSV com nome atualizado
df = pd.read_csv('BYBIT_BTCUSDT.P_1h.csv')
# df['time'] = pd.to_datetime(df['time'], unit='s')  # Descomente se necessário

# Definir a grade de parâmetros para a Random Search com intervalos e passos
param_grid_definicao = {
    'emaShortLength': [5, 20, 1],
    'emaLongLength': [20, 100, 1],
    'rsiLength': [7, 21, 1],
    'macdShort': [5, 15, 1],
    'macdLong': [20, 35, 1],
    'macdSignal': [5, 12, 1],
    'adxLength': [7, 28, 1],
    'adxSmoothing': [7, 21, 1],
    'adxThreshold': [20, 40, 1],
    'bbLength': [10, 30, 1],
    'bbMultiplier': [1.5, 3.0, 0.1],
    'lateralThreshold': [0.002, 0.01, 0.001],
    'stopgain_lateral_long': [1.02, 1.10, 0.01],
    'stoploss_lateral_long': [0.90, 0.98, 0.01],
    'stopgain_lateral_short': [0.90, 0.98, 0.01],
    'stoploss_lateral_short': [1.02, 1.10, 0.01],
    'stopgain_normal_long': [1.05, 1.35, 0.01],
    'stoploss_normal_long': [0.80, 0.95, 0.01],
    'stopgain_normal_short': [0.70, 0.95, 0.01],
    'stoploss_normal_short': [1.05, 1.15, 0.01],
    'commission': [0.00032]  # Fixa
}

# Gerar listas de valores para cada parâmetro
param_grid = {
    key: generate_parameter_list(*values) if key != 'commission' else values
    for key, values in param_grid_definicao.items()
}

# Definir o número de iterações para a Random Search
n_iterations = 10000  # Ajuste conforme a capacidade computacional

# Executar a Random Search
resultado_random = random_search(df, param_grid, n_iterations, seed=42)

# Ordenar os resultados pelo saldo final em ordem decrescente
resultado_random_sorted = resultado_random.sort_values(by='saldo_final', ascending=False)

# Exibir os top 5 resultados
print("\nTop 5 Resultados da Random Search:")
print(resultado_random_sorted.head(5))

# Salvar os resultados em um arquivo CSV para análise posterior
resultado_random_sorted.to_csv('random_search_resultados.csv', index=False)
# Out:
# Iniciando Random Search com 100 iterações...
# Random Search: 100%|██████████| 100/100 [01:21<00:00,  1.22it/s]
# Top 5 Resultados da Random Search:
#     emaShortLength  emaLongLength  rsiLength  macdShort  macdLong  macdSignal  \
# 70               7             85         17          6        26          10
# 31              10             59          8         14        20           9
# 19              12             54          9          6        32           5
# 58               6             62         10          7        26           6
# 57              19             50         20         10        23          10
#
#     adxLength  adxSmoothing  adxThreshold  bbLength  ...  \
# 70         18            18            40        14  ...
# 31         25            17            32        22  ...
# 19         22            10            26        24  ...
# 58         24            10            38        16  ...
# 57         24            21            40        21  ...
#
#     stoploss_lateral_long  stopgain_lateral_short  stoploss_lateral_short  \
# 70                    1.0                     1.0                     1.0
# 31                    1.0                     1.0                     1.0
# 19                    1.0                     1.0                     1.0
# 58                    1.0                     1.0                     1.0
# 57                    1.0                     1.0                     1.0
#
#     stopgain_normal_long  stoploss_normal_long  stopgain_normal_short  \
# 70                   1.0                   1.0                    1.0
# 31                   1.0                   1.0                    1.0
# 19                   1.0                   1.0                    1.0
# 58                   1.0                   1.0                    1.0
# 57                   1.0                   1.0                    1.0
#
#     stoploss_normal_short  commission  saldo_final  trade_count
# 70                    1.0     0.00032    1000000.0            1
# 31                    1.0     0.00032    1000000.0            0
# 19                    1.0     0.00032    1000000.0            1
# 58                    1.0     0.00032    1000000.0            0
# 57                    1.0     0.00032    1000000.0            0
#
# [5 rows x 23 columns]

# %%
from joblib import Parallel, delayed

# Função para realizar uma única iteração do Random Search
def single_iteration(df, param_grid):
    # Selecionar aleatoriamente um valor para cada parâmetro
    params = {key: random.choice(values) for key, values in param_grid.items()}
    
    # Criar uma tupla de parâmetros na ordem esperada pela função backtest
    param_tuple = (
        params['emaShortLength'],
        params['emaLongLength'],
        params['rsiLength'],
        params['macdShort'],
        params['macdLong'],
        params['macdSignal'],
        params['adxLength'],
        params['adxSmoothing'],
        params['adxThreshold'],
        params['bbLength'],
        params['bbMultiplier'],
        params['lateralThreshold'],
        params['stopgain_lateral_long'],
        params['stoploss_lateral_long'],
        params['stopgain_lateral_short'],
        params['stoploss_lateral_short'],
        params['stopgain_normal_long'],
        params['stoploss_normal_long'],
        params['stopgain_normal_short'],
        params['stoploss_normal_short'],
        params['commission']
    )
    
    # Executar o backtest com os parâmetros selecionados
    saldo_final, trade_count = backtest(param_tuple, df)
    
    # Adicionar os resultados
    result = params.copy()
    result['saldo_final'] = saldo_final
    result['trade_count'] = trade_count
    return result

# Função para realizar Random Search com paralelização
def random_search_parallel(df, param_grid, n_iterations, n_jobs=-1, seed=None):
    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)
    
    print(f"Iniciando Random Search com {n_iterations} iterações em paralelo...")
    
    # Executar as iterações em paralelo
    results = Parallel(n_jobs=n_jobs)(
        delayed(single_iteration)(df, param_grid) for _ in range(n_iterations)
    )
    
    # Converter os resultados para um DataFrame
    resultados_df = pd.DataFrame(results)
    return resultados_df

# Executar a Random Search com paralelização
resultado_random_parallel = random_search_parallel(df, param_grid, n_iterations=10000, n_jobs=-1, seed=42)

# Ordenar os resultados pelo saldo final em ordem decrescente
resultado_random_parallel_sorted = resultado_random_parallel.sort_values(by='saldo_final', ascending=False)

# Exibir os top 5 resultados
print("\nTop 5 Resultados da Random Search (Paralelizado):")
print(resultado_random_parallel_sorted.head(5))

# Salvar os resultados em um arquivo CSV para análise posterior
resultado_random_parallel_sorted.to_csv('random_search_resultados_paralelizado.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 60
#      57     return resultados_df
#      59 # Executar a Random Search com paralelização
# ---> 60 resultado_random_parallel = random_search_parallel(df, param_grid, n_iterations=10000, n_jobs=-1, seed=42)
#      62 # Ordenar os resultados pelo saldo final em ordem decrescente
#      63 resultado_random_parallel_sorted = resultado_random_parallel.sort_values(by='saldo_final', ascending=False)
#
# NameError: name 'param_grid' is not defined
